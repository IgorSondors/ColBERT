# %%
import json

pth_json = '/mnt/vdb1/Datasets/ColBERT/18_categories/metrics_data/EVAL/categories_one_by_one/triples_shuffle_colbert-9555.json'
with open(pth_json, 'r') as fp:
    data = json.load(fp)

data = {int(k):v for k,v in data.items()}
data #  a list of (passage_id, rank, score) for the top-k passages
# Out:
# {363: [[57813, 1, 25.75],
#   [57617, 2, 21.34375],
#   [57781, 3, 20.6875],
#   [57814, 4, 20.234375],
#   [57770, 5, 19.109375]],
#  929: [[57782, 1, 29.1875],
#   [57781, 2, 25.234375],
#   [57814, 3, 23.625],
#   [57743, 4, 22.09375],
#   [57640, 5, 21.90625]],
#  1794: [[57553, 1, 25.4375],
#   [57552, 2, 22.09375],
#   [57554, 3, 22.03125],
#   [57562, 4, 19.234375],
#   [57376, 5, 17.828125]],
#  1925: [[57780, 1, 18.4375],
#   [57838, 2, 17.15625],
#   [57837, 3, 16.609375],
#   [57779, 4, 16.046875],
#   [57827, 5, 15.5234375]],
#  2738: [[57843, 1, 28.4375],
#   [57842, 2, 21.078125],
#   [57671, 3, 19.609375],
#   [57819, 4, 18.78125],
#   [57772, 5, 18.75]],
#  3069: [[57787, 1, 27.90625],
#   [57777, 2, 23.296875],
#   [57401, 3, 22.609375],
#   [57402, 4, 22.078125],
#   [57400, 5, 20.796875]],
#  3302: [[57789, 1, 27.6875],
#   [57788, 2, 23.75],
#   [57687, 3, 21.53125],
#   [57743, 4, 20.4375],
#   [57808, 5, 19.140625]],
#  3515: [[57658, 1, 27.9375],
# ...

# %%
import pandas as pd

pth_models = "/mnt/vdb1/Datasets/ColBERT/18_categories/test/models_18_categories.csv"
pth_offers = "/mnt/vdb1/Datasets/ColBERT/18_categories/test/triplets_test_18_categories.csv"

df_models = pd.read_csv(pth_models, sep=";")
df_models = df_models.drop(columns=['average_price', 'comment'])
df_offers = pd.read_csv(pth_offers, sep=";")
df_offers = df_offers.drop(columns=['true_match', 'false_match'])

df_models
# Out:
# /tmp/ipykernel_16805/1844090299.py:6: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_models = pd.read_csv(pth_models, sep=";")
#         model_id        name brand_name            full_name
# 0         623742  920-005619   Logitech  Logitech 920-005619  \
# 1         721952  Zipper Bag       Hama      Hama Zipper Bag
# 2         721970     CC-3064      Nokia        Nokia CC-3064
# 3         751488    CKS-X7/R       Sony        Sony CKS-X7/R
# 4         751989   EP-031023    Era Pro    Era Pro EP-031023
# ...          ...         ...        ...                  ...
# 103209   7049424      MD-108       Mivo          Mivo MD-108
# 103210   7049425      MD-165       Mivo          Mivo MD-165
# 103211   7049426   Boost 20W     Rocket     Rocket Boost 20W
# 103212   7049427  Motion 10W     Rocket    Rocket Motion 10W
# 103213   7049428          Z1   SmartBuy          SmartBuy Z1
#
# ...

# %%
df_offers
# Out:
#                                                      name  model_id
# 0       Портативная акустика Hoco HC2 Xpress темно-зел...   4771613  \
# 1       Акустическая система HYUNDAI Колонка порт. H-P...   4570006
# 2       Кухонная мойка из искусственного камня Vigro V...   5769579
# 3       Хиллс 604304 Puppy Large сух.д/щенков крупных ...   4386018
# 4          Смартфон Xiaomi POCO M5 4/128 GB Global, серый   5506115
# ...                                                   ...       ...
# 135891                      Кухонная Мойка Zorg X-78-2-44   3601922
# 135892  Balenciaga, Cristobal Pour Homme, 100 мл., туа...   3081853
# 135893   Умная колонка MAIL Капсула, белый [mrc01(white)]   4855069
# 135894  Наушники беспроводные JBL Tune 750BTNC черные ...   4455835
# 135895              Кухонная мойка Granula GR-7804 Арктик   3601738
#
#                                      category_name  category_id
# 0                             портативная акустика         3904
# ...

# %%
x = list(data.keys())
x.sort()
print(x)
print(len(x))
# Out:
# [0, 1, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 16, 17, 18, 19, 20, 21, 22, 24, 26, 27, 29, 32, 34, 37, 38, 39, 40, 41, 42, 43, 49, 50, 51, 53, 54, 55, 56, 57, 58, 59, 60, 62, 64, 65, 67, 68, 70, 72, 73, 74, 75, 76, 77, 78, 79, 80, 82, 85, 86, 87, 88, 90, 92, 93, 95, 96, 99, 100, 101, 102, 103, 109, 111, 113, 117, 118, 119, 120, 122, 126, 129, 130, 131, 132, 133, 134, 135, 137, 138, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 152, 155, 157, 158, 160, 162, 164, 167, 168, 170, 171, 172, 178, 179, 181, 182, 183, 184, 185, 188, 190, 193, 194, 195, 197, 202, 203, 204, 205, 207, 208, 209, 210, 213, 214, 215, 217, 218, 219, 220, 221, 222, 223, 224, 225, 229, 230, 231, 232, 235, 239, 241, 242, 243, 244, 245, 246, 247, 251, 252, 254, 255, 256, 258, 259, 262, 264, 265, 267, 268, 269, 270, 273, 274, 275, 276, 277, 279, 281, 282, 283, 284, 285, 286, 288, 291, 292, 293, 295, 298, 299, 301, 302, 303, 304, 305, 307, 309, 310, 311, 312, 313, 314, 316, 318, 319, 320, 321, 322, 323, 324, 325, 326, 328
# ...

# %%
for i in range(len(data)): # data[i] is a list of (passage_id, rank, score) for the top-k passages
    print(i)
    print(data[i])
    model_ids = [df_models.iloc[x[0]].model_id for x in data[i]]
    confidences = [x[2] for x in data[i]]

    df_offers.at[i, 'model_id_pred'] = f"{model_ids[0]},{model_ids[1]},{model_ids[2]},{model_ids[3]},{model_ids[4]}"
    df_offers.at[i,'confidence'] = f"{confidences[0]},{confidences[1]},{confidences[2]},{confidences[3]},{confidences[4]}"
df_offers
# Out:
# 0
# [[76986, 1, 24.5625], [73325, 2, 24.53125], [73706, 3, 18.171875], [77350, 4, 18.171875], [75346, 5, 16.125]]
# 1
# [[73034, 1, 14.6796875], [76711, 2, 14.6796875], [73042, 3, 14.265625], [76719, 4, 14.265625], [74367, 5, 13.734375]]
# 2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 for i in range(len(data)): # data[i] is a list of (passage_id, rank, score) for the top-k passages
#       2     print(i)
# ----> 3     print(data[i])
#       4     model_ids = [df_models.iloc[x[0]].model_id for x in data[i]]
#       5     confidences = [x[2] for x in data[i]]
#
# KeyError: 2

# %%
def split(x):
    return [int(i) for i in x.split(",")]
def split2(x):
    return [float(i) for i in x.split(",")]

df_offers['model_id_pred'] = df_offers['model_id_pred'].apply(split)
df_offers['confidence'] = df_offers['confidence'].apply(split2)
df_offers
# Out:
#                                                      name  model_id
# 0       Портативная акустика Hoco HC2 Xpress темно-зел...   4771613  \
# 1       Акустическая система HYUNDAI Колонка порт. H-P...   4570006
# 2       Кухонная мойка из искусственного камня Vigro V...   5769579
# 3       Хиллс 604304 Puppy Large сух.д/щенков крупных ...   4386018
# 4          Смартфон Xiaomi POCO M5 4/128 GB Global, серый   5506115
# ...                                                   ...       ...
# 135891                      Кухонная Мойка Zorg X-78-2-44   3601922
# 135892  Balenciaga, Cristobal Pour Homme, 100 мл., туа...   3081853
# 135893   Умная колонка MAIL Капсула, белый [mrc01(white)]   4855069
# 135894  Наушники беспроводные JBL Tune 750BTNC черные ...   4455835
# 135895              Кухонная мойка Granula GR-7804 Арктик   3601738
#
#                                      category_name  category_id
# 0                             портативная акустика         3904  \
# ...

# %%
categories = [
    "диктофоны, портативные рекордеры",
    "электронные книги",
    "автомобильные телевизоры, мониторы",
    "смарт-часы и браслеты",
    "портативные медиаплееры",
    "чехлы, обложки для гаджетов (телефонов, планшетов etc)",
    "портативная акустика",
    "мобильные телефоны",
    "VR-гарнитуры (VR-очки, шлемы, очки виртуальной реальности, FPV очки для квадрокоптеров)",
    "планшетные компьютеры и мини-планшеты",
    "наушники, гарнитуры, наушники c микрофоном",
    "радиоприемники, радиобудильники, радиочасы",
    "магнитолы",
    "GPS-навигаторы"
    ]

def accuracy_top_n(offer_model_id, offer_model_id_pred, top_k):
    correct_predictions = 0

    for true_id, predicted_ids in zip(offer_model_id, offer_model_id_pred):
        top_k_predictions = predicted_ids[:top_k]
        if true_id in top_k_predictions:
            correct_predictions += 1

    accuracy = correct_predictions / len(offer_model_id)
    return accuracy

def calculate_precision_recall(offer_model_id, offer_model_id_pred, top_k): # проверить функцию
    true_positives = 0
    false_positives = 0
    false_negatives = 0

    for true_id, predicted_ids in zip(offer_model_id, offer_model_id_pred):
        top_k_predictions = predicted_ids[:top_k]
        
        if true_id in top_k_predictions:
            true_positives += 1
        else:
            false_negatives += 1
            false_positives += (true_id in predicted_ids)

    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0

    return precision, recall

def calc_acc_for_category(df_offers, df_models, imya_kategorii):
    print(f"{imya_kategorii}")
    df_offers = df_offers[df_offers.category_name == imya_kategorii]
    df_models = df_models[df_models.category_name == imya_kategorii]

    offer_names = list(df_offers['name'])
    offer_model_id = list(df_offers['model_id'])
    offer_model_id_pred = list(df_offers['model_id_pred'])

    model_full_names = list(df_models['full_name'])

    print(f"\tофферов {len(offer_model_id)} шт поиск матча для каждого среди {len(model_full_names)} шт моделей:\n")

    top1_accuracy = accuracy_top_n(offer_model_id, offer_model_id_pred, 1)
    top3_accuracy = accuracy_top_n(offer_model_id, offer_model_id_pred, 3)
    top5_accuracy = accuracy_top_n(offer_model_id, offer_model_id_pred, 5)

    top1_precision, top1_recall = calculate_precision_recall(offer_model_id, offer_model_id_pred, top_k=1)
    top3_precision, top3_recall = calculate_precision_recall(offer_model_id, offer_model_id_pred, top_k=3)
    top5_precision, top5_recall = calculate_precision_recall(offer_model_id, offer_model_id_pred, top_k=5)

    print(f'\tTop-1: Accuracy = {top1_accuracy:.2%}')
    print(f'\tTop-3: Accuracy = {top3_accuracy:.2%}')
    print(f'\tTop-5: Accuracy = {top5_accuracy:.2%}\n')

    # print(f'\tTop-1: Accuracy = {top1_accuracy:.2%}, Precision = {top1_precision:.2%}, Recall = {top1_recall:.2%}')
    # print(f'\tTop-3: Accuracy = {top3_accuracy:.2%}, Precision = {top3_precision:.2%}, Recall = {top3_recall:.2%}')
    # print(f'\tTop-5: Accuracy = {top5_accuracy:.2%}, Precision = {top5_precision:.2%}, Recall = {top5_recall:.2%}\n')

for category in categories:
    calc_acc_for_category(df_offers, df_models, category)
# Out:
# диктофоны, портативные рекордеры
# 	офферов 251 шт поиск матча для каждого среди 488 шт моделей:
#
# 	Top-1: Accuracy = 85.26%
# 	Top-3: Accuracy = 88.05%
# 	Top-5: Accuracy = 89.24%
#
# электронные книги
# 	офферов 367 шт поиск матча для каждого среди 680 шт моделей:
#
# 	Top-1: Accuracy = 70.84%
# 	Top-3: Accuracy = 76.02%
# 	Top-5: Accuracy = 77.66%
#
# автомобильные телевизоры, мониторы
# 	офферов 100 шт поиск матча для каждого среди 790 шт моделей:
#
# 	Top-1: Accuracy = 68.00%
# 	Top-3: Accuracy = 72.00%
# 	Top-5: Accuracy = 73.00%
#
# смарт-часы и браслеты
# 	офферов 6083 шт поиск матча для каждого среди 2577 шт моделей:
#
# 	Top-1: Accuracy = 82.44%
# 	Top-3: Accuracy = 88.43%
# 	Top-5: Accuracy = 90.35%
#
# портативные медиаплееры
# 	офферов 589 шт поиск матча для каждого среди 847 шт моделей:
#
# 	Top-1: Accuracy = 86.25%
# 	Top-3: Accuracy = 91.17%
# 	Top-5: Accuracy = 92.36%
#
# чехлы, обложки для гаджетов (телефонов, планшетов etc)
# ...

# %%
"""
диктофоны, портативные рекордеры
	офферов 251 шт поиск матча для каждого среди 488 шт моделей:

	Top-1: Accuracy = 85.26%
	Top-3: Accuracy = 88.05%
	Top-5: Accuracy = 89.24%

электронные книги
	офферов 367 шт поиск матча для каждого среди 680 шт моделей:

	Top-1: Accuracy = 70.84%
	Top-3: Accuracy = 76.02%
	Top-5: Accuracy = 77.66%

автомобильные телевизоры, мониторы
	офферов 100 шт поиск матча для каждого среди 790 шт моделей:

	Top-1: Accuracy = 68.00%
	Top-3: Accuracy = 72.00%
	Top-5: Accuracy = 73.00%

смарт-часы и браслеты
	офферов 6083 шт поиск матча для каждого среди 2577 шт моделей:

	Top-1: Accuracy = 82.44%
	Top-3: Accuracy = 88.43%
	Top-5: Accuracy = 90.35%

портативные медиаплееры
	офферов 589 шт поиск матча для каждого среди 847 шт моделей:

	Top-1: Accuracy = 86.25%
	Top-3: Accuracy = 91.17%
	Top-5: Accuracy = 92.36%

чехлы, обложки для гаджетов (телефонов, планшетов etc)
	офферов 7978 шт поиск матча для каждого среди 37045 шт моделей:

	Top-1: Accuracy = 47.67%
	Top-3: Accuracy = 64.05%
	Top-5: Accuracy = 70.49%

портативная акустика
	офферов 13276 шт поиск матча для каждого среди 7399 шт моделей:

	Top-1: Accuracy = 77.64%
	Top-3: Accuracy = 81.06%
	Top-5: Accuracy = 82.08%

мобильные телефоны
	офферов 25697 шт поиск матча для каждого среди 9494 шт моделей:

	Top-1: Accuracy = 77.45%
	Top-3: Accuracy = 85.19%
	Top-5: Accuracy = 87.69%

VR-гарнитуры (VR-очки, шлемы, очки виртуальной реальности, FPV очки для квадрокоптеров)
	офферов 195 шт поиск матча для каждого среди 146 шт моделей:

	Top-1: Accuracy = 44.62%
	Top-3: Accuracy = 65.13%
	Top-5: Accuracy = 69.23%

планшетные компьютеры и мини-планшеты
	офферов 5785 шт поиск матча для каждого среди 3839 шт моделей:

	Top-1: Accuracy = 68.44%
	Top-3: Accuracy = 81.56%
	Top-5: Accuracy = 85.57%

наушники, гарнитуры, наушники c микрофоном
	офферов 22915 шт поиск матча для каждого среди 11118 шт моделей:

	Top-1: Accuracy = 77.73%
	Top-3: Accuracy = 81.93%
	Top-5: Accuracy = 82.93%

радиоприемники, радиобудильники, радиочасы
	офферов 954 шт поиск матча для каждого среди 1452 шт моделей:

	Top-1: Accuracy = 82.81%
	Top-3: Accuracy = 84.70%
	Top-5: Accuracy = 85.22%

магнитолы
	офферов 208 шт поиск матча для каждого среди 498 шт моделей:

	Top-1: Accuracy = 84.13%
	Top-3: Accuracy = 88.94%
	Top-5: Accuracy = 89.42%

GPS-навигаторы
	офферов 279 шт поиск матча для каждого среди 1709 шт моделей:

	Top-1: Accuracy = 78.85%
	Top-3: Accuracy = 83.87%
	Top-5: Accuracy = 85.30%

"""

# %%
"""
диктофоны, портативные рекордеры
	офферов 251 шт поиск матча для каждого среди 488 шт моделей:

	Top-1: Accuracy = 86.85%
	Top-3: Accuracy = 89.24%
	Top-5: Accuracy = 90.84%

электронные книги
	офферов 367 шт поиск матча для каждого среди 680 шт моделей:

	Top-1: Accuracy = 61.31%
	Top-3: Accuracy = 74.39%
	Top-5: Accuracy = 76.57%

автомобильные телевизоры, мониторы
	офферов 100 шт поиск матча для каждого среди 790 шт моделей:

	Top-1: Accuracy = 69.00%
	Top-3: Accuracy = 72.00%
	Top-5: Accuracy = 73.00%

смарт-часы и браслеты
	офферов 6083 шт поиск матча для каждого среди 2577 шт моделей:

	Top-1: Accuracy = 75.06%
	Top-3: Accuracy = 83.56%
	Top-5: Accuracy = 86.55%

портативные медиаплееры
	офферов 589 шт поиск матча для каждого среди 847 шт моделей:

	Top-1: Accuracy = 82.51%
	Top-3: Accuracy = 90.15%
	Top-5: Accuracy = 91.51%

чехлы, обложки для гаджетов (телефонов, планшетов etc)
	офферов 7978 шт поиск матча для каждого среди 37045 шт моделей:

	Top-1: Accuracy = 46.48%
	Top-3: Accuracy = 61.36%
	Top-5: Accuracy = 67.54%

портативная акустика
	офферов 13276 шт поиск матча для каждого среди 7399 шт моделей:

	Top-1: Accuracy = 74.77%
	Top-3: Accuracy = 79.17%
	Top-5: Accuracy = 80.62%

мобильные телефоны
	офферов 25697 шт поиск матча для каждого среди 9494 шт моделей:

	Top-1: Accuracy = 71.30%
	Top-3: Accuracy = 79.09%
	Top-5: Accuracy = 81.40%

VR-гарнитуры (VR-очки, шлемы, очки виртуальной реальности, FPV очки для квадрокоптеров)
	офферов 195 шт поиск матча для каждого среди 146 шт моделей:

	Top-1: Accuracy = 48.21%
	Top-3: Accuracy = 63.59%
	Top-5: Accuracy = 74.36%

планшетные компьютеры и мини-планшеты
	офферов 5785 шт поиск матча для каждого среди 3839 шт моделей:

	Top-1: Accuracy = 59.17%
	Top-3: Accuracy = 72.58%
	Top-5: Accuracy = 77.93%

наушники, гарнитуры, наушники c микрофоном
	офферов 22915 шт поиск матча для каждого среди 11118 шт моделей:

	Top-1: Accuracy = 74.41%
	Top-3: Accuracy = 80.14%
	Top-5: Accuracy = 81.75%

радиоприемники, радиобудильники, радиочасы
	офферов 954 шт поиск матча для каждого среди 1452 шт моделей:

	Top-1: Accuracy = 79.98%
	Top-3: Accuracy = 83.96%
	Top-5: Accuracy = 84.80%

магнитолы
	офферов 208 шт поиск матча для каждого среди 498 шт моделей:

	Top-1: Accuracy = 83.17%
	Top-3: Accuracy = 87.50%
	Top-5: Accuracy = 90.38%

GPS-навигаторы
	офферов 279 шт поиск матча для каждого среди 1709 шт моделей:

	Top-1: Accuracy = 72.76%
	Top-3: Accuracy = 83.87%
	Top-5: Accuracy = 87.10%


"""
# Out:
# '\nдиктофоны, портативные рекордеры\n\tофферов 251 шт поиск матча для каждого среди 488 шт моделей:\n\n\tTop-1: Accuracy = 86.85%\n\tTop-3: Accuracy = 89.24%\n\tTop-5: Accuracy = 90.84%\n\nэлектронные книги\n\tофферов 367 шт поиск матча для каждого среди 680 шт моделей:\n\n\tTop-1: Accuracy = 61.31%\n\tTop-3: Accuracy = 74.39%\n\tTop-5: Accuracy = 76.57%\n\nавтомобильные телевизоры, мониторы\n\tофферов 100 шт поиск матча для каждого среди 790 шт моделей:\n\n\tTop-1: Accuracy = 69.00%\n\tTop-3: Accuracy = 72.00%\n\tTop-5: Accuracy = 73.00%\n\nсмарт-часы и браслеты\n\tофферов 6083 шт поиск матча для каждого среди 2577 шт моделей:\n\n\tTop-1: Accuracy = 75.06%\n\tTop-3: Accuracy = 83.56%\n\tTop-5: Accuracy = 86.55%\n\nпортативные медиаплееры\n\tофферов 589 шт поиск матча для каждого среди 847 шт моделей:\n\n\tTop-1: Accuracy = 82.51%\n\tTop-3: Accuracy = 90.15%\n\tTop-5: Accuracy = 91.51%\n\nчехлы, обложки для гаджетов (телефонов, планшетов etc)\n\tофферов 7978 шт поиск матча для каждог
# ...

# %%
"""
диктофоны, портативные рекордеры
	офферов 251 шт поиск матча для каждого среди 488 шт моделей:

	Top-1: Accuracy = 84.06%
	Top-3: Accuracy = 87.25%
	Top-5: Accuracy = 88.45%

электронные книги
	офферов 367 шт поиск матча для каждого среди 680 шт моделей:

	Top-1: Accuracy = 68.94%
	Top-3: Accuracy = 75.20%
	Top-5: Accuracy = 76.29%

автомобильные телевизоры, мониторы
	офферов 100 шт поиск матча для каждого среди 790 шт моделей:

	Top-1: Accuracy = 66.00%
	Top-3: Accuracy = 72.00%
	Top-5: Accuracy = 73.00%

смарт-часы и браслеты
	офферов 6083 шт поиск матча для каждого среди 2577 шт моделей:

	Top-1: Accuracy = 79.86%
	Top-3: Accuracy = 87.31%
	Top-5: Accuracy = 89.17%

портативные медиаплееры
	офферов 589 шт поиск матча для каждого среди 847 шт моделей:

	Top-1: Accuracy = 85.74%
	Top-3: Accuracy = 91.17%
	Top-5: Accuracy = 92.87%

чехлы, обложки для гаджетов (телефонов, планшетов etc)
	офферов 7978 шт поиск матча для каждого среди 37045 шт моделей:

	Top-1: Accuracy = 49.29%
	Top-3: Accuracy = 65.35%
	Top-5: Accuracy = 71.31%

портативная акустика
	офферов 13276 шт поиск матча для каждого среди 7399 шт моделей:

	Top-1: Accuracy = 76.63%
	Top-3: Accuracy = 80.39%
	Top-5: Accuracy = 81.43%

мобильные телефоны
	офферов 25697 шт поиск матча для каждого среди 9494 шт моделей:

	Top-1: Accuracy = 75.39%
	Top-3: Accuracy = 83.42%
	Top-5: Accuracy = 85.69%

VR-гарнитуры (VR-очки, шлемы, очки виртуальной реальности, FPV очки для квадрокоптеров)
	офферов 195 шт поиск матча для каждого среди 146 шт моделей:

	Top-1: Accuracy = 48.72%
	Top-3: Accuracy = 72.82%
	Top-5: Accuracy = 76.92%

планшетные компьютеры и мини-планшеты
	офферов 5785 шт поиск матча для каждого среди 3839 шт моделей:

	Top-1: Accuracy = 64.62%
	Top-3: Accuracy = 78.89%
	Top-5: Accuracy = 83.53%

наушники, гарнитуры, наушники c микрофоном
	офферов 22915 шт поиск матча для каждого среди 11118 шт моделей:

	Top-1: Accuracy = 76.91%
	Top-3: Accuracy = 81.00%
	Top-5: Accuracy = 82.04%

радиоприемники, радиобудильники, радиочасы
	офферов 954 шт поиск матча для каждого среди 1452 шт моделей:

	Top-1: Accuracy = 82.08%
	Top-3: Accuracy = 84.17%
	Top-5: Accuracy = 84.59%

магнитолы
	офферов 208 шт поиск матча для каждого среди 498 шт моделей:

	Top-1: Accuracy = 81.25%
	Top-3: Accuracy = 87.98%
	Top-5: Accuracy = 89.90%

GPS-навигаторы
	офферов 279 шт поиск матча для каждого среди 1709 шт моделей:

	Top-1: Accuracy = 79.93%
	Top-3: Accuracy = 85.66%
	Top-5: Accuracy = 86.74%

"""
# Out:
# '\nдиктофоны, портативные рекордеры\n\tофферов 251 шт поиск матча для каждого среди 488 шт моделей:\n\n\tTop-1: Accuracy = 84.06%\n\tTop-3: Accuracy = 87.25%\n\tTop-5: Accuracy = 88.45%\n\nэлектронные книги\n\tофферов 367 шт поиск матча для каждого среди 680 шт моделей:\n\n\tTop-1: Accuracy = 68.94%\n\tTop-3: Accuracy = 75.20%\n\tTop-5: Accuracy = 76.29%\n\nавтомобильные телевизоры, мониторы\n\tофферов 100 шт поиск матча для каждого среди 790 шт моделей:\n\n\tTop-1: Accuracy = 66.00%\n\tTop-3: Accuracy = 72.00%\n\tTop-5: Accuracy = 73.00%\n\nсмарт-часы и браслеты\n\tофферов 6083 шт поиск матча для каждого среди 2577 шт моделей:\n\n\tTop-1: Accuracy = 79.86%\n\tTop-3: Accuracy = 87.31%\n\tTop-5: Accuracy = 89.17%\n\nпортативные медиаплееры\n\tофферов 589 шт поиск матча для каждого среди 847 шт моделей:\n\n\tTop-1: Accuracy = 85.74%\n\tTop-3: Accuracy = 91.17%\n\tTop-5: Accuracy = 92.87%\n\nчехлы, обложки для гаджетов (телефонов, планшетов etc)\n\tофферов 7978 шт поиск матча для каждог
# ...

# %%
for i in range(len(data)):
    if i==6:
        break
    print(f"{df_offers.iloc[i]['model_id']}: {df_offers.iloc[i]['name']}")
    for j in range(5):
        print(f"\t{df_models.iloc[data[i][j][0]].model_id}: {df_models.iloc[data[i][j][0]].full_name}")
    print("\n")
# Out:
# 4771613: Портативная акустика Hoco HC2 Xpress темно-зеленый
# 	4771613: Hoco HC2 Xpress
# 	4771613: Hoco HC2 Xpress
# 	4851243: Hoco HC2
# 	4851243: Hoco HC2
# 	116390: Sonim XP2
#
#
# 4570006: Акустическая система HYUNDAI Колонка порт. H-PAC560 черный 10W 1.0 BT / 3.5Jack / USB 10м 3000mAh
# 	4570000: Hyundai H-PAC400
# 	4570008: Hyundai H-PCD400
# 	293332: Hyundai H-1541
# 	293516: Hyundai H-1511
# 	5128628: Hyundai H-RCL400
#
#
# 5769579: Кухонная мойка из искусственного камня Vigro VG403 латте (673*495*220)
# 	6189413: Brozo Чехол накладка на OPPO A16/ Оппо А16 прозрачная из качественного силикона с защитой вокруг камер
# 	4847992: IT Baggage Чехол-подставка для планшета универсальный 9,7", Искусственная кожа, Красный ITUNI97-3
# 	5797415: G-Case Чехол книжка из качественной экокожи для Tecno Camon 19 Neo, черный
# 	6189423: Brozo Чехол накладка на Samsung Galaxy A03/Самсунг А03 черный матовый из качественного силикона с защитой вокруг камер
# ...
