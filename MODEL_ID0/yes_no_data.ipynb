# %%
import pandas as pd
import matplotlib

pth_models = "/home/sondors/Documents/price/BERT_data/data/10-04-2024_Timofey/2801_models_Apple.csv"
pth_offers = "/home/sondors/Documents/price/BERT_data/data/17-04-2024_Timofey/MODEL_ID=0/2801_Apple_offers_active_model_id0_before_10-04-2024_cos_no_repeats.csv"

df_models = pd.read_csv(pth_models, sep=";")
# df_models = df_models.drop(columns=['average_price', 'comment'])
df_offers = pd.read_csv(pth_offers, sep=";")
# df_offers = df_offers.drop(columns=['true_match', 'false_match'])

df_offers
# Out:
#                                                   name  model_id    offer_id  \
# 0    Смартфон Apple iPhone 15 Pro Max 512GB (MU7F3,...         0  1879787949
# 1    Смартфон Apple iPhone 14 Pro 512GB MQ213LL/A g...         0  1879786672
# 2    Смартфон Apple iPhone 15 Plus 128GB eSim (Розо...         0  1878037377
# 3                Смартфон Apple iPhone 14 512 ГБ Black         0  1878184506
# 4                  Смартфон Apple iPhone 14 256 ГБ Red         0  1878184508
# ..                                                 ...       ...         ...
# 241  Apple iPhone 11 Pro Max 512Gb Dual SIM Midnigh...         0  1878778887
# 242  Apple iPhone 11 Pro Max 64Gb Dual SIM Space Gr...         0  1878779487
# 243  Смартфон Apple iPhone 14 Pro 256GB Global (256...         0  1878794631
# 244  Смартфон Apple A2403 iPhone 12 128Gb 4Gb белый...         0  1878800745
# 245  Apple iPhone 14 Pro Max 1ТБ Deep Purple (Глубо...         0  1878795827
#
#      modelized_by_barcode       category_name  category_id     price  \
# 0                     NaN  мобильные телефоны         2801  175760.0
# 1                     NaN  мобильные телефоны         2801  166572.0
# 2                     NaN  мобильные телефоны         2801   80480.0
# 3                     NaN  мобильные телефоны         2801   88990.0
# 4                     NaN  мобильные телефоны         2801   72190.0
# ..                    ...                 ...          ...       ...
# 241                   NaN  мобильные телефоны         2801  110149.0
# 242                   NaN  мобильные телефоны         2801  120082.0
# 243                   NaN  мобильные телефоны         2801   95990.0
# 244                   NaN  мобильные телефоны         2801   61360.0
# 245                   NaN  мобильные телефоны         2801  131910.0
#
#                                                  attrs  \
# 0    [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 1    [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 2    [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 3    [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 4    [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# ..                                                 ...
# 241  [{'id': 14517, 'type': 'b', 'value': 1.0}, {'i...
# 242  [{'id': 14518, 'type': 'b', 'value': 1.0}, {'i...
# 243  [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 244  [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 245  [{'id': 14530, 'type': 'b', 'value': 1.0}, {'i...
#
#                                            description  \
# 0                                        blue titanium
# 1                         gold, no SIM, dual eSIM only
# 2                                                  NaN
# 3    Диагональ экрана: 6,1" Тип экрана: Super Retin...
# 4    Диагональ экрана: 6,1" Тип экрана: Super Retin...
# ..                                                 ...
# 241  Оригинальный Apple iPhone 11 Pro Max 512Gb Dua...
# 242  Оригинальный Apple iPhone 11 Pro Max 64Gb Dual...
# 243  Фирменный iPhone 14 Pro в состоянии: б/у. Полн...
# 244  Смартфон Apple A2403 iPhone 12 128Gb 4Gb белый...
# 245  Apple iPhone 14 Pro Max — молниеносный смартфо...
#
#                                      external_category  ... cosine_sims_1  \
# 0                 Техника APPLE :: iPhone :: iPhone 15  ...       0.95650
# 1                 Техника APPLE :: iPhone :: iPhone 14  ...       0.95109
# 2                                       iPhone 15 Plus  ...       0.95451
# 3    Смартфоны и планшеты :: Смартфоны :: iPhone ::...  ...       0.88825
# 4    Смартфоны и планшеты :: Смартфоны :: iPhone ::...  ...       0.96965
# ..                                                 ...  ...           ...
# 241                                              Apple  ...       0.83208
# 242                                              Apple  ...       0.78588
# 243                                      iPhone 14 Pro  ...       0.94570
# 244         Смартфоны, планшеты и гаджеты :: Смартфоны  ...       0.93781
# 245                  Телефоны :: Телефоны Apple iPhone  ...       0.87136
#
#     model_id_pred_2  cosine_sims_2  model_id_pred_3  cosine_sims_3  \
# 0         7883783.0        0.85082        7883779.0        0.74075
# 1         7883566.0        0.85605        7883562.0        0.75437
# 2         7883662.0        0.84234        7883673.0        0.83730
# 3         7883462.0        0.70580        7883447.0        0.70350
# 4         7883437.0        0.79708        7883431.0        0.76771
# ..              ...            ...              ...            ...
# 241       7883232.0        0.66117        7883227.0        0.61016
# 242       7883204.0        0.68559        7883229.0        0.66609
# 243       7883551.0        0.81652        7883547.0        0.78174
# 244       7883245.0        0.85067        7883237.0        0.83217
# 245       7883591.0        0.82490        7883582.0        0.66798
#
#      model_id_pred_4  cosine_sims_4  model_id_pred_5  cosine_sims_5  \
# 0          7883789.0        0.67811        7883696.0        0.67342
# 1          7883559.0        0.74706        7883557.0        0.73512
# 2          7883664.0        0.80128        7883661.0        0.79209
# 3          7883453.0        0.67802        7883463.0        0.66680
# 4          7883444.0        0.65443        7883445.0        0.65364
# ..               ...            ...              ...            ...
# 241        7883218.0        0.60801        7883203.0        0.60624
# 242        7883226.0        0.61417        7883863.0        0.59536
# 243        7883445.0        0.78128        7883553.0        0.71542
# 244        7883241.0        0.76494        7883242.0        0.74017
# 245        7883595.0        0.65301        7883532.0        0.64099
#
#      model_id_manual
# 0          7883787.0
# 1          7883558.0
# 2          7883663.0
# 3                0.0
# 4                0.0
# ..               ...
# 241              NaN
# 242              NaN
# 243              NaN
# 244              NaN
# 245              NaN
#
# [246 rows x 23 columns]

# %%
list(df_models.name)
# Out:
# ['iPhone 11 128Gb, Dual nano-SIM, Черный',
#  'iPhone 11 128Gb, nano-Sim+eSIM, Green',
#  'iPhone 11 128Gb, nano-Sim+eSIM, Белый',
#  'iPhone 11 128Gb, nano-Sim+eSIM, Желтый',
#  'iPhone 11 128Gb, nano-Sim+eSIM, Красный',
#  'iPhone 11 128Gb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 11 128Gb, nano-Sim+eSIM, Черный',
#  'iPhone 11 256Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone 11 256Gb, nano-Sim+eSIM, Green',
#  'iPhone 11 256Gb, nano-Sim+eSIM, Yellow',
#  'iPhone 11 256Gb, nano-Sim+eSIM, Белый',
#  'iPhone 11 256Gb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 11 256Gb, nano-Sim+eSIM, Черный',
#  'iPhone 11 64Gb, Dual nano-SIM, Green',
#  'iPhone 11 64Gb, Dual nano-SIM, Белый',
#  'iPhone 11 64Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone 11 64Gb, nano-Sim+eSIM, Green',
#  'iPhone 11 64Gb, nano-Sim+eSIM, Белый',
#  'iPhone 11 64Gb, nano-Sim+eSIM, Желтый',
#  'iPhone 11 64Gb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 11 64Gb, nano-Sim+eSIM, Черный',
#  'iPhone 11 Pro 256Gb, nano-Sim+eSIM, Gold',
#  'iPhone 11 Pro 256Gb, nano-Sim+eSIM, Midnight Green',
#  'iPhone 11 Pro 256Gb, nano-Sim+eSIM, Silver',
#  'iPhone 11 Pro 256Gb, nano-Sim+eSIM, Серый космос',
#  'iPhone 11 Pro 512Gb, nano-Sim+eSIM, Gold',
#  'iPhone 11 Pro 512Gb, nano-Sim+eSIM, Silver',
#  'iPhone 11 Pro 512Gb, nano-Sim+eSIM, Space Gray',
#  'iPhone 11 Pro 512Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 11 Pro 64Gb, nano-Sim+eSIM, Gold',
#  'iPhone 11 Pro 64Gb, nano-Sim+eSIM, Silver',
#  'iPhone 11 Pro 64Gb, nano-Sim+eSIM, Space Gray',
#  'iPhone 11 Pro 64Gb, nano-Sim+eSIM, Тёмно-зелёный',
#  'iPhone 11 Pro Max 256Gb, nano-Sim+eSIM, Gold',
#  'iPhone 11 Pro Max 256Gb, nano-Sim+eSIM, Midnight Green',
#  'iPhone 11 Pro Max 256Gb, nano-Sim+eSIM, Серебристый',
#  'iPhone 11 Pro Max 256Gb, nano-Sim+eSIM, Серый космос',
#  'iPhone 11 Pro Max 512Gb, nano-Sim+eSIM, Gold',
#  'iPhone 11 Pro Max 512Gb, nano-Sim+eSIM, Silver',
#  'iPhone 11 Pro Max 512Gb, nano-Sim+eSIM, Space Gray',
#  'iPhone 11 Pro Max 512Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 11 Pro Max 64Gb, nano-Sim+eSIM, Gold',
#  'iPhone 11 Pro Max 64Gb, nano-Sim+eSIM, Midnight Green',
#  'iPhone 11 Pro Max 64Gb, nano-Sim+eSIM, Silver',
#  'iPhone 11 Pro Max 64Gb, nano-Sim+eSIM, Space Gray',
#  'iPhone 12 128Gb, Dual nano-SIM, Black',
#  'iPhone 12 128Gb, Dual nano-SIM, Green',
#  'iPhone 12 128Gb, Dual nano-SIM, Белый',
#  'iPhone 12 128Gb, Dual nano-SIM, Красный',
#  'iPhone 12 128Gb, Dual nano-SIM, Синий',
#  'iPhone 12 128Gb, eSIM, Green',
#  'iPhone 12 128Gb, nano-Sim+eSIM, Black',
#  'iPhone 12 128Gb, nano-Sim+eSIM, Green',
#  'iPhone 12 128Gb, nano-Sim+eSIM, Белый',
#  'iPhone 12 128Gb, nano-Sim+eSIM, Красный',
#  'iPhone 12 128Gb, nano-Sim+eSIM, Синий',
#  'iPhone 12 128Gb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 12 256Gb, Dual nano-SIM, (PRODUCT)RED',
#  'iPhone 12 256Gb, Dual nano-SIM, Белый',
#  'iPhone 12 256Gb, Dual nano-SIM, Зеленый',
#  'iPhone 12 256Gb, Dual nano-SIM, Синий',
#  'iPhone 12 256Gb, Dual nano-SIM, Фиолетовый',
#  'iPhone 12 256Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone 12 256Gb, nano-Sim+eSIM, Белый',
#  'iPhone 12 256Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 12 256Gb, nano-Sim+eSIM, Синий',
#  'iPhone 12 256Gb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 12 256Gb, nano-Sim+eSIM, Черный',
#  'iPhone 12 64Gb, Dual nano-SIM, (PRODUCT)RED',
#  'iPhone 12 64Gb, Dual nano-SIM, Black',
#  'iPhone 12 64Gb, Dual nano-SIM, Green',
#  'iPhone 12 64Gb, Dual nano-SIM, Белый',
#  'iPhone 12 64Gb, Dual nano-SIM, Синий',
#  'iPhone 12 64Gb, Dual nano-SIM, Фиолетовый',
#  'iPhone 12 64Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone 12 64Gb, nano-Sim+eSIM, Black',
#  'iPhone 12 64Gb, nano-Sim+eSIM, Green',
#  'iPhone 12 64Gb, nano-Sim+eSIM, Белый',
#  'iPhone 12 64Gb, nano-Sim+eSIM, Синий',
#  'iPhone 12 64Gb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 12 mini 128Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone 12 mini 128Gb, nano-Sim+eSIM, Black',
#  'iPhone 12 mini 128Gb, nano-Sim+eSIM, Green',
#  'iPhone 12 mini 128Gb, nano-Sim+eSIM, Purple',
#  'iPhone 12 mini 128Gb, nano-Sim+eSIM, Белый',
#  'iPhone 12 mini 128Gb, nano-Sim+eSIM, Синий',
#  'iPhone 12 mini 256Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone 12 mini 256Gb, nano-Sim+eSIM, Green',
#  'iPhone 12 mini 256Gb, nano-Sim+eSIM, Белый',
#  'iPhone 12 mini 256Gb, nano-Sim+eSIM, Синий',
#  'iPhone 12 mini 256Gb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 12 mini 256Gb, nano-Sim+eSIM, Черный',
#  'iPhone 12 mini 64Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone 12 mini 64Gb, nano-Sim+eSIM, Black',
#  'iPhone 12 mini 64Gb, nano-Sim+eSIM, Green',
#  'iPhone 12 mini 64Gb, nano-Sim+eSIM, Purple',
#  'iPhone 12 mini 64Gb, nano-Sim+eSIM, White',
#  'iPhone 12 mini 64Gb, nano-Sim+eSIM, Синий',
#  'iPhone 12 Pro 128Gb, nano-Sim+eSIM, Gold',
#  'iPhone 12 Pro 128Gb, nano-Sim+eSIM, Silver',
#  'iPhone 12 Pro 128Gb, nano-Sim+eSIM, Графитовый',
#  'iPhone 12 Pro 128Gb, nano-Sim+eSIM, Серебристый',
#  'iPhone 12 Pro 128Gb, nano-Sim+eSIM, Синий',
#  'iPhone 12 Pro 128Gb, nano-Sim+eSIM, Тихоокеанский синий',
#  'iPhone 12 Pro 256Gb, nano-Sim+eSIM, Gold',
#  'iPhone 12 Pro 256Gb, nano-Sim+eSIM, Pacific Blue',
#  'iPhone 12 Pro 256Gb, nano-Sim+eSIM, Silver',
#  'iPhone 12 Pro 256Gb, nano-Sim+eSIM, Графитовый',
#  'iPhone 12 Pro 256Gb, nano-Sim+eSIM, Синий',
#  'iPhone 12 Pro 512Gb, Dual nano-SIM, Синий',
#  'iPhone 12 Pro 512Gb, nano-Sim+eSIM, Gold',
#  'iPhone 12 Pro 512Gb, nano-Sim+eSIM, Graphite',
#  'iPhone 12 Pro 512Gb, nano-Sim+eSIM, Silver',
#  'iPhone 12 Pro 512Gb, nano-Sim+eSIM, Синий',
#  'iPhone 12 Pro 512Gb, nano-Sim+eSIM, Тихоокеанский синий',
#  'iPhone 12 Pro Max 128Gb, nano-Sim+eSIM, Gold',
#  'iPhone 12 Pro Max 128Gb, nano-Sim+eSIM, Graphite',
#  'iPhone 12 Pro Max 128Gb, nano-Sim+eSIM, Pacific Blue',
#  'iPhone 12 Pro Max 128Gb, nano-Sim+eSIM, Серебристый',
#  'iPhone 12 Pro Max 256Gb, nano-Sim+eSIM, Gold',
#  'iPhone 12 Pro Max 256Gb, nano-Sim+eSIM, Graphite',
#  'iPhone 12 Pro Max 256Gb, nano-Sim+eSIM, Pacific Blue',
#  'iPhone 12 Pro Max 256Gb, nano-Sim+eSIM, Silver',
#  'iPhone 12 Pro Max 512Gb, nano-Sim+eSIM, Gold',
#  'iPhone 12 Pro Max 512Gb, nano-Sim+eSIM, Graphite',
#  'iPhone 12 Pro Max 512Gb, nano-Sim+eSIM, Pacific Blue',
#  'iPhone 12 Pro Max 512Gb, nano-Sim+eSIM, Silver',
#  'iPhone 13 128Gb, Dual nano-SIM, Midnight',
#  'iPhone 13 128Gb, Dual nano-SIM, Silver',
#  'iPhone 13 128Gb, Dual nano-SIM, Starlight',
#  'iPhone 13 128Gb, Dual nano-SIM, Зеленый',
#  'iPhone 13 128Gb, Dual nano-SIM, Красный',
#  'iPhone 13 128Gb, Dual nano-SIM, Розовый',
#  'iPhone 13 128Gb, Dual nano-SIM, Синий',
#  'iPhone 13 128Gb, nano-Sim+eSIM, Midnight',
#  'iPhone 13 128Gb, nano-Sim+eSIM, Starlight',
#  'iPhone 13 128Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 13 128Gb, nano-Sim+eSIM, Красный',
#  'iPhone 13 128Gb, nano-Sim+eSIM, Розовый',
#  'iPhone 13 128Gb, nano-Sim+eSIM, Синий',
#  'iPhone 13 256Gb, Dual nano-SIM, Midnight',
#  'iPhone 13 256Gb, Dual nano-SIM, Starlight',
#  'iPhone 13 256Gb, Dual nano-SIM, Зеленый',
#  'iPhone 13 256Gb, Dual nano-SIM, Красный',
#  'iPhone 13 256Gb, Dual nano-SIM, Розовый',
#  'iPhone 13 256Gb, Dual nano-SIM, Синий',
#  'iPhone 13 256Gb, nano-Sim+eSIM, Midnight',
#  'iPhone 13 256Gb, nano-Sim+eSIM, Starlight',
#  'iPhone 13 256Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 13 256Gb, nano-Sim+eSIM, Красный',
#  'iPhone 13 256Gb, nano-Sim+eSIM, Розовый',
#  'iPhone 13 256Gb, nano-Sim+eSIM, Синий',
#  'iPhone 13 512Gb, Dual nano-SIM, Blue',
#  'iPhone 13 512Gb, nano-Sim+eSIM, Blue',
#  'iPhone 13 512Gb, nano-Sim+eSIM, Midnight',
#  'iPhone 13 512Gb, nano-Sim+eSIM, Starlight',
#  'iPhone 13 512Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 13 512Gb, nano-Sim+eSIM, Красный',
#  'iPhone 13 512Gb, nano-Sim+eSIM, Розовый',
#  'iPhone 13 mini 128Gb, nano-Sim+eSIM, Pink',
#  'iPhone 13 mini 128Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 13 mini 128Gb, nano-Sim+eSIM, Красный',
#  'iPhone 13 mini 128Gb, nano-Sim+eSIM, Синий',
#  'iPhone 13 mini 128Gb, nano-Sim+eSIM, Сияющая звезда',
#  'iPhone 13 mini 128Gb, nano-Sim+eSIM, Черный',
#  'iPhone 13 mini 256Gb, Dual nano-SIM, Midnight',
#  'iPhone 13 mini 256Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone 13 mini 256Gb, nano-Sim+eSIM, Midnight',
#  'iPhone 13 mini 256Gb, nano-Sim+eSIM, Белый',
#  'iPhone 13 mini 256Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 13 mini 256Gb, nano-Sim+eSIM, Розовый',
#  'iPhone 13 mini 256Gb, nano-Sim+eSIM, Синий',
#  'iPhone 13 mini 512Gb, nano-Sim+eSIM, Blue',
#  'iPhone 13 mini 512Gb, nano-Sim+eSIM, Green',
#  'iPhone 13 mini 512Gb, nano-Sim+eSIM, Midnight',
#  'iPhone 13 mini 512Gb, nano-Sim+eSIM, Pink',
#  'iPhone 13 mini 512Gb, nano-Sim+eSIM, Starlight',
#  'iPhone 13 mini 512Gb, nano-Sim+eSIM, Красный',
#  'iPhone 13 Pro 128Gb, nano-Sim+eSIM, Alpine Green',
#  'iPhone 13 Pro 128Gb, nano-Sim+eSIM, Silver',
#  'iPhone 13 Pro 128Gb, nano-Sim+eSIM, Голубой',
#  'iPhone 13 Pro 128Gb, nano-Sim+eSIM, Графитовый',
#  'iPhone 13 Pro 128Gb, nano-Sim+eSIM, Золотой',
#  'iPhone 13 Pro 1Tb, nano-Sim+eSIM, Alpine Green',
#  'iPhone 13 Pro 1Tb, nano-Sim+eSIM, Gold',
#  'iPhone 13 Pro 1Tb, nano-Sim+eSIM, Graphite',
#  'iPhone 13 Pro 1Tb, nano-Sim+eSIM, Silver',
#  'iPhone 13 Pro 1Tb, nano-Sim+eSIM, Небесно-голубой',
#  'iPhone 13 Pro 256Gb, nano-Sim+eSIM, Gold',
#  'iPhone 13 Pro 256Gb, nano-Sim+eSIM, Silver',
#  'iPhone 13 Pro 256Gb, nano-Sim+eSIM, Голубой',
#  'iPhone 13 Pro 256Gb, nano-Sim+eSIM, Графитовый',
#  'iPhone 13 Pro 256Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 13 Pro 512Gb, nano-Sim+eSIM, Голубой',
#  'iPhone 13 Pro 512Gb, nano-Sim+eSIM, Графитовый',
#  'iPhone 13 Pro 512Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 13 Pro 512Gb, nano-Sim+eSIM, Золотой',
#  'iPhone 13 Pro 512Gb, nano-Sim+eSIM, Серебристый',
#  'iPhone 13 Pro Max 128Gb, nano-Sim+eSIM, Alpine Green',
#  'iPhone 13 Pro Max 128Gb, nano-Sim+eSIM, Graphite',
#  'iPhone 13 Pro Max 128Gb, nano-Sim+eSIM, Sierra Blue',
#  'iPhone 13 Pro Max 128Gb, nano-Sim+eSIM, Золотой',
#  'iPhone 13 Pro Max 128Gb, nano-Sim+eSIM, Серебристый',
#  'iPhone 13 Pro Max 1Tb, nano-Sim+eSIM, Alpine Green',
#  'iPhone 13 Pro Max 1Tb, nano-Sim+eSIM, Gold',
#  'iPhone 13 Pro Max 1Tb, nano-Sim+eSIM, Graphite',
#  'iPhone 13 Pro Max 1Tb, nano-Sim+eSIM, Sierra Blue',
#  'iPhone 13 Pro Max 1Tb, nano-Sim+eSIM, Silver',
#  'iPhone 13 Pro Max 256Gb, Dual nano-SIM, Голубой',
#  'iPhone 13 Pro Max 256Gb, nano-Sim+eSIM, Gold',
#  'iPhone 13 Pro Max 256Gb, nano-Sim+eSIM, Graphite',
#  'iPhone 13 Pro Max 256Gb, nano-Sim+eSIM, Silver',
#  'iPhone 13 Pro Max 256Gb, nano-Sim+eSIM, Голубой',
#  'iPhone 13 Pro Max 256Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 13 Pro Max 512Gb, nano-Sim+eSIM, Gold',
#  'iPhone 13 Pro Max 512Gb, nano-Sim+eSIM, Голубой',
#  'iPhone 13 Pro Max 512Gb, nano-Sim+eSIM, Графитовый',
#  'iPhone 13 Pro Max 512Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 13 Pro Max 512Gb, nano-Sim+eSIM, Серебристый',
#  'iPhone 14 128Gb, Dual eSIM, Blue',
#  'iPhone 14 128Gb, Dual eSIM, Purple',
#  'iPhone 14 128Gb, Dual eSIM, Starlight',
#  'iPhone 14 128Gb, Dual eSIM, Желтый',
#  'iPhone 14 128Gb, Dual eSIM, Красный',
#  'iPhone 14 128Gb, Dual eSIM, Тёмная ночь',
#  'iPhone 14 128Gb, Dual nano-SIM, Blue',
#  'iPhone 14 128Gb, Dual nano-SIM, Purple',
#  'iPhone 14 128Gb, Dual nano-SIM, Starlight',
#  'iPhone 14 128Gb, Dual nano-SIM, Желтый',
#  'iPhone 14 128Gb, Dual nano-SIM, Красный',
#  'iPhone 14 128Gb, Dual nano-SIM, Тёмная ночь',
#  'iPhone 14 128Gb, nano-Sim+eSIM, Blue',
#  'iPhone 14 128Gb, nano-Sim+eSIM, Purple',
#  'iPhone 14 128Gb, nano-Sim+eSIM, Silver',
#  'iPhone 14 128Gb, nano-Sim+eSIM, Starlight',
#  'iPhone 14 128Gb, nano-Sim+eSIM, Желтый',
#  'iPhone 14 128Gb, nano-Sim+eSIM, Красный',
#  'iPhone 14 128Gb, nano-Sim+eSIM, Тёмная ночь',
#  'iPhone 14 256Gb, Dual eSIM, Blue',
#  'iPhone 14 256Gb, Dual eSIM, Starlight',
#  'iPhone 14 256Gb, Dual eSIM, Желтый',
#  'iPhone 14 256Gb, Dual eSIM, Красный',
#  'iPhone 14 256Gb, Dual eSIM, Тёмная ночь',
#  'iPhone 14 256Gb, Dual eSIM, Фиолетовый',
#  'iPhone 14 256Gb, Dual nano-SIM, Blue',
#  'iPhone 14 256Gb, Dual nano-SIM, Starlight',
#  'iPhone 14 256Gb, Dual nano-SIM, Желтый',
#  'iPhone 14 256Gb, Dual nano-SIM, Красный',
#  'iPhone 14 256Gb, Dual nano-SIM, Тёмная ночь',
#  'iPhone 14 256Gb, Dual nano-SIM, Фиолетовый',
#  'iPhone 14 256Gb, nano-Sim+eSIM, Blue',
#  'iPhone 14 256Gb, nano-Sim+eSIM, Starlight',
#  'iPhone 14 256Gb, nano-Sim+eSIM, Желтый',
#  'iPhone 14 256Gb, nano-Sim+eSIM, Красный',
#  'iPhone 14 256Gb, nano-Sim+eSIM, Тёмная ночь',
#  'iPhone 14 256Gb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 14 512Gb, Dual eSIM, (PRODUCT)RED',
#  'iPhone 14 512Gb, Dual eSIM, Midnight',
#  'iPhone 14 512Gb, Dual eSIM, Purple',
#  'iPhone 14 512Gb, Dual eSIM, Yellow',
#  'iPhone 14 512Gb, Dual eSIM, Синий',
#  'iPhone 14 512Gb, Dual eSIM, Сияющая звезда',
#  'iPhone 14 512Gb, Dual nano-SIM, (PRODUCT)RED',
#  'iPhone 14 512Gb, Dual nano-SIM, Midnight',
#  'iPhone 14 512Gb, Dual nano-SIM, Purple',
#  'iPhone 14 512Gb, Dual nano-SIM, Yellow',
#  'iPhone 14 512Gb, Dual nano-SIM, Синий',
#  'iPhone 14 512Gb, Dual nano-SIM, Сияющая звезда',
#  'iPhone 14 512Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone 14 512Gb, nano-Sim+eSIM, Midnight',
#  'iPhone 14 512Gb, nano-Sim+eSIM, Purple',
#  'iPhone 14 512Gb, nano-Sim+eSIM, Yellow',
#  'iPhone 14 512Gb, nano-Sim+eSIM, Синий',
#  'iPhone 14 512Gb, nano-Sim+eSIM, Сияющая звезда',
#  'iPhone 14 Plus 128Gb, Dual eSIM, (PRODUCT)RED',
#  'iPhone 14 Plus 128Gb, Dual eSIM, Blue',
#  'iPhone 14 Plus 128Gb, Dual eSIM, Белый',
#  'iPhone 14 Plus 128Gb, Dual eSIM, Желтый',
#  'iPhone 14 Plus 128Gb, Dual eSIM, Тёмная ночь',
#  'iPhone 14 Plus 128Gb, Dual eSIM, Фиолетовый',
#  'iPhone 14 Plus 128Gb, Dual nano-SIM, (PRODUCT)RED',
#  'iPhone 14 Plus 128Gb, Dual nano-SIM, Blue',
#  'iPhone 14 Plus 128Gb, Dual nano-SIM, Белый',
#  'iPhone 14 Plus 128Gb, Dual nano-SIM, Желтый',
#  'iPhone 14 Plus 128Gb, Dual nano-SIM, Тёмная ночь',
#  'iPhone 14 Plus 128Gb, Dual nano-SIM, Фиолетовый',
#  'iPhone 14 Plus 128Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone 14 Plus 128Gb, nano-Sim+eSIM, Blue',
#  'iPhone 14 Plus 128Gb, nano-Sim+eSIM, Gold',
#  'iPhone 14 Plus 128Gb, nano-Sim+eSIM, Silver',
#  'iPhone 14 Plus 128Gb, nano-Sim+eSIM, Белый',
#  'iPhone 14 Plus 128Gb, nano-Sim+eSIM, Желтый',
#  'iPhone 14 Plus 128Gb, nano-Sim+eSIM, Тёмная ночь',
#  'iPhone 14 Plus 128Gb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 14 Plus 256Gb, Dual eSIM, Purple',
#  'iPhone 14 Plus 256Gb, Dual eSIM, Yellow',
#  'iPhone 14 Plus 256Gb, Dual eSIM, Красный',
#  'iPhone 14 Plus 256Gb, Dual eSIM, Синий',
#  'iPhone 14 Plus 256Gb, Dual eSIM, Сияющая звезда',
#  'iPhone 14 Plus 256Gb, Dual eSIM, Черный',
#  'iPhone 14 Plus 256Gb, Dual nano-SIM, Purple',
#  'iPhone 14 Plus 256Gb, Dual nano-SIM, Yellow',
#  'iPhone 14 Plus 256Gb, Dual nano-SIM, Красный',
#  'iPhone 14 Plus 256Gb, Dual nano-SIM, Синий',
#  'iPhone 14 Plus 256Gb, Dual nano-SIM, Сияющая звезда',
#  'iPhone 14 Plus 256Gb, Dual nano-SIM, Черный',
#  'iPhone 14 Plus 256Gb, nano-Sim+eSIM, Purple',
#  'iPhone 14 Plus 256Gb, nano-Sim+eSIM, Yellow',
#  'iPhone 14 Plus 256Gb, nano-Sim+eSIM, Красный',
#  'iPhone 14 Plus 256Gb, nano-Sim+eSIM, Синий',
#  'iPhone 14 Plus 256Gb, nano-Sim+eSIM, Сияющая звезда',
#  'iPhone 14 Plus 256Gb, nano-Sim+eSIM, Черный',
#  'iPhone 14 Plus 512Gb, Dual eSIM, (PRODUCT)RED',
#  'iPhone 14 Plus 512Gb, Dual eSIM, Blue',
#  'iPhone 14 Plus 512Gb, Dual eSIM, Midnight',
#  'iPhone 14 Plus 512Gb, Dual eSIM, Starlight',
#  'iPhone 14 Plus 512Gb, Dual eSIM, Yellow',
#  'iPhone 14 Plus 512Gb, Dual eSIM, Фиолетовый',
#  'iPhone 14 Plus 512Gb, Dual nano-SIM, (PRODUCT)RED',
#  'iPhone 14 Plus 512Gb, Dual nano-SIM, Blue',
#  'iPhone 14 Plus 512Gb, Dual nano-SIM, Midnight',
#  'iPhone 14 Plus 512Gb, Dual nano-SIM, Starlight',
#  'iPhone 14 Plus 512Gb, Dual nano-SIM, Yellow',
#  'iPhone 14 Plus 512Gb, Dual nano-SIM, Фиолетовый',
#  'iPhone 14 Plus 512Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone 14 Plus 512Gb, nano-Sim+eSIM, Blue',
#  'iPhone 14 Plus 512Gb, nano-Sim+eSIM, Midnight',
#  'iPhone 14 Plus 512Gb, nano-Sim+eSIM, Starlight',
#  'iPhone 14 Plus 512Gb, nano-Sim+eSIM, Yellow',
#  'iPhone 14 Plus 512Gb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 14 Pro 128Gb, Dual eSIM, Deep Purple',
#  'iPhone 14 Pro 128Gb, Dual eSIM, Gold',
#  'iPhone 14 Pro 128Gb, Dual eSIM, Silver',
#  'iPhone 14 Pro 128Gb, Dual eSIM, Черный',
#  'iPhone 14 Pro 128Gb, Dual nano-SIM, Deep Purple',
#  'iPhone 14 Pro 128Gb, Dual nano-SIM, Gold',
#  'iPhone 14 Pro 128Gb, Dual nano-SIM, Silver',
#  'iPhone 14 Pro 128Gb, Dual nano-SIM, Черный',
#  'iPhone 14 Pro 128Gb, nano-Sim+eSIM, Deep Purple',
#  'iPhone 14 Pro 128Gb, nano-Sim+eSIM, Gold',
#  'iPhone 14 Pro 128Gb, nano-Sim+eSIM, Silver',
#  'iPhone 14 Pro 128Gb, nano-Sim+eSIM, Черный',
#  'iPhone 14 Pro 1Tb, Dual eSIM, Deep Purple',
#  'iPhone 14 Pro 1Tb, Dual eSIM, Gold',
#  'iPhone 14 Pro 1Tb, Dual eSIM, Silver',
#  'iPhone 14 Pro 1Tb, Dual eSIM, Space Black',
#  'iPhone 14 Pro 1Tb, Dual nano-SIM, Deep Purple',
#  'iPhone 14 Pro 1Tb, Dual nano-SIM, Gold',
#  'iPhone 14 Pro 1Tb, Dual nano-SIM, Silver',
#  'iPhone 14 Pro 1Tb, Dual nano-SIM, Space Black',
#  'iPhone 14 Pro 1Tb, nano-Sim+eSIM, Deep Purple',
#  'iPhone 14 Pro 1Tb, nano-Sim+eSIM, Gold',
#  'iPhone 14 Pro 1Tb, nano-Sim+eSIM, Silver',
#  'iPhone 14 Pro 1Tb, nano-Sim+eSIM, Space Black',
#  'iPhone 14 Pro 256Gb, Dual eSIM, Silver',
#  'iPhone 14 Pro 256Gb, Dual eSIM, Space Black',
#  'iPhone 14 Pro 256Gb, Dual eSIM, Золотой',
#  'iPhone 14 Pro 256Gb, Dual eSIM, Фиолетовый',
#  'iPhone 14 Pro 256Gb, Dual nano-SIM, Silver',
#  'iPhone 14 Pro 256Gb, Dual nano-SIM, Space Black',
#  'iPhone 14 Pro 256Gb, Dual nano-SIM, Золотой',
#  'iPhone 14 Pro 256Gb, Dual nano-SIM, Фиолетовый',
#  'iPhone 14 Pro 256Gb, nano-Sim+eSIM, Silver',
#  'iPhone 14 Pro 256Gb, nano-Sim+eSIM, Space Black',
#  'iPhone 14 Pro 256Gb, nano-Sim+eSIM, Золотой',
#  'iPhone 14 Pro 256Gb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 14 Pro 512Gb, Dual eSIM, Deep Purple',
#  'iPhone 14 Pro 512Gb, Dual eSIM, Silver',
#  'iPhone 14 Pro 512Gb, Dual eSIM, Золотой',
#  'iPhone 14 Pro 512Gb, Dual eSIM, Черный',
#  'iPhone 14 Pro 512Gb, Dual nano-SIM, Deep Purple',
#  'iPhone 14 Pro 512Gb, Dual nano-SIM, Silver',
#  'iPhone 14 Pro 512Gb, Dual nano-SIM, Золотой',
#  'iPhone 14 Pro 512Gb, Dual nano-SIM, Черный',
#  'iPhone 14 Pro 512Gb, nano-Sim+eSIM, Deep Purple',
#  'iPhone 14 Pro 512Gb, nano-Sim+eSIM, Silver',
#  'iPhone 14 Pro 512Gb, nano-Sim+eSIM, Золотой',
#  'iPhone 14 Pro 512Gb, nano-Sim+eSIM, Черный',
#  'iPhone 14 Pro Max 128Gb, Dual eSIM, Deep Purple',
#  'iPhone 14 Pro Max 128Gb, Dual eSIM, Silver',
#  'iPhone 14 Pro Max 128Gb, Dual eSIM, Space Black',
#  'iPhone 14 Pro Max 128Gb, Dual eSIM, Золотой',
#  'iPhone 14 Pro Max 128Gb, Dual nano-SIM, Deep Purple',
#  'iPhone 14 Pro Max 128Gb, Dual nano-SIM, Silver',
#  'iPhone 14 Pro Max 128Gb, Dual nano-SIM, Space Black',
#  'iPhone 14 Pro Max 128Gb, Dual nano-SIM, Золотой',
#  'iPhone 14 Pro Max 128Gb, nano-Sim+eSIM, Deep Purple',
#  'iPhone 14 Pro Max 128Gb, nano-Sim+eSIM, Silver',
#  'iPhone 14 Pro Max 128Gb, nano-Sim+eSIM, Space Black',
#  'iPhone 14 Pro Max 128Gb, nano-Sim+eSIM, Золотой',
#  'iPhone 14 Pro Max 1Tb, Dual eSIM, Gold',
#  'iPhone 14 Pro Max 1Tb, Dual eSIM, Silver',
#  'iPhone 14 Pro Max 1Tb, Dual eSIM, Space Black',
#  'iPhone 14 Pro Max 1Tb, Dual eSIM, Фиолетовый',
#  'iPhone 14 Pro Max 1Tb, Dual nano-SIM, Gold',
#  'iPhone 14 Pro Max 1Tb, Dual nano-SIM, Silver',
#  'iPhone 14 Pro Max 1Tb, Dual nano-SIM, Space Black',
#  'iPhone 14 Pro Max 1Tb, Dual nano-SIM, Фиолетовый',
#  'iPhone 14 Pro Max 1Tb, nano-Sim+eSIM, Gold',
#  'iPhone 14 Pro Max 1Tb, nano-Sim+eSIM, Silver',
#  'iPhone 14 Pro Max 1Tb, nano-Sim+eSIM, Space Black',
#  'iPhone 14 Pro Max 1Tb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 14 Pro Max 256Gb, Dual eSIM, Silver',
#  'iPhone 14 Pro Max 256Gb, Dual eSIM, Space Black',
#  'iPhone 14 Pro Max 256Gb, Dual eSIM, Золотой',
#  'iPhone 14 Pro Max 256Gb, Dual eSIM, Фиолетовый',
#  'iPhone 14 Pro Max 256Gb, Dual nano-SIM, Silver',
#  'iPhone 14 Pro Max 256Gb, Dual nano-SIM, Space Black',
#  'iPhone 14 Pro Max 256Gb, Dual nano-SIM, Золотой',
#  'iPhone 14 Pro Max 256Gb, Dual nano-SIM, Фиолетовый',
#  'iPhone 14 Pro Max 256Gb, nano-Sim+eSIM, Silver',
#  'iPhone 14 Pro Max 256Gb, nano-Sim+eSIM, Space Black',
#  'iPhone 14 Pro Max 256Gb, nano-Sim+eSIM, Золотой',
#  'iPhone 14 Pro Max 256Gb, nano-Sim+eSIM, Фиолетовый',
#  'iPhone 14 Pro Max 512Gb, Dual eSIM, Deep Purple',
#  'iPhone 14 Pro Max 512Gb, Dual eSIM, Silver',
#  'iPhone 14 Pro Max 512Gb, Dual eSIM, Золотой',
#  'iPhone 14 Pro Max 512Gb, Dual eSIM, Черный',
#  'iPhone 14 Pro Max 512Gb, Dual nano-SIM, Deep Purple',
#  'iPhone 14 Pro Max 512Gb, Dual nano-SIM, Silver',
#  'iPhone 14 Pro Max 512Gb, Dual nano-SIM, Золотой',
#  'iPhone 14 Pro Max 512Gb, Dual nano-SIM, Черный',
#  'iPhone 14 Pro Max 512Gb, nano-Sim+eSIM, Deep Purple',
#  'iPhone 14 Pro Max 512Gb, nano-Sim+eSIM, Silver',
#  'iPhone 14 Pro Max 512Gb, nano-Sim+eSIM, Золотой',
#  'iPhone 14 Pro Max 512Gb, nano-Sim+eSIM, Черный',
#  'iPhone 15 128Gb, Dual eSIM, Black',
#  'iPhone 15 128Gb, Dual eSIM, Blue',
#  'iPhone 15 128Gb, Dual eSIM, Pink',
#  'iPhone 15 128Gb, Dual eSIM, Желтый',
#  'iPhone 15 128Gb, Dual eSIM, Зеленый',
#  'iPhone 15 128Gb, Dual nano-SIM, Black',
#  'iPhone 15 128Gb, Dual nano-SIM, Blue',
#  'iPhone 15 128Gb, Dual nano-SIM, Pink',
#  'iPhone 15 128Gb, Dual nano-SIM, Желтый',
#  'iPhone 15 128Gb, Dual nano-SIM, Зеленый',
#  'iPhone 15 128Gb, nano-Sim+eSIM, Black',
#  'iPhone 15 128Gb, nano-Sim+eSIM, Blue',
#  'iPhone 15 128Gb, nano-Sim+eSIM, Pink',
#  'iPhone 15 128Gb, nano-Sim+eSIM, Желтый',
#  'iPhone 15 128Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 15 256Gb, Dual eSIM, Blue',
#  'iPhone 15 256Gb, Dual eSIM, Green',
#  'iPhone 15 256Gb, Dual eSIM, Yellow',
#  'iPhone 15 256Gb, Dual eSIM, Розовый',
#  'iPhone 15 256Gb, Dual eSIM, Черный',
#  'iPhone 15 256Gb, Dual nano-SIM, Blue',
#  'iPhone 15 256Gb, Dual nano-SIM, Green',
#  'iPhone 15 256Gb, Dual nano-SIM, Yellow',
#  'iPhone 15 256Gb, Dual nano-SIM, Розовый',
#  'iPhone 15 256Gb, Dual nano-SIM, Черный',
#  'iPhone 15 256Gb, nano-Sim+eSIM, Blue',
#  'iPhone 15 256Gb, nano-Sim+eSIM, Green',
#  'iPhone 15 256Gb, nano-Sim+eSIM, Yellow',
#  'iPhone 15 256Gb, nano-Sim+eSIM, Розовый',
#  'iPhone 15 256Gb, nano-Sim+eSIM, Черный',
#  'iPhone 15 512Gb, Dual eSIM, Blue',
#  'iPhone 15 512Gb, Dual eSIM, Yellow',
#  'iPhone 15 512Gb, Dual eSIM, Зеленый',
#  'iPhone 15 512Gb, Dual eSIM, Розовый',
#  'iPhone 15 512Gb, Dual eSIM, Черный',
#  'iPhone 15 512Gb, Dual nano-SIM, Blue',
#  'iPhone 15 512Gb, Dual nano-SIM, Yellow',
#  'iPhone 15 512Gb, Dual nano-SIM, Зеленый',
#  'iPhone 15 512Gb, Dual nano-SIM, Розовый',
#  'iPhone 15 512Gb, Dual nano-SIM, Черный',
#  'iPhone 15 512Gb, nano-Sim+eSIM, Blue',
#  'iPhone 15 512Gb, nano-Sim+eSIM, Yellow',
#  'iPhone 15 512Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 15 512Gb, nano-Sim+eSIM, Розовый',
#  'iPhone 15 512Gb, nano-Sim+eSIM, Черный',
#  'iPhone 15 Plus 128Gb, Dual eSIM, Black',
#  'iPhone 15 Plus 128Gb, Dual eSIM, Green',
#  'iPhone 15 Plus 128Gb, Dual eSIM, Pink',
#  'iPhone 15 Plus 128Gb, Dual eSIM, Yellow',
#  'iPhone 15 Plus 128Gb, Dual eSIM, Синий',
#  'iPhone 15 Plus 128Gb, Dual nano-SIM, Black',
#  'iPhone 15 Plus 128Gb, Dual nano-SIM, Green',
#  'iPhone 15 Plus 128Gb, Dual nano-SIM, Pink',
#  'iPhone 15 Plus 128Gb, Dual nano-SIM, Yellow',
#  'iPhone 15 Plus 128Gb, Dual nano-SIM, Синий',
#  'iPhone 15 Plus 128Gb, nano-Sim+eSIM, Black',
#  'iPhone 15 Plus 128Gb, nano-Sim+eSIM, Green',
#  'iPhone 15 Plus 128Gb, nano-Sim+eSIM, Pink',
#  'iPhone 15 Plus 128Gb, nano-Sim+eSIM, Yellow',
#  'iPhone 15 Plus 128Gb, nano-Sim+eSIM, Синий',
#  'iPhone 15 Plus 256Gb, Dual eSIM, Blue',
#  'iPhone 15 Plus 256Gb, Dual eSIM, Green',
#  'iPhone 15 Plus 256Gb, Dual eSIM, Pink',
#  'iPhone 15 Plus 256Gb, Dual eSIM, Yellow',
#  'iPhone 15 Plus 256Gb, Dual eSIM, Черный',
#  'iPhone 15 Plus 256Gb, Dual nano-SIM, Blue',
#  'iPhone 15 Plus 256Gb, Dual nano-SIM, Green',
#  'iPhone 15 Plus 256Gb, Dual nano-SIM, Pink',
#  'iPhone 15 Plus 256Gb, Dual nano-SIM, Yellow',
#  'iPhone 15 Plus 256Gb, Dual nano-SIM, Черный',
#  'iPhone 15 Plus 256Gb, nano-Sim+eSIM, Blue',
#  'iPhone 15 Plus 256Gb, nano-Sim+eSIM, Green',
#  'iPhone 15 Plus 256Gb, nano-Sim+eSIM, Pink',
#  'iPhone 15 Plus 256Gb, nano-Sim+eSIM, Yellow',
#  'iPhone 15 Plus 256Gb, nano-Sim+eSIM, Черный',
#  'iPhone 15 Plus 512Gb, Dual eSIM, Blue',
#  'iPhone 15 Plus 512Gb, Dual eSIM, Yellow',
#  'iPhone 15 Plus 512Gb, Dual eSIM, Зеленый',
#  'iPhone 15 Plus 512Gb, Dual eSIM, Розовый',
#  'iPhone 15 Plus 512Gb, Dual eSIM, Черный',
#  'iPhone 15 Plus 512Gb, Dual nano-SIM, Blue',
#  'iPhone 15 Plus 512Gb, Dual nano-SIM, Yellow',
#  'iPhone 15 Plus 512Gb, Dual nano-SIM, Зеленый',
#  'iPhone 15 Plus 512Gb, Dual nano-SIM, Розовый',
#  'iPhone 15 Plus 512Gb, Dual nano-SIM, Черный',
#  'iPhone 15 Plus 512Gb, nano-Sim+eSIM, Blue',
#  'iPhone 15 Plus 512Gb, nano-Sim+eSIM, Yellow',
#  'iPhone 15 Plus 512Gb, nano-Sim+eSIM, Зеленый',
#  'iPhone 15 Plus 512Gb, nano-Sim+eSIM, Розовый',
#  'iPhone 15 Plus 512Gb, nano-Sim+eSIM, Черный',
#  'iPhone 15 Pro 128Gb, Dual eSIM, Black Titanium',
#  'iPhone 15 Pro 128Gb, Dual eSIM, Blue Titanium',
#  'iPhone 15 Pro 128Gb, Dual eSIM, Natural Titanium',
#  'iPhone 15 Pro 128Gb, Dual eSIM, Белый',
#  'iPhone 15 Pro 128Gb, Dual nano-SIM, Black Titanium',
#  'iPhone 15 Pro 128Gb, Dual nano-SIM, Blue Titanium',
#  'iPhone 15 Pro 128Gb, Dual nano-SIM, Natural Titanium',
#  'iPhone 15 Pro 128Gb, Dual nano-SIM, Белый',
#  'iPhone 15 Pro 128Gb, nano-Sim+eSIM, Black Titanium',
#  'iPhone 15 Pro 128Gb, nano-Sim+eSIM, Blue Titanium',
#  'iPhone 15 Pro 128Gb, nano-Sim+eSIM, Natural Titanium',
#  'iPhone 15 Pro 128Gb, nano-Sim+eSIM, Белый',
#  'iPhone 15 Pro 1Tb, Dual eSIM, Black Titanium',
#  'iPhone 15 Pro 1Tb, Dual eSIM, Blue Titanium',
#  'iPhone 15 Pro 1Tb, Dual eSIM, Natural Titanium',
#  'iPhone 15 Pro 1Tb, Dual eSIM, White Titanium',
#  'iPhone 15 Pro 1Tb, Dual nano-SIM, Black Titanium',
#  'iPhone 15 Pro 1Tb, Dual nano-SIM, Blue Titanium',
#  'iPhone 15 Pro 1Tb, Dual nano-SIM, Natural Titanium',
#  'iPhone 15 Pro 1Tb, Dual nano-SIM, White Titanium',
#  'iPhone 15 Pro 1Tb, nano-Sim+eSIM, Black Titanium',
#  'iPhone 15 Pro 1Tb, nano-Sim+eSIM, Blue Titanium',
#  'iPhone 15 Pro 1Tb, nano-Sim+eSIM, Natural Titanium',
#  'iPhone 15 Pro 1Tb, nano-Sim+eSIM, White Titanium',
#  'iPhone 15 Pro 256Gb, Dual eSIM, Blue Titanium',
#  'iPhone 15 Pro 256Gb, Dual eSIM, Белый',
#  'iPhone 15 Pro 256Gb, Dual eSIM, Титан',
#  'iPhone 15 Pro 256Gb, Dual eSIM, Черный',
#  'iPhone 15 Pro 256Gb, Dual nano-SIM, Blue Titanium',
#  'iPhone 15 Pro 256Gb, Dual nano-SIM, Белый',
#  'iPhone 15 Pro 256Gb, Dual nano-SIM, Титан',
#  'iPhone 15 Pro 256Gb, Dual nano-SIM, Черный',
#  'iPhone 15 Pro 256Gb, nano-Sim+eSIM, Blue Titanium',
#  'iPhone 15 Pro 256Gb, nano-Sim+eSIM, Белый',
#  'iPhone 15 Pro 256Gb, nano-Sim+eSIM, Титан',
#  'iPhone 15 Pro 256Gb, nano-Sim+eSIM, Черный',
#  'iPhone 15 Pro 512Gb, Dual eSIM, White Titanium',
#  'iPhone 15 Pro 512Gb, Dual eSIM, Синий',
#  'iPhone 15 Pro 512Gb, Dual eSIM, Титан',
#  'iPhone 15 Pro 512Gb, Dual eSIM, Черный',
#  'iPhone 15 Pro 512Gb, Dual nano-SIM, White Titanium',
#  'iPhone 15 Pro 512Gb, Dual nano-SIM, Синий',
#  'iPhone 15 Pro 512Gb, Dual nano-SIM, Титан',
#  'iPhone 15 Pro 512Gb, Dual nano-SIM, Черный',
#  'iPhone 15 Pro 512Gb, nano-Sim+eSIM, White Titanium',
#  'iPhone 15 Pro 512Gb, nano-Sim+eSIM, Синий',
#  'iPhone 15 Pro 512Gb, nano-Sim+eSIM, Титан',
#  'iPhone 15 Pro 512Gb, nano-Sim+eSIM, Черный',
#  'iPhone 15 Pro Max 1Tb, Dual eSIM, Black Titanium',
#  'iPhone 15 Pro Max 1Tb, Dual eSIM, Blue Titanium',
#  'iPhone 15 Pro Max 1Tb, Dual eSIM, Natural Titanium',
#  'iPhone 15 Pro Max 1Tb, Dual eSIM, White Titanium',
#  'iPhone 15 Pro Max 1Tb, Dual nano-SIM, Black Titanium',
#  'iPhone 15 Pro Max 1Tb, Dual nano-SIM, Blue Titanium',
#  'iPhone 15 Pro Max 1Tb, Dual nano-SIM, Natural Titanium',
#  'iPhone 15 Pro Max 1Tb, Dual nano-SIM, White Titanium',
#  'iPhone 15 Pro Max 1Tb, nano-Sim+eSIM, Black Titanium',
#  'iPhone 15 Pro Max 1Tb, nano-Sim+eSIM, Blue Titanium',
#  'iPhone 15 Pro Max 1Tb, nano-Sim+eSIM, Natural Titanium',
#  'iPhone 15 Pro Max 1Tb, nano-Sim+eSIM, White Titanium',
#  'iPhone 15 Pro Max 256Gb, Dual eSIM, Белый',
#  'iPhone 15 Pro Max 256Gb, Dual eSIM, Синий',
#  'iPhone 15 Pro Max 256Gb, Dual eSIM, Титан',
#  'iPhone 15 Pro Max 256Gb, Dual eSIM, Черный',
#  'iPhone 15 Pro Max 256Gb, Dual nano-SIM, Белый',
#  'iPhone 15 Pro Max 256Gb, Dual nano-SIM, Синий',
#  'iPhone 15 Pro Max 256Gb, Dual nano-SIM, Титан',
#  'iPhone 15 Pro Max 256Gb, Dual nano-SIM, Черный',
#  'iPhone 15 Pro Max 256Gb, nano-Sim+eSIM, Белый',
#  'iPhone 15 Pro Max 256Gb, nano-Sim+eSIM, Blue Titanium',
#  'iPhone 15 Pro Max 256Gb, nano-Sim+eSIM, Титан',
#  'iPhone 15 Pro Max 256Gb, nano-Sim+eSIM, Черный',
#  'iPhone 15 Pro Max 512Gb, Dual eSIM, Белый',
#  'iPhone 15 Pro Max 512Gb, Dual eSIM, Синий',
#  'iPhone 15 Pro Max 512Gb, Dual eSIM, Титан',
#  'iPhone 15 Pro Max 512Gb, Dual eSIM, Черный',
#  'iPhone 15 Pro Max 512Gb, Dual nano-SIM, Белый',
#  'iPhone 15 Pro Max 512Gb, Dual nano-SIM, Синий',
#  'iPhone 15 Pro Max 512Gb, Dual nano-SIM, Титан',
#  'iPhone 15 Pro Max 512Gb, Dual nano-SIM, Черный',
#  'iPhone 15 Pro Max 512Gb, nano-Sim+eSIM, Белый',
#  'iPhone 15 Pro Max 512Gb, nano-Sim+eSIM, Синий',
#  'iPhone 15 Pro Max 512Gb, nano-Sim+eSIM, Титан',
#  'iPhone 15 Pro Max 512Gb, nano-Sim+eSIM, Черный',
#  'iPhone 6 128Gb, nano-Sim, Space Gray',
#  'iPhone 6 16Gb, nano-Sim, Silver',
#  'iPhone 6s 16Gb, nano-Sim, Silver',
#  'iPhone 6s 16Gb, nano-Sim, Space Gray',
#  'iPhone 6s 64Gb, nano-Sim, Gold',
#  'iPhone 7 128Gb, nano-Sim, Gold',
#  'iPhone 7 128Gb, nano-Sim, Rose Gold',
#  'iPhone 7 32Gb, nano-Sim, Silver',
#  'iPhone 7 Plus 256Gb, nano-Sim, Gold',
#  'iPhone 7 Plus 32Gb, nano-Sim, (PRODUCT)RED',
#  'iPhone 7 Plus 32Gb, nano-Sim, Black',
#  'iPhone 8 256Gb, nano-Sim, Space Gray',
#  'iPhone 8 64Gb, nano-Sim, Silver',
#  'iPhone 8 64Gb, nano-Sim, Серый космос',
#  'iPhone 8 Plus 256Gb, nano-Sim, (PRODUCT)RED',
#  'iPhone 8 Plus 256Gb, nano-Sim, Silver',
#  'iPhone SE (2020) 128Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone SE (2020) 128Gb, nano-Sim+eSIM, Black',
#  'iPhone SE (2020) 128Gb, nano-Sim+eSIM, White',
#  'iPhone SE (2020) 256Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone SE (2020) 256Gb, nano-Sim+eSIM, Black',
#  'iPhone SE (2020) 256Gb, nano-Sim+eSIM, White',
#  'iPhone SE (2020) 64Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone SE (2020) 64Gb, nano-Sim+eSIM, Black',
#  'iPhone SE (2020) 64Gb, nano-Sim+eSIM, White',
#  'iPhone SE (2022) 128Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone SE (2022) 128Gb, nano-Sim+eSIM, Midnight',
#  'iPhone SE (2022) 128Gb, nano-Sim+eSIM, Starlight',
#  'iPhone SE (2022) 256Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone SE (2022) 256Gb, nano-Sim+eSIM, Midnight',
#  'iPhone SE (2022) 256Gb, nano-Sim+eSIM, Starlight',
#  'iPhone SE (2022) 64Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone SE (2022) 64Gb, nano-Sim+eSIM, Midnight',
#  'iPhone SE (2022) 64Gb, nano-Sim+eSIM, Starlight',
#  'iPhone X 256Gb, nano-Sim, Серебристый',
#  'iPhone X 256Gb, nano-Sim, Серый космос',
#  'iPhone X 64Gb, nano-Sim, Silver',
#  'iPhone X 64Gb, nano-Sim, Space Gray',
#  'iPhone Xr 128Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone Xr 128Gb, nano-Sim+eSIM, Blue',
#  'iPhone Xr 128Gb, nano-Sim+eSIM, Coral',
#  'iPhone Xr 128Gb, nano-Sim+eSIM, White',
#  'iPhone Xr 128Gb, nano-Sim+eSIM, Yellow',
#  'iPhone Xr 128Gb, nano-Sim+eSIM, Черный',
#  'iPhone Xr 256Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone Xr 256Gb, nano-Sim+eSIM, Black',
#  'iPhone Xr 256Gb, nano-Sim+eSIM, Blue',
#  'iPhone Xr 256Gb, nano-Sim+eSIM, Coral',
#  'iPhone Xr 256Gb, nano-Sim+eSIM, Yellow',
#  'iPhone Xr 256Gb, nano-Sim+eSIM, Белый',
#  'iPhone Xr 64Gb, nano-Sim+eSIM, (PRODUCT)RED',
#  'iPhone Xr 64Gb, nano-Sim+eSIM, Blue',
#  'iPhone Xr 64Gb, nano-Sim+eSIM, Coral',
#  'iPhone Xr 64Gb, nano-Sim+eSIM, Yellow',
#  'iPhone Xr 64Gb, nano-Sim+eSIM, Белый',
#  'iPhone Xr 64Gb, nano-Sim+eSIM, Черный',
#  'iPhone Xs 256Gb, nano-Sim+eSIM, Золотой',
#  'iPhone Xs 256Gb, nano-Sim+eSIM, Серебристый',
#  'iPhone Xs 256Gb, nano-Sim+eSIM, Серый космос',
#  'iPhone Xs 512Gb, nano-Sim+eSIM, Gold',
#  'iPhone Xs 512Gb, nano-Sim+eSIM, Silver',
#  'iPhone Xs 512Gb, nano-Sim+eSIM, Space Gray',
#  'iPhone Xs 64Gb, nano-Sim+eSIM, Gold',
#  'iPhone Xs 64Gb, nano-Sim+eSIM, Silver',
#  'iPhone Xs 64Gb, nano-Sim+eSIM, Space Gray',
#  'iPhone Xs Max 256Gb, nano-Sim+eSIM, Silver',
#  'iPhone Xs Max 256Gb, nano-Sim+eSIM, Золотой',
#  'iPhone Xs Max 256Gb, nano-Sim+eSIM, Серый космос',
#  'iPhone Xs Max 512Gb, nano-Sim+eSIM, Gold',
#  'iPhone Xs Max 512Gb, nano-Sim+eSIM, Silver',
#  'iPhone Xs Max 512Gb, nano-Sim+eSIM, Space Gray',
#  'iPhone Xs Max 64Gb, nano-Sim+eSIM, Gold',
#  'iPhone Xs Max 64Gb, nano-Sim+eSIM, Silver',
#  'iPhone Xs Max 64Gb, nano-Sim+eSIM, Space Gray',
#  'Iphone 12 128Gb, Dual nano-SIM, Purple',
#  'Iphone 12 256Gb, Dual nano-SIM, Black',
#  'Iphone 13 128Gb, Dual eSIM, Blue',
#  'Iphone 13 128Gb, Dual eSIM, Green',
#  'Iphone 13 128Gb, Dual eSIM, Midnight',
#  'Iphone 13 128Gb, Dual eSIM, Pink',
#  'Iphone 13 128Gb, Dual eSIM, Starlight',
#  'Iphone 13 256Gb, Dual eSIM, Blue',
#  'Iphone 13 256Gb, Dual eSIM, Green',
#  'Iphone 13 256Gb, Dual eSIM, Midnight',
#  'Iphone 13 256Gb, Dual eSIM, Pink',
#  'Iphone 13 256Gb, Dual eSIM, Starlight',
#  'Iphone 14 Pro 128Gb, nano-Sim+eSIM,, White',
#  'Iphone 14 Pro 1Tb, Dual eSIM, White',
#  'Iphone 14 Pro Max 128Gb, Dual eSIM, White',
#  'Iphone 14 Pro Max 1Tb, nano-Sim+eSIM,, White',
#  'Iphone 7 256Gb, nano-Sim, Silver',
#  'Iphone 7 32Gb, nano-Sim, Gold',
#  'Iphone 7 32Gb, nano-Sim, Rose Gold',
#  'Iphone 7 Plus 128Gb, nano-Sim, (PRODUCT)RED',
#  'Iphone 7 Plus 32Gb, nano-Sim, Silver',
#  'Iphone 8 Plus 256Gb, nano-Sim, Space Gray',
#  'Iphone 8 Plus 64Gb, nano-Sim, Silver',
#  'Iphone 8 Plus 64Gb, nano-Sim, Space Gray']

# %%
df_thresh = df_offers[df_offers.cosine_sims_1 >= 0.9]
df_thresh
# Out:
#                                                   name  model_id    offer_id  \
# 0    Смартфон Apple iPhone 15 Pro Max 512GB (MU7F3,...         0  1879787949
# 1    Смартфон Apple iPhone 14 Pro 512GB MQ213LL/A g...         0  1879786672
# 2    Смартфон Apple iPhone 15 Plus 128GB eSim (Розо...         0  1878037377
# 4                  Смартфон Apple iPhone 14 256 ГБ Red         0  1878184508
# 6    Смартфон Apple iPhone 15 Pro 128GB (MTQ53ZA/A,...         0  1879788196
# ..                                                 ...       ...         ...
# 232  Смартфон Apple iPhone 15 Pro 256GB TITANIUM (M...         0  1875670866
# 233  Смартфон Apple A2403 iPhone 12 128Gb 4Gb фиоле...         0  1878800988
# 238  Apple iPhone 11 Pro Max 512Gb Space Gray (Серы...         0  1878778855
# 243  Смартфон Apple iPhone 14 Pro 256GB Global (256...         0  1878794631
# 244  Смартфон Apple A2403 iPhone 12 128Gb 4Gb белый...         0  1878800745
#
#      modelized_by_barcode       category_name  category_id     price  \
# 0                     NaN  мобильные телефоны         2801  175760.0
# 1                     NaN  мобильные телефоны         2801  166572.0
# 2                     NaN  мобильные телефоны         2801   80480.0
# 4                     NaN  мобильные телефоны         2801   72190.0
# 6                     NaN  мобильные телефоны         2801  120999.0
# ..                    ...                 ...          ...       ...
# 232                   NaN  мобильные телефоны         2801  138197.0
# 233                   NaN  мобильные телефоны         2801   61360.0
# 238                   NaN  мобильные телефоны         2801   69908.0
# 243                   NaN  мобильные телефоны         2801   95990.0
# 244                   NaN  мобильные телефоны         2801   61360.0
#
#                                                  attrs  \
# 0    [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 1    [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 2    [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 4    [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 6    [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# ..                                                 ...
# 232  [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 233  [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 238  [{'id': 14518, 'type': 'b', 'value': 1.0}, {'i...
# 243  [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
# 244  [{'id': 3, 'type': 'e', 'value': 676.0}, {'id'...
#
#                                            description  \
# 0                                        blue titanium
# 1                         gold, no SIM, dual eSIM only
# 2                                                  NaN
# 4    Диагональ экрана: 6,1" Тип экрана: Super Retin...
# 6    (MTQ53ZA/A, MV923CH/A) White Titanium (A3104),...
# ..                                                 ...
# 232                                                NaN
# 233  Смартфон Apple A2403 iPhone 12 128Gb 4Gb фиоле...
# 238  Оригинальный Apple iPhone 11 Pro Max 512Gb Spa...
# 243  Фирменный iPhone 14 Pro в состоянии: б/у. Полн...
# 244  Смартфон Apple A2403 iPhone 12 128Gb 4Gb белый...
#
#                                      external_category  ... cosine_sims_1  \
# 0                 Техника APPLE :: iPhone :: iPhone 15  ...       0.95650
# 1                 Техника APPLE :: iPhone :: iPhone 14  ...       0.95109
# 2                                       iPhone 15 Plus  ...       0.95451
# 4    Смартфоны и планшеты :: Смартфоны :: iPhone ::...  ...       0.96965
# 6                 Техника APPLE :: iPhone :: iPhone 15  ...       0.92619
# ..                                                 ...  ...           ...
# 232          Аудио/видео техника :: Мобильные телефоны  ...       0.91942
# 233         Смартфоны, планшеты и гаджеты :: Смартфоны  ...       0.95456
# 238                                              Apple  ...       0.98277
# 243                                      iPhone 14 Pro  ...       0.94570
# 244         Смартфоны, планшеты и гаджеты :: Смартфоны  ...       0.93781
#
#     model_id_pred_2  cosine_sims_2  model_id_pred_3  cosine_sims_3  \
# 0         7883783.0        0.85082        7883779.0        0.74075
# 1         7883566.0        0.85605        7883562.0        0.75437
# 2         7883662.0        0.84234        7883673.0        0.83730
# 4         7883437.0        0.79708        7883431.0        0.76771
# 6         7883717.0        0.90982        7883709.0        0.74695
# ..              ...            ...              ...            ...
# 232       7883736.0        0.81229        7883732.0        0.80931
# 233       7924751.0        0.85032        7883245.0        0.74215
# 238       7883234.0        0.83184        7883228.0        0.70737
# 243       7883551.0        0.81652        7883547.0        0.78174
# 244       7883245.0        0.85067        7883237.0        0.83217
#
#      model_id_pred_4  cosine_sims_4  model_id_pred_5  cosine_sims_5  \
# 0          7883789.0        0.67811        7883696.0        0.67342
# 1          7883559.0        0.74706        7883557.0        0.73512
# 2          7883664.0        0.80128        7883661.0        0.79209
# 4          7883444.0        0.65443        7883445.0        0.65364
# 6          7883711.0        0.70907        7883715.0        0.69548
# ..               ...            ...              ...            ...
# 232        7883741.0        0.68518        7883644.0        0.63155
# 233        7883256.0        0.70775        7883269.0        0.70135
# 238        7883230.0        0.68807        7883860.0        0.68513
# 243        7883445.0        0.78128        7883553.0        0.71542
# 244        7883241.0        0.76494        7883242.0        0.74017
#
#      model_id_manual
# 0          7883787.0
# 1          7883558.0
# 2          7883663.0
# 4                0.0
# 6                NaN
# ..               ...
# 232              NaN
# 233              NaN
# 238              NaN
# 243              NaN
# 244              NaN
#
# [167 rows x 23 columns]

# %%
dict(df_thresh.iloc[0])
# Out:
# {'name': 'Смартфон Apple iPhone 15 Pro Max 512GB (MU7F3, MU6X3J/A) blue titanium',
#  'model_id': 0,
#  'offer_id': 1879787949,
#  'modelized_by_barcode': nan,
#  'category_name': 'мобильные телефоны',
#  'category_id': 2801,
#  'price': 175760.0,
#  'attrs': "[{'id': 3, 'type': 'e', 'value': 676.0}, {'id': 14522, 'type': 'b', 'value': 1.0}, {'id': 25586, 'type': 'e', 'value': 733.0}]",
#  'description': 'blue titanium',
#  'external_category': 'Техника APPLE :: iPhone :: iPhone 15',
#  'external_brand': 'Apple',
#  'external_type': 'Смартфон',
#  'model_id_pred_1': 7883787.0,
#  'cosine_sims_1': 0.9565,
#  'model_id_pred_2': 7883783.0,
#  'cosine_sims_2': 0.85082,
#  'model_id_pred_3': 7883779.0,
#  'cosine_sims_3': 0.74075,
#  'model_id_pred_4': 7883789.0,
#  'cosine_sims_4': 0.67811,
#  'model_id_pred_5': 7883696.0,
#  'cosine_sims_5': 0.67342,
#  'model_id_manual': 7883787.0}

# %%
# df_thresh.to_csv('/home/sondors/Documents/price/ColBERT/EVAL/740101_lr04_bsize230_offers_top_n_model_id_0_cos_>=08.csv', sep=';', index=False)

# %%
df1 = df_offers[df_offers.cosine_sims_1 < 0.8]
id_to_name = dict(zip(df_models['model_id'], df_models['full_name']))
for index,row in df1.iterrows():
    print(index)
    offer = row['name']
    print(offer)
    sim = row['cosine_sims_1']
    id_pred = row['model_id_pred_1']
    # id = row['model_id']
    # model = id_to_name[id]
    model_pred = id_to_name[id_pred]
    # print(f"\t{model} --> {model_pred} | {round(float(sim), 2)}")
    print(f"{model_pred} | {round(float(sim), 2)}")
    print("_"*60)
# Out:
# 5
# Смартфон Apple iPhone 12 A2403, 6.1" 1170x2532 OLED, Apple A14 Bionic, 4Gb RAM, 64Gb, 3G/4G/5G, NFC, Wi-Fi, BT, 2xCam, 2-Sim (nano SIM+eSIM), Lightning, iOS 14, черный (MGJ53HN/A)
# Apple iPhone 12 128Gb, nano-Sim+eSIM, Синий | 0.77
# ____________________________________________________________
# 19
# Смартфон Apple iPhone 15 Pro Max
# Apple iPhone 15 Pro Max 256Gb, nano-Sim+eSIM, Черный | 0.68
# ____________________________________________________________
# 28
# Трекер Apple AirTag MX532BE/A, белый
# Apple iPhone 15 Pro Max 256Gb, nano-Sim+eSIM, Белый | 0.6
# ____________________________________________________________
# 37
# Смартфон Apple iPhone 11 A2221, 6.1" 828x1792 IPS, Apple A13 Bionic, 128Gb, 3G/4G, NFC, Wi-Fi, BT, 2xCam, 2-Sim, Lightning, iOS 13, черный (MHDH3RM/A)
# Apple iPhone 11 64Gb, nano-Sim+eSIM, Черный | 0.78
# ____________________________________________________________
# 38
# Смартфон Apple iPhone 12, 6.1" 1170x2532 OLED, Apple A14 Bionic, 4Gb RAM, 64Gb, 3G/4G/5G, NFC, Wi-Fi, BT, 2xCam, 2-Sim (nano SIM+eSIM), Lightning, iOS 14, фиолетовый (MJNM3HN/A)
# Apple iPhone 12 256Gb, Dual nano-SIM, Зеленый | 0.76
# ____________________________________________________________
# 48
# Смартфон Apple iPhone 13 A2634, 6.1" 1170x2532 OLED, Apple A15 Bionic, 4Gb RAM, 128Gb, 3G/4G/5G, NFC, Wi-Fi, BT, 2xCam, 2-Nano-SIM, 3240 мА·ч, Lightning, iOS 15, белый (MLDV3CH/A)
# Apple iPhone 13 256Gb, nano-Sim+eSIM, Midnight | 0.65
# ____________________________________________________________
# 61
# Смартфон Apple
# Apple iPhone 14 256Gb, nano-Sim+eSIM, Blue | 0.53
# ____________________________________________________________
# 76
# Смартфон Apple iPhone 14 Pro Max A2893, 6.7" 2796x1290 OLED, Apple A16 Bionic, 1Tb, 3G/4G/5G, NFC, Wi-Fi, BT, 3xCam, 2-Sim (nano SIM+eSIM), Lightning, iOS 16, фиолетовый
# Apple iPhone 14 Pro Max 256Gb, Dual nano-SIM, Золотой | 0.67
# ____________________________________________________________
# 94
# Смартфон Apple iPhone XS 256GB Золотой "Хорошее состояние"
# Apple iPhone Xs 256Gb, nano-Sim+eSIM, Золотой | 0.8
# ____________________________________________________________
# 95
# Смартфон Apple iPhone 8 64GB Red "Хорошее состояние"
# Apple iPhone 8 64Gb, nano-Sim, Silver | 0.76
# ____________________________________________________________
# 137
# Смартфон Apple iPhone 11 A2221, 6.1" 828x1792 IPS, Apple A13 Bionic, 64Gb, 3G/4G, NFC, Wi-Fi, BT, 2xCam, 2-Sim, Lightning, iOS 13, черный (MHDA3VN/A)
# Apple iPhone 11 64Gb, nano-Sim+eSIM, Черный | 0.78
# ____________________________________________________________
# 143
# Смартфон Apple iPhone 8 128GB Silver "Хорошее состояние"
# Apple iPhone 14 128Gb, nano-Sim+eSIM, Silver | 0.65
# ____________________________________________________________
# 154
# Apple iPhone 11 128Gb Dual SIM Yellow (Желтый) на 2 SIM-карты
# Apple iPhone 15 128Gb, Dual nano-SIM, Желтый | 0.69
# ____________________________________________________________
# 176
# Apple iPhone 11 64Gb Dual SIM Yellow (Желтый) на 2 SIM-карты
# Apple iPhone 11 64Gb, Dual nano-SIM, Green | 0.71
# ____________________________________________________________
# 183
# Apple iPhone 11 Pro Max 256Gb Dual SIM Space Gray (Серый космос) A2220 на 2 СИМ-карты
# Apple iPhone 11 Pro Max 256Gb, nano-Sim+eSIM, Серый космос | 0.78
# ____________________________________________________________
# 188
# Смартфон Apple A2221 iPhone 11, 6.1" 828x1792 IPS, Apple A13 Bionic, 64Gb, 3G/4G/5G, NFC, Wi-Fi, BT, 2xCam, 2-Sim, Lightning, iOS 13, белый (MHDC3LZ/A)
# Apple iPhone 11 64Gb, nano-Sim+eSIM, Черный | 0.76
# ____________________________________________________________
# 200
# Apple iPhone 11 128Gb Dual SIM Purple (Фиолетовый) на 2 SIM-карты
# Apple iPhone 11 128Gb, nano-Sim+eSIM, Фиолетовый | 0.79
# ____________________________________________________________
# 201
# Apple iPhone 11 Pro 256Gb Dual SIM Space Gray (Серый космос) A2217 на 2 СИМ-карты
# Apple iPhone 11 Pro 256Gb, nano-Sim+eSIM, Серый космос | 0.75
# ____________________________________________________________
# 212
# Apple iPhone 11 128Gb Dual SIM Green (Зеленый) на 2 SIM-карты
# Apple iPhone 15 128Gb, Dual nano-SIM, Зеленый | 0.72
# ____________________________________________________________
# 215
# Apple iPhone 11 128Gb Dual SIM Red (Красный) на 2 SIM-карты
# Apple iPhone 11 128Gb, nano-Sim+eSIM, Красный | 0.77
# ____________________________________________________________
# 217
# Apple iPhone 11 64Gb Dual SIM Purple (Фиолетовый) на 2 SIM-карты
# Apple iPhone 11 64Gb, nano-Sim+eSIM, Фиолетовый | 0.8
# ____________________________________________________________
# 228
# Apple iPhone 11 256Gb Dual SIM White (Белый) на 2 SIM-карты
# Apple iPhone 11 64Gb, Dual nano-SIM, Белый | 0.77
# ____________________________________________________________
# 235
# Apple iPhone 11 256Gb Dual SIM Green (Зеленый) на 2 SIM-карты
# Apple iPhone 11 64Gb, Dual nano-SIM, Green | 0.75
# ____________________________________________________________
# 236
# Apple iPhone 11 256Gb Dual SIM Yellow (Желтый) на 2 SIM-карты
# Apple iPhone 11 256Gb, nano-Sim+eSIM, Yellow | 0.73
# ____________________________________________________________
# 239
# Apple iPhone 11 256Gb Dual SIM Black (Черный) на 2 SIM-карты
# Apple iPhone 11 256Gb, nano-Sim+eSIM, Черный | 0.77
# ____________________________________________________________
# 240
# Apple iPhone 11 256Gb Dual SIM Red (Красный) на 2 SIM-карты
# Apple iPhone 11 256Gb, nano-Sim+eSIM, (PRODUCT)RED | 0.78
# ____________________________________________________________
# 242
# Apple iPhone 11 Pro Max 64Gb Dual SIM Space Gray (Серый космос) A2220 на 2 СИМ-карты
# Apple iPhone 11 Pro Max 64Gb, nano-Sim+eSIM, Space Gray | 0.79
# ____________________________________________________________

# %%
df_models
# Out:
#      model_id  average_price                                         name  \
# 0     7883190        45490.0       iPhone 11 128Gb, Dual nano-SIM, Черный
# 1     7883191        35999.0        iPhone 11 128Gb, nano-Sim+eSIM, Green
# 2     7883192        53998.5        iPhone 11 128Gb, nano-Sim+eSIM, Белый
# 3     7883193        48490.0       iPhone 11 128Gb, nano-Sim+eSIM, Желтый
# 4     7883194        31990.0      iPhone 11 128Gb, nano-Sim+eSIM, Красный
# ..        ...            ...                                          ...
# 693   7924770        21034.0  Iphone 7 Plus 128Gb, nano-Sim, (PRODUCT)RED
# 694   7924771        16588.0         Iphone 7 Plus 32Gb, nano-Sim, Silver
# 695   7924772        30290.0    Iphone 8 Plus 256Gb, nano-Sim, Space Gray
# 696   7924773        20280.0         Iphone 8 Plus 64Gb, nano-Sim, Silver
# 697   7924774        19890.0     Iphone 8 Plus 64Gb, nano-Sim, Space Gray
#
#     brand_name                                          full_name  comment  \
# 0        Apple       Apple iPhone 11 128Gb, Dual nano-SIM, Черный      NaN
# 1        Apple        Apple iPhone 11 128Gb, nano-Sim+eSIM, Green      NaN
# 2        Apple        Apple iPhone 11 128Gb, nano-Sim+eSIM, Белый      NaN
# 3        Apple       Apple iPhone 11 128Gb, nano-Sim+eSIM, Желтый      NaN
# 4        Apple      Apple iPhone 11 128Gb, nano-Sim+eSIM, Красный      NaN
# ..         ...                                                ...      ...
# 693      Apple  Apple Iphone 7 Plus 128Gb, nano-Sim, (PRODUCT)RED      NaN
# 694      Apple         Apple Iphone 7 Plus 32Gb, nano-Sim, Silver      NaN
# 695      Apple    Apple Iphone 8 Plus 256Gb, nano-Sim, Space Gray      NaN
# 696      Apple         Apple Iphone 8 Plus 64Gb, nano-Sim, Silver      NaN
# 697      Apple     Apple Iphone 8 Plus 64Gb, nano-Sim, Space Gray      NaN
#
#           category_name  category_id
# 0    мобильные телефоны         2801
# 1    мобильные телефоны         2801
# 2    мобильные телефоны         2801
# 3    мобильные телефоны         2801
# 4    мобильные телефоны         2801
# ..                  ...          ...
# 693  мобильные телефоны         2801
# 694  мобильные телефоны         2801
# 695  мобильные телефоны         2801
# 696  мобильные телефоны         2801
# 697  мобильные телефоны         2801
#
# [698 rows x 8 columns]

# %%
"""
Случаи в данных с ошибками:

0) исключить из ручной проверки совпадающие top_1-top_5 с разметкой model_id. Если top_1 != model_id, ColBERT ошибся.
Пренебрегаем случаями когда разметка неправильная и среди top_1-top_5 находится этот неправильный model_id. Допустим что их количество мало.
5144478: Samsung Galaxy Tab S8
Samsung Планшет Samsung Galaxy Tab S8, 8 ГБ/128 ГБ, Wi-Fi + Cellular, со стилусом, графит (Global)
	5144478: Samsung Galaxy Tab S8 --> 28.97
	5144477: Samsung Galaxy Tab S8+ --> 24.97
	937550: Samsung Galaxy Tab S2 9.7 SM-T813 --> 24.0
	5144479: Samsung Galaxy Tab S8 Ultra --> 23.98
	816746: Samsung Galaxy Tab S2 9.7 SM-T810 --> 23.64

1) ColBERT находит среди top_1-top_5 правильный матч, а разметка model_id при этом не правильная.
Тогда пользователь руками вводит число от 1 до 5, записывается новый model_id 
Эта ошибка не должна учитываться в метрике accuracy, ее необходимо исключить из тестового датасета.
5144478: Samsung Galaxy Tab S9
Samsung Планшет Samsung Galaxy Tab S8, 8 ГБ/128 ГБ, Wi-Fi + Cellular, со стилусом, графит (Global)
	5144478: Samsung Galaxy Tab S8 --> 28.97
	5144477: Samsung Galaxy Tab S8+ --> 24.97
	937550: Samsung Galaxy Tab S2 9.7 SM-T813 --> 24.0
	5144479: Samsung Galaxy Tab S8 Ultra --> 23.98
	816746: Samsung Galaxy Tab S2 9.7 SM-T810 --> 23.64

2) среди top_1-top_5 нет правильного матча, разметка model_id правильная
5144478: Samsung Galaxy Tab S8
Samsung Планшет Samsung Galaxy Tab S8, 8 ГБ/128 ГБ, Wi-Fi + Cellular, со стилусом, графит (Global)
	5144478: Samsung Galaxy Tab S9 --> 28.97
	5144477: Samsung Galaxy Tab S8+ --> 24.97
	937550: Samsung Galaxy Tab S2 9.7 SM-T813 --> 24.0
	5144479: Samsung Galaxy Tab S8 Ultra --> 23.98
	816746: Samsung Galaxy Tab S2 9.7 SM-T810 --> 23.64

3) среди top_1-top_5 нет правильного матча, разметка model_id не правильная
Эта ошибка не должна учитываться в метрике accuracy, ее необходимо исключить из тестового датасета.
5144478: Samsung Galaxy Tab S9
Samsung Планшет Samsung Galaxy Tab S8, 8 ГБ/128 ГБ, Wi-Fi + Cellular, со стилусом, графит (Global)
	5144478: Samsung Galaxy Tab S10 --> 28.97
	5144477: Samsung Galaxy Tab S8+ --> 24.97
	937550: Samsung Galaxy Tab S2 9.7 SM-T813 --> 24.0
	5144479: Samsung Galaxy Tab S8 Ultra --> 23.98
	816746: Samsung Galaxy Tab S2 9.7 SM-T810 --> 23.64
"""

"""
Действия:
I) Заводим колонки model_id_correct, model_id_manual
II) Делаем прогон да/нет-кой на строках с top_1-top_5 != model_id, записываем в model_id_correct 0/1/2. 0-неправильно, 1-правильно, 2-хз
III) Для неправильной разметки переразмечаем см случай 1), если среди top_1-top_5 нет правильного матча см случай 3) ставим model_id_manual = 0
IV) Для правильной разметки см случай 2) не исключаем примеры, они должны участвовать в ошибке
"""
# Out:
# "\n- из 1000 шт да/нет-ки выделить случаи не правильной разметки и посчитать долю правильно предсказанных ColBERT'ом\n- остальные 2334шт выкинуть из val, посчитать метрики без этих примеров\n- разметить model_id=0 ColBERT'ом, кластеризовать, посмотреть, прокликать да/нет-кой\n- завести задачу для Гриши\n"

# %%
def exclude_from_df(df, col):
    return df[df['model_id'] != df[col]].reset_index(drop=True)

clms = ['model_id_pred_1','model_id_pred_2','model_id_pred_3', 'model_id_pred_4', 'model_id_pred_5']
df = df_offers.copy()
for i in range(len(clms)):
    df = exclude_from_df(df, clms[i])
# df.to_csv('/home/sondors/Documents/price/ColBERT/proverka/colbert-5387_offers_top_n_exclude_top5.csv', sep=';', index=False)
df
# Out:
#                                                    name  model_id    offer_id  \
# 0                 Мойка Ulgran Quartz Prima 780 Трюфель         0  1795220469
# 1                 Кухонная мойка GRANULA (6503, ЧЁРНЫЙ)         0  1795194407
# 2              Кухонная мойка GRANULA (4651, АЛЮМИНИУМ)         0  1795225034
# 3        Кухонная мойка GRANULA Standart (7601, ГРАФИТ)         0  1795186310
# 4                    Мойка Ulgran Quartz Nora 485 Бетон         0  1793872543
# ...                                                 ...       ...         ...
# 2813                Мойка кухонная Granfest VERTEX 680L         0  1793899310
# 2814                 Мойка кухонная Practik 760L, топаз         0  1784847807
# 2815  Мойка кухонная MIXLINE 532306, врезная, толщин...         0  1343434281
# 2816  Кухонная мойка и смеситель GreenStone GRS-04-3...         0  1452409439
# 2817  Кухонная мойка DrGans Лора 620 везувий 25020A0...         0  1768434516
#
#       modelized_by_barcode   category_name  category_id  model_id_pred_1  \
# 0                      NaN  кухонные мойки       740101          4312878
# 1                      NaN  кухонные мойки       740101          3601736
# 2                      NaN  кухонные мойки       740101          5143875
# 3                      NaN  кухонные мойки       740101          5143872
# 4                      NaN  кухонные мойки       740101          6300567
# ...                    ...             ...          ...              ...
# 2813                   NaN  кухонные мойки       740101          5143853
# 2814                   NaN  кухонные мойки       740101          1538824
# 2815                   NaN  кухонные мойки       740101          5769445
# 2816                   NaN  кухонные мойки       740101           593102
# 2817                   NaN  кухонные мойки       740101           728535
#
#       similarity_1  model_id_pred_2  similarity_2  ...  similarity_3  \
# 0            21.84          5143684         17.55  ...         15.93
# 1            26.16          5143885         21.33  ...         20.66
# 2            23.53           519494         21.06  ...         20.64
# 3            26.45          5143889         25.94  ...         23.45
# 4            27.52           942332         18.50  ...         17.98
# ...            ...              ...           ...  ...           ...
# 2813         27.05           518184         21.67  ...         21.67
# 2814         29.05           518163         25.47  ...         17.05
# 2815         24.50          6300473         24.28  ...         23.81
# 2816         24.06           591811         19.41  ...         19.11
# 2817         24.98          5143689         22.55  ...         21.78
#
#       model_id_pred_4  similarity_4  model_id_pred_5  similarity_5  \
# 0              620861         15.91           520026         15.81
# 1              591797         20.59          3601737         19.97
# 2             2110177         20.55          3601735         20.53
# 3             5143890         23.34           519494         18.94
# 4              543697         17.23          1055256         17.14
# ...               ...           ...              ...           ...
# 2813          5143854         17.58          5143846         15.95
# 2814           518749         13.42          2114251         13.22
# 2815          6300472         23.41          7794845         22.86
# 2816           591813         18.61           591812         17.94
# 2817           942333         21.72          5143707         21.70
#
#       cosine_sims1  cosine_sims2  cosine_sims3  cosine_sims4  cosine_sims5
# 0             0.82          0.47          0.51          0.51          0.40
# 1             0.89          0.65          0.60          0.68          0.57
# 2             0.80          0.67          0.57          0.31          0.40
# 3             0.87          0.84          0.61          0.57          0.67
# 4             0.93          0.52          0.59          0.44          0.57
# ...            ...           ...           ...           ...           ...
# 2813          0.86          0.55          0.69          0.53          0.42
# 2814          0.91          0.80          0.55          0.39          0.38
# 2815          0.83          0.77          0.81          0.80          0.76
# 2816          0.80          0.61          0.58          0.50          0.53
# 2817          0.84          0.67          0.63          0.65          0.63
#
# [2818 rows x 21 columns]

# %%
df[df.name == "Планшетный компьютер Apple iPad Pro 12.9-inch Wi-Fi + Cellular 512GB - Silver [MXF82RU/A] (2020)"]
# Out:
#                                                   name  model_id  \
# 751  Планшетный компьютер Apple iPad Pro 12.9-inch ...   4355166
#
#                              category_name  category_id  model_id_pred_1  \
# 751  планшетные компьютеры и мини-планшеты       510401          4070863
#
#      similarity_1  model_id_pred_2  similarity_2  model_id_pred_3  \
# 751         25.69          4355160         25.69          4070867
#
#      similarity_3  model_id_pred_4  similarity_4  model_id_pred_5  \
# 751         25.66          1465229         25.59          4800947
#
#      similarity_5
# 751         25.58

# %%
dict(df.iloc[390])
# Out:
# {'name': 'Планшет Apple 11-inch iPad Pro Wi-Fi + Cellular 256GB, Silver (MXE52RU/A)',
#  'model_id': 911280,
#  'category_name': 'планшетные компьютеры и мини-планшеты',
#  'category_id': 510401,
#  'model_id_pred_1': 4069038,
#  'similarity_1': 28.39,
#  'model_id_pred_2': 4800942,
#  'similarity_2': 28.08,
#  'model_id_pred_3': 4355157,
#  'similarity_3': 27.98,
#  'model_id_pred_4': 4800941,
#  'similarity_4': 24.56,
#  'model_id_pred_5': 5811841,
#  'similarity_5': 24.28}

# %%
for index, row in df[751:752].iterrows():
    model_gt = list(df_models[df_models.model_id == row['model_id']]['full_name'])[0]
    model_pred = list(df_models[df_models.model_id == row['model_id_pred_1']]['full_name'])[0]
    print(f"\n{model_gt}:\n{row['name']} --> {model_pred}\n")  
    model_pred = list(df_models[df_models.model_id == row['model_id_pred_2']]['full_name'])[0]
    print(f"\n{model_gt}:\n{row['name']} --> {model_pred}\n")  
    model_pred = list(df_models[df_models.model_id == row['model_id_pred_3']]['full_name'])[0]
    print(f"\n{model_gt}:\n{row['name']} --> {model_pred}\n")  
    model_pred = list(df_models[df_models.model_id == row['model_id_pred_4']]['full_name'])[0]
    print(f"\n{model_gt}:\n{row['name']} --> {model_pred}\n")
# Out:
# Apple iPad Pro 12.9 (2020) 512GB WiFi + Cellular:
# Планшетный компьютер Apple iPad Pro 12.9-inch Wi-Fi + Cellular 512GB - Silver [MXF82RU/A] (2020) --> Apple iPad Pro 12.9 (2018) 256Gb Wi-Fi
#
#
# Apple iPad Pro 12.9 (2020) 512GB WiFi + Cellular:
# Планшетный компьютер Apple iPad Pro 12.9-inch Wi-Fi + Cellular 512GB - Silver [MXF82RU/A] (2020) --> Apple iPad Pro 12.9 (2020) 128Gb Wi-Fi
#
#
# Apple iPad Pro 12.9 (2020) 512GB WiFi + Cellular:
# Планшетный компьютер Apple iPad Pro 12.9-inch Wi-Fi + Cellular 512GB - Silver [MXF82RU/A] (2020) --> Apple iPad Pro 12.9 (2018) 64Gb Wi-Fi
#
#
# Apple iPad Pro 12.9 (2020) 512GB WiFi + Cellular:
# Планшетный компьютер Apple iPad Pro 12.9-inch Wi-Fi + Cellular 512GB - Silver [MXF82RU/A] (2020) --> Apple iPad Pro 12.9 (2017) 64Gb Wi-Fi

# %%
dict(df.iloc[0])
# Out:
# {'name': 'Акустическая система HYUNDAI Колонка порт. H-PAC560 черный 10W 1.0 BT / 3.5Jack / USB 10м 3000mAh',
#  'model_id': 4570006,
#  'category_name': 'портативная акустика',
#  'category_id': 3904,
#  'model_id_pred_1': 4569993,
#  'similarity_1': 24.89,
#  'model_id_pred_2': 4569999,
#  'similarity_2': 24.86,
#  'model_id_pred_3': 4569990,
#  'similarity_3': 24.72,
#  'model_id_pred_4': 3709109,
#  'similarity_4': 24.7,
#  'model_id_pred_5': 4569996,
#  'similarity_5': 24.69}

# %%
df
# Out:
#                                                    name  model_id  \
# 0     Акустическая система HYUNDAI Колонка порт. H-P...   4570006
# 1                          Смарт-часы CANYON CNS-SW82BB   4565865
# 2     Гарнитура Мультимедийные стереонаушники с микр...   1001102
# 3                                        SVEN SV-015008   1426186
# 4     Гарнитура CANYON проводные наушники с микрофон...   4676812
# ...                                                 ...       ...
# 3329  Внутриканальные (вакуумные) беспроводные Focal...   1426118
# 3330  Bluetooth стерео-гарнитура Harper Наушники с м...   4049393
# 3331  Гарнитура GEMBIRD проводные наушники с микрофо...    742577
# 3332  2в1 Портативная акустика + внешний аккумулятор...   4851344
# 3333  Наушники с микрофоном (гарнитура) Harper Наушн...   4300119
#
#                                    category_name  category_id  \
# 0                           портативная акустика         3904
# 1                          смарт-часы и браслеты         2815
# 2     наушники, гарнитуры, наушники c микрофоном         2102
# 3     наушники, гарнитуры, наушники c микрофоном         2102
# 4     наушники, гарнитуры, наушники c микрофоном         2102
# ...                                          ...          ...
# 3329  наушники, гарнитуры, наушники c микрофоном         2102
# 3330  наушники, гарнитуры, наушники c микрофоном         2102
# 3331  наушники, гарнитуры, наушники c микрофоном         2102
# 3332                        портативная акустика         3904
# 3333  наушники, гарнитуры, наушники c микрофоном         2102
#
#       model_id_pred_1  similarity_1  model_id_pred_2  similarity_2  \
# 0             4569993         24.89          4569999         24.86
# 1             4178947         27.38          5151627         26.16
# 2             3621627         16.88          4636867         16.78
# 3             4455941         24.12          1034729         22.95
# 4              749928         21.75          2986233         21.64
# ...               ...           ...              ...           ...
# 3329          4455962         17.16           746174         16.80
# 3330          4455800         23.61          4533126         23.58
# 3331           742576         22.56          4049936         22.56
# 3332           300218         15.62           332059         15.11
# 3333          2083873         17.84          4049951         17.83
#
#       model_id_pred_3  similarity_3  model_id_pred_4  similarity_4  \
# 0             4569990         24.72          3709109         24.70
# 1             4178942         25.06          4178944         23.80
# 2             2050212         16.75          4735667         16.73
# 3             4770097         22.52          1040395         22.50
# 4             3537855         21.52           746343         21.48
# ...               ...           ...              ...           ...
# 3329          4677040         16.77          4300242         16.64
# 3330          4533125         23.53          4994477         23.52
# 3331           742571         22.48           742581         22.45
# 3332           290713         14.83           705129         14.81
# 3333          1676488         17.77          4735664         17.52
#
#       model_id_pred_5  similarity_5
# 0             4569996         24.69
# 1             5151628         23.55
# 2             1426187         16.70
# 3             2083909         22.47
# 4              933005         21.39
# ...               ...           ...
# 3329          4300243         16.61
# 3330           746520         23.52
# 3331           742579         22.41
# 3332           297140         14.73
# 3333          2083908         17.48
#
# [3334 rows x 14 columns]

# %%
pth_1000 = "/home/sondors/Documents/price/ColBERT/proverka/colbert-5387_offers_top_n_exclude_top5_yes_no_1000.csv"

df_1000 = pd.read_csv(pth_1000, sep=";")
df_1000 = df_1000[:1000]
df_1000
# Out:
#                                                   name  model_id  \
# 0    Акустическая система HYUNDAI Колонка порт. H-P...   4570006
# 1                         Смарт-часы CANYON CNS-SW82BB   4565865
# 2    Гарнитура Мультимедийные стереонаушники с микр...   1001102
# 3                                       SVEN SV-015008   1426186
# 4    Гарнитура CANYON проводные наушники с микрофон...   4676812
# ..                                                 ...       ...
# 995  Универсальная мобильная гарнитура JBL C50HI RE...   4455819
# 996  Планшетный компьютер Digma Планшет Citi 7591 3...   4273003
# 997  внутриканальные Наушники Xiaomi BHR5264GL, Mi ...   4455970
# 998  Портативная акустическая система Hyundai Колон...   4570004
# 999  Портативная акустическая система SVEN Колонка ...   1925445
#
#                                   category_name  category_id  model_id_pred_1  \
# 0                          портативная акустика         3904          4569993
# 1                         смарт-часы и браслеты         2815          4178947
# 2    наушники, гарнитуры, наушники c микрофоном         2102          3621627
# 3    наушники, гарнитуры, наушники c микрофоном         2102          4455941
# 4    наушники, гарнитуры, наушники c микрофоном         2102           749928
# ..                                          ...          ...              ...
# 995  наушники, гарнитуры, наушники c микрофоном         2102           746901
# 996       планшетные компьютеры и мини-планшеты       510401          3843911
# 997  наушники, гарнитуры, наушники c микрофоном         2102          5137672
# 998                        портативная акустика         3904          4569993
# 999                        портативная акустика         3904          4570127
#
#      similarity_1  model_id_pred_2  similarity_2  model_id_pred_3  \
# 0           24.89          4569999         24.86          4569990
# 1           27.38          5151627         26.16          4178942
# 2           16.88          4636867         16.78          2050212
# 3           24.12          1034729         22.95          4770097
# 4           21.75          2986233         21.64          3537855
# ..            ...              ...           ...              ...
# 995         15.19          4300186         15.00           616609
# 996         25.70          4273002         25.31          1950145
# 997         20.44          4677044         20.28          1041951
# 998         24.36          4569996         24.23          4569999
# 999         26.12          4298663         26.02          4247953
#
#      similarity_3  model_id_pred_4  similarity_4  model_id_pred_5  \
# 0           24.72          3709109         24.70          4569996
# 1           25.06          4178944         23.80          5151628
# 2           16.75          4735667         16.73          1426187
# 3           22.52          1040395         22.50          2083909
# 4           21.52           746343         21.48           933005
# ..            ...              ...           ...              ...
# 995         14.67           760225         14.57          4300180
# 996         25.25          4404425         25.22          2341722
# 997         20.22          5137673         19.95          4049806
# 998         24.23          3709109         24.17          4585106
# 999         26.00          4851880         25.98          4570124
#
#      similarity_5  model_id_correct
# 0           24.69               1.0
# 1           23.55               2.0
# 2           16.70               1.0
# 3           22.47               2.0
# 4           21.39               1.0
# ..            ...               ...
# 995         14.42               1.0
# 996         25.12               1.0
# 997         19.94               2.0
# 998         24.17               1.0
# 999         25.97               1.0
#
# [1000 rows x 15 columns]

# %%
df_1000_errors_2 = df_1000[df_1000.model_id_correct == 2.0]
df_1000_errors_2.to_csv('/home/sondors/Documents/price/ColBERT/proverka/colbert-5387_offers_top_n_exclude_top5_yes_no_1000_errors_2.csv', sep=';', index=False)

df_1000_errors_2
# Out:
#                                                   name  model_id  \
# 1                         Смарт-часы CANYON CNS-SW82BB   4565865
# 3                                       SVEN SV-015008   1426186
# 6                                  Наушники HP T1A67AA   4533500
# 8                       Наушники Skullcandy S2IVW-N740   4731816
# 19                   Портативный GPS-навигатор Navitel    930885
# ..                                                 ...       ...
# 898  Игровая гарнитура проводная Crown CMGH-3103 че...   4455769
# 921  Планшет DIGMA 1402D 10.1" 4/64GB Silver Wi-Fi+...   4557928
# 925  Смартфон Acer V360 Dual SIM Black Acer Смартфо...    325207
# 945                    Радиоприёмник Sangean Revery R4   4569805
# 997  внутриканальные Наушники Xiaomi BHR5264GL, Mi ...   4455970
#
#                                   category_name  category_id  model_id_pred_1  \
# 1                         смарт-часы и браслеты         2815          4178947
# 3    наушники, гарнитуры, наушники c микрофоном         2102          4455941
# 6    наушники, гарнитуры, наушники c микрофоном         2102          3367309
# 8    наушники, гарнитуры, наушники c микрофоном         2102           856843
# 19                               GPS-навигаторы       280801           145480
# ..                                          ...          ...              ...
# 898  наушники, гарнитуры, наушники c микрофоном         2102          4455770
# 921       планшетные компьютеры и мини-планшеты       510401          6177706
# 925                          мобильные телефоны         2801           190678
# 945  радиоприемники, радиобудильники, радиочасы         3903           594083
# 997  наушники, гарнитуры, наушники c микрофоном         2102          5137672
#
#      similarity_1  model_id_pred_2  similarity_2  model_id_pred_3  \
# 1           27.38          5151627         26.16          4178942
# 3           24.12          1034729         22.95          4770097
# 6           23.94          4049448         22.72           746528
# 8           26.08           856844         26.03          4090100
# 19          26.36           145477         26.23           145828
# ..            ...              ...           ...              ...
# 898         28.56          4533066         24.64          4533065
# 921         20.23           831852         20.20          1464879
# 925         23.36           818797         23.30           188050
# 945         23.64          4569804         21.84          4569801
# 997         20.44          4677044         20.28          1041951
#
#      similarity_3  model_id_pred_4  similarity_4  model_id_pred_5  \
# 1           25.06          4178944         23.80          5151628
# 3           22.52          1040395         22.50          2083909
# 6           22.41          4883259         21.34           742770
# 8           26.00          4090102         25.75          4090099
# 19          26.20           145829         26.14           930883
# ..            ...              ...           ...              ...
# 898         23.28          4533431         23.20          4533062
# 921         19.67           646909         19.50           944123
# 925         23.28           137982         23.22           938217
# 945         20.88           512753         20.58           871021
# 997         20.22          5137673         19.95          4049806
#
#      similarity_5  model_id_correct
# 1           23.55               2.0
# 3           22.47               2.0
# 6           20.95               2.0
# 8           25.70               2.0
# 19          26.12               2.0
# ..            ...               ...
# 898         20.78               2.0
# 921         19.23               2.0
# 925         23.19               2.0
# 945         19.81               2.0
# 997         19.94               2.0
#
# [75 rows x 15 columns]

# %%
id_category = {
    3902: 'диктофоны, портативные рекордеры',
    510402: 'электронные книги',
    4302: 'автомобильные телевизоры, мониторы',
    2815: 'смарт-часы и браслеты',
    3901: 'портативные медиаплееры',
    3904: 'портативная акустика',
    2801: 'мобильные телефоны',
    3908: 'VR-гарнитуры (VR-очки, шлемы, очки виртуальной реальности, FPV очки для квадрокоптеров)',
    510401: 'планшетные компьютеры и мини-планшеты',
    2102: 'наушники, гарнитуры, наушники c микрофоном',
    3903: 'радиоприемники, радиобудильники, радиочасы',
    3907: 'магнитолы',
    280801: 'GPS-навигаторы'
    }

print(dict(df_1000.model_id_correct.value_counts()))

# for category in id_category.values():
#     print(category)
#     df_1000_cat = df_1000[df_1000.category_name == category]
#     print(len(df_1000_cat))
#     print(dict(df_1000_cat.model_id_correct.value_counts()))
# Out:
# {1.0: 775, 0.0: 150, 2.0: 75}

# %%
pth_1000_errors_2 = '/home/sondors/Documents/price/ColBERT/proverka/colbert-5387_offers_top_n_exclude_top5_yes_no_1000_errors_2.csv'
df_1000_errors_2 = pd.read_csv(pth_1000_errors_2, sep=";")
# df_1000_errors_2 = df_1000_errors_2[df_1000_errors_2.category_id == 2102]
df_1000_errors_2['model_id_manual'] = df_1000_errors_2['model_id_manual'].astype(int)
df_1000_errors_no_model = df_1000_errors_2[df_1000_errors_2.model_id_manual == df_1000_errors_2.model_id_pred_5].reset_index(drop=True)
df_1000_errors_correct = df_1000_errors_2[df_1000_errors_2.model_id_manual == df_1000_errors_2.model_id_pred_1].reset_index(drop=True)
df_1000_errors_not_correct = df_1000_errors_2[df_1000_errors_2.model_id_manual == 0].reset_index(drop=True)

df_1000_errors_correct
# Out:
#                                                  name  model_id  \
# 0   Умные часы Smarterra Смарт-часы FitMaster Aura...   4271585
# 1                      Наушники Marley EM-FE033 White   1001031
# 2         Портативная акустика Philips BT 110 Красный   3709126
# 3                  Акустика портативная RITMIX SP-150    686059
# 4   Часы Apple Watch SE 2 GPS 44mm MNTE3 модель A2...   5678011
# 5   Планшет Apple iPad Pro 12.9 (2021), 8/256 Гб, ...   4800929
# 6                    Смартфон LG K7 (2017) X230 Titan    885408
# 7   Яндекс Умная колонка Яндекс.Станция Лайт, цвет...   4854469
# 8   Компьютерная гарнитура Jabra STEALTH UC черный...    747057
# 9   Apple Watch SE GPS 40мм Aluminum Case with Spo...   4511020
# 10  Lenovo M10 HD TB-X306F 4/64GB ZA6W0111RU (сере...   4557939
# 11                 DEFENDER (65687) ENJOY S1000 синий    407308
# 12     Портативная колонка Rombica MySound Melody Red   4851774
# 13        Планшет Alcatel 1T (2020) 7.0 (Цвет: Black)   4566072
# 14             Портативная акустика SMARTBUY SBS-1001   4851817
# 15  Акустика 2.1 Edifier X230, 28 Вт, AUX, Bluetoo...   4771619
# 16  Apple Watch Series 4 44mm (GPS) Silver Aluminu...   4511080
# 17      OnePlus 10 Pro 5G (8 / 256 Gb / Зеленый / CN)   4710262
# 18          Плеер Apple iPod touch 128GB - Space Grey   4228074
# 19  Планшет Xiaomi Redmi Pad 4/128Gb Серый графит ...   4892900
# 20  Смартфон Xiaomi Redmi Note 11 EU 6Gb/ 128Gb Серый   4890706
# 21   Портативная акустика Rombica MySound Melody Blue   4851773
# 22    Акустиа MAGIC ACOUSTIC SK1014R (503007) 1244715   4851617
# 23           iPad 9 64Gb Space Gray Wi-Fi (MK2K3RU/A)   4800932
# 24  Bluetooth гарнитура Xiaomi Mi Bluetooth Headse...   2986646
# 25  Акустика MAGIC ACOUSTIC SK1025GN ( SK1019GN) з...   4851579
# 26  Портативная акустика Rombica MySound Melody. Ц...   4851775
# 27          Беспроводные наушники 1More AirFree Black   4533001
# 28  Apple Watch SE 2022 (MNT33) 40mm Aluminum Case...   5678594
# 29  Беспроводная гарнитура HONOR X3 Lite , белый (...   4850161
# 30  Игровая гарнитура проводная Crown CMGH-3103 че...   4455769
#
#                                  category_name  category_id  model_id_pred_1  \
# 0                        смарт-часы и браслеты         2815          4271583
# 1   наушники, гарнитуры, наушники c микрофоном         2102          2812317
# 2                         портативная акустика         3904           995747
# 3                         портативная акустика         3904          4298653
# 4                        смарт-часы и браслеты         2815          4511020
# 5        планшетные компьютеры и мини-планшеты       510401          4800951
# 6                           мобильные телефоны         2801          2111564
# 7                         портативная акустика         3904          4854470
# 8   наушники, гарнитуры, наушники c микрофоном         2102           636346
# 9                        смарт-часы и браслеты         2815          4511029
# 10       планшетные компьютеры и мини-планшеты       510401          4557938
# 11                        портативная акустика         3904          4248133
# 12                        портативная акустика         3904          4851782
# 13       планшетные компьютеры и мини-планшеты       510401           591638
# 14                        портативная акустика         3904           705119
# 15                        портативная акустика         3904           612198
# 16                       смарт-часы и браслеты         2815          4511072
# 17                          мобильные телефоны         2801          5123111
# 18                     портативные медиаплееры         3901           858090
# 19       планшетные компьютеры и мини-планшеты       510401          6196023
# 20                          мобильные телефоны         2801          4890707
# 21                        портативная акустика         3904          4851782
# 22                        портативная акустика         3904          4851595
# 23       планшетные компьютеры и мини-планшеты       510401           188793
# 24  наушники, гарнитуры, наушники c микрофоном         2102          4153490
# 25                        портативная акустика         3904          4851604
# 26                        портативная акустика         3904          4851782
# 27  наушники, гарнитуры, наушники c микрофоном         2102          4049065
# 28                       смарт-часы и браслеты         2815          5678011
# 29  наушники, гарнитуры, наушники c микрофоном         2102          6200753
# 30  наушники, гарнитуры, наушники c микрофоном         2102          4455770
#
#     similarity_1  model_id_pred_2  similarity_2  model_id_pred_3  \
# 0          28.09          4271584         25.06          5151697
# 1          27.09          2812316         26.02           856735
# 2          24.42           995746         23.39           291994
# 3          29.72          1153071         26.91           302232
# 4          25.06          4577121         24.05          4511071
# 5          28.09          4800952         25.36          4070863
# 6          26.72          2038470         24.75           112233
# 7          27.98          5151961         27.42          5151970
# 8          22.28           742818         22.03           747204
# 9          30.28          4511035         28.89          4580479
# 10         27.09          1677246         22.20          6370506
# 11         27.59          6226411         25.16          4228132
# 12         28.28          4851784         25.97          4851776
# 13         21.34          1036760         21.31           734280
# 14         25.48           705144         25.47          6525983
# 15         26.12          6226417         24.92          4248137
# 16         29.23          4511073         25.88          4511079
# 17         28.38          5123109         27.70          4425637
# 18         28.27          4228072         27.83           330801
# 19         29.44          4153384         26.38          4153382
# 20         28.03          4890705         24.58          6476927
# 21         29.20          4851784         26.86          4851772
# 22         22.38          4851611         21.03          4851593
# 23         27.25           188788         25.75           284387
# 24         21.48          4455968         20.92          5281627
# 25         26.52          4851592         24.92          5128658
# 26         28.44          4851784         27.72          4851772
# 27         27.00          4636703         24.80          4153409
# 28         29.78          5769430         28.72          5678591
# 29         27.92          6200752         24.94          4797567
# 30         28.56          4533066         24.64          4533065
#
#     similarity_3  model_id_pred_4  similarity_4  model_id_pred_5  \
# 0          24.28          4179708         24.08          3933671
# 1          25.88           950278         23.92          2812333
# 2          22.53          2705892         20.80          4851951
# 3          22.97           290907         22.77          4851351
# 4          23.72          5678012         23.48          5678594
# 5          25.05          1465233         24.97          4800941
# 6          21.75           114776         21.52           116203
# 7          27.22          5151966         27.20          5151965
# 8          21.45          4300127         21.03           747222
# 9          27.98          5678011         26.34          5769430
# 10         22.06          1007743         21.34           866836
# 11         22.77          3931797         22.25          4228131
# 12         24.05          4851772         23.98          4851778
# 13         20.95           734282         20.34          4892885
# 14         24.55           705143         24.11           705145
# 15         21.55          4850976         19.81          4850999
# 16         24.08          5769429         22.50          4542362
# 17         25.89          5123110         25.34          5145768
# 18         25.17           331123         24.73           330799
# 19         24.78          4153383         24.69          5143673
# 20         23.47          6266811         23.41          6476930
# 21         25.59          4851778         25.19          4851780
# 22         20.94          4851614         20.70          4851606
# 23         25.61           188825         25.55           204706
# 24         20.45          4049806         19.97          5281629
# 25         23.73          4851602         23.42          4851023
# 26         24.97          4851778         24.67          4851780
# 27         24.64          4676749         24.42          4090043
# 28         27.58          5678012         25.31          5678592
# 29         21.06          4676951         20.44          1833520
# 30         23.28          4533431         23.20          4533062
#
#     similarity_5  model_id_correct  model_id_manual
# 0          23.80               2.0          4271583
# 1          21.98               2.0          2812317
# 2          20.09               2.0           995747
# 3          22.72               2.0          4298653
# 4          22.88               2.0          4511020
# 5          24.25               2.0          4800951
# 6          21.36               2.0          2111564
# 7          27.19               2.0          4854470
# 8          20.97               2.0           636346
# 9          25.44               2.0          4511029
# 10         19.86               2.0          4557938
# 11         21.89               2.0          4248133
# 12         23.58               2.0          4851782
# 13         20.06               2.0           591638
# 14         24.02               2.0           705119
# 15         19.17               2.0           612198
# 16         22.38               2.0          4511072
# 17         25.30               2.0          5123111
# 18         24.69               2.0           858090
# 19         23.56               2.0          6196023
# 20         23.41               2.0          4890707
# 21         25.17               2.0          4851782
# 22         20.44               2.0          4851595
# 23         25.30               2.0           188793
# 24         19.75               2.0          4153490
# 25         23.05               2.0          4851604
# 26         24.62               2.0          4851782
# 27         23.84               2.0          4049065
# 28         24.44               2.0          5678011
# 29         20.12               2.0          6200753
# 30         20.78               2.0          4455770

# %%
df_1000_errors_not_correct
# Out:
#                                                 name  model_id  \
# 0  Беспроводные Bluetooth наушники для мобильных ...   4731862
# 1  Беспроводная акустика Умная колонка Яндекс.Ста...   4854469
# 2  Bluetooth стерео-гарнитура, Спортивная Bluetoo...   4533214
# 3  Полностью беспроводные наушники Bowers & Wilki...   4850060
# 4  Планшет DIGMA 1402D 10.1" 4/64GB Silver Wi-Fi+...   4557928
#
#                                 category_name  category_id  model_id_pred_1  \
# 0  наушники, гарнитуры, наушники c микрофоном         2102          4802464
# 1                        портативная акустика         3904          5151970
# 2  наушники, гарнитуры, наушники c микрофоном         2102          4153443
# 3  наушники, гарнитуры, наушники c микрофоном         2102           742049
# 4       планшетные компьютеры и мини-планшеты       510401          6177706
#
#    similarity_1  model_id_pred_2  similarity_2  model_id_pred_3  similarity_3  \
# 0         15.53          4533628         15.12          4636872         15.06
# 1         21.69          5151961         21.66          5151964         21.66
# 2         14.40          5490537         14.33          4754612         14.30
# 3         21.72          4455762         21.52           742050         21.52
# 4         20.23           831852         20.20          1464879         19.67
#
#    model_id_pred_4  similarity_4  model_id_pred_5  similarity_5  \
# 0          4533632         14.98           743101         14.97
# 1          5151967         21.59          5151963         21.52
# 2          1034671         14.27          4735624         14.24
# 3          6200717         21.50          5137469         21.42
# 4           646909         19.50           944123         19.23
#
#    model_id_correct  model_id_manual
# 0               2.0                0
# 1               2.0                0
# 2               2.0                0
# 3               2.0                0
# 4               2.0                0

# %%
print(f"ColBERT прав: {len(df_1000_errors_correct)}\nColBERT ошибся: {len(df_1000_errors_not_correct)}\nотсутствующая модель: {len(df_1000_errors_no_model)}")
# Out:
# ColBERT прав: 31
# ColBERT ошибся: 5
# отсутствующая модель: 39

# %%
{1.0: 775, 0.0: 150, 2.0: 75}

# Для данных в которых среди top_5 матчей ColBERT'а нет model_id, присвоенного офферу моделайзером 
# Моделайзер прав: 775
# ColBERT прав: 31
# Моделайзер и ColBERT ошиблись одновременно: 5
# проблема с оффером или моделью: 189
