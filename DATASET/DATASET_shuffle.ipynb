# %%
import random

# Открываем исходный файл для чтения
input_file_path = '/home/sondors/Documents/price/ColBERT_data/13_categories/train_filtered/triples_X1_13_categories_filtered.json'
with open(input_file_path, 'r', encoding='utf-8') as input_file:
    # Читаем строки из исходного файла
    lines = input_file.readlines()

lines
# Out:
# ['[0, 27370, 15746]\n',
#  '[1, 3487, 19891]\n',
#  '[2, 19891, 12880]\n',
#  '[3, 14644, 10390]\n',
#  '[4, 19891, 12880]\n',
#  '[5, 19891, 12880]\n',
#  '[6, 19891, 12880]\n',
#  '[7, 3487, 19891]\n',
#  '[8, 14595, 4223]\n',
#  '[9, 14595, 4223]\n',
#  '[10, 19891, 12880]\n',
#  '[11, 14644, 10390]\n',
#  '[12, 13634, 23414]\n',
#  '[13, 24827, 16732]\n',
#  '[14, 19891, 12880]\n',
#  '[15, 13634, 23414]\n',
#  '[16, 13634, 23414]\n',
#  '[17, 14644, 10390]\n',
#  '[18, 14644, 10390]\n',
#  '[19, 24827, 16732]\n',
#  '[20, 24827, 16732]\n',
#  '[21, 24827, 16732]\n',
#  '[22, 24827, 16732]\n',
#  '[23, 24827, 16732]\n',
#  '[24, 12880, 14595]\n',
#  '[25, 12880, 14595]\n',
#  '[26, 12880, 14595]\n',
#  '[27, 12880, 14595]\n',
#  '[28, 15173, 11261]\n',
#  '[29, 10390, 15173]\n',
#  '[30, 10390, 15173]\n',
#  '[31, 10390, 15173]\n',
#  '[32, 4413, 4778]\n',
#  '[33, 6664, 19285]\n',
#  '[34, 6664, 19285]\n',
#  '[35, 22943, 18514]\n',
#  '[36, 4087, 16899]\n',
# ...

# %%
def shuffle_wrt_file(output_file_path, lines):
    random.shuffle(lines)
    with open(output_file_path, 'w', encoding='utf-8') as output_file:
        output_file.writelines(lines)

output_file_path = '/home/sondors/Documents/price/ColBERT_data/13_categories/train_filtered/triples_X1_13_categories_filtered_shuffle.json'

shuffle_wrt_file(output_file_path, lines)
print(f'Файл {output_file_path} успешно создан с перемешанным порядком строк.')
# Out:
# Файл /home/sondors/Documents/price/ColBERT_data/13_categories/train_filtered/triples_X1_13_categories_filtered_shuffle.json успешно создан с перемешанным порядком строк.

# %%
lines
# Out:
# ['[107246, 27211, 25735]\n',
#  '[536083, 4812, 8905]\n',
#  '[557414, 2468, 8312]\n',
#  '[364183, 22784, 26085]\n',
#  '[151273, 13460, 2705]\n',
#  '[112564, 13181, 6753]\n',
#  '[298155, 13916, 11990]\n',
#  '[220721, 17131, 14020]\n',
#  '[58221, 12575, 13938]\n',
#  '[125032, 27770, 22627]\n',
#  '[414434, 13682, 9423]\n',
#  '[408687, 19309, 2761]\n',
#  '[192606, 6268, 19755]\n',
#  '[530855, 27849, 19078]\n',
#  '[222222, 17969, 12229]\n',
#  '[77558, 1814, 24954]\n',
#  '[448200, 7842, 20349]\n',
#  '[325282, 22023, 26403]\n',
#  '[224875, 16550, 4834]\n',
#  '[538955, 8003, 8676]\n',
#  '[468643, 21109, 21993]\n',
#  '[274071, 10521, 6167]\n',
#  '[160593, 19086, 5041]\n',
#  '[331875, 22784, 26085]\n',
#  '[284047, 907, 6858]\n',
#  '[41347, 9580, 11689]\n',
#  '[226455, 15648, 2959]\n',
#  '[117856, 8101, 24766]\n',
#  '[338196, 25429, 26774]\n',
#  '[240488, 13768, 14233]\n',
#  '[287129, 14356, 11124]\n',
#  '[65190, 23050, 23407]\n',
#  '[406033, 1816, 22304]\n',
# ...
