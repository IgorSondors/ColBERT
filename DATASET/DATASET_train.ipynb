# %%
import pandas as pd
import random

scr_pth = "/home/sondors/Documents/price/BERT_data/data/27-03-2024_Timofey/740101_triplets_offer_model_train.csv"
dst_fld = "/home/sondors/Documents/price/ColBERT_data/10_categories/740101/train"
dst_name = "740101"
df_triplets = pd.read_csv(scr_pth, sep=";")
df_triplets
# Out:
#                                                      name  model_id  \
# 0                                          Teac R-1 black    293450
# 1           Tivoli Audio Model Three black/silver (M3BLK)    293587
# 2              Tivoli Audio Model One black/black (M1BLK)    293586
# 3       Tivoli Audio Portable Audio Laboratory electri...    293460
# 4             Tivoli Audio Model One white/silver (M1WHT)    293586
# ...                                                   ...       ...
# 569170  Планшет Blackview Tab 11 SE Cortex SC9863A (1....   4898118
# 569171  Планшет Digma CITI Kids 10 MT8321 4C 2/32Gb 10...   4908671
# 569172  Планшет Xiaomi Redmi Pad (6 / 128 Gb / Зеленый...   6196024
# 569173  Планшет HUAWEI MatePad 10.4" (2022) 4+64GB WiF...   4903255
# 569174  Планшет Samsung Galaxy Tab A 8.0 (2017) LTE 16...   2112686
#
#                                      category_name  category_id  \
# 0       радиоприемники, радиобудильники, радиочасы         3903
# 1       радиоприемники, радиобудильники, радиочасы         3903
# 2       радиоприемники, радиобудильники, радиочасы         3903
# 3       радиоприемники, радиобудильники, радиочасы         3903
# 4       радиоприемники, радиобудильники, радиочасы         3903
# ...                                            ...          ...
# 569170       планшетные компьютеры и мини-планшеты       510401
# 569171       планшетные компьютеры и мини-планшеты       510401
# 569172       планшетные компьютеры и мини-планшеты       510401
# 569173       планшетные компьютеры и мини-планшеты       510401
# 569174       планшетные компьютеры и мини-планшеты       510401
#
#         model_id_pred_1  similarity_1  model_id_pred_2  similarity_2  \
# 0                293450         27.50           293451         21.59
# 1                293587         25.80           293525         24.66
# 2                293586         26.59           293584         25.88
# 3                293460         27.23           293588         21.92
# 4                293586         27.31           293584         26.44
# ...                 ...           ...              ...           ...
# 569170          4898118         22.42          4898121         18.06
# 569171          4908671         25.42          4811261         21.78
# 569172          6196024         26.78          6196023         23.31
# 569173          4903255         26.62          4465666         25.14
# 569174          4277007         24.94           813756         24.30
#
#         model_id_pred_3  similarity_3  model_id_pred_4  similarity_4  \
# 0                512755         18.55           512752         16.20
# 1                293585         17.50           293524         16.48
# 2                293456         23.20           293524         19.77
# 3                293589         21.80           535779         21.55
# 4                293456         23.94           293524         20.39
# ...                 ...           ...              ...           ...
# 569170           408043         16.97          4898120         16.94
# 569171          4784078         21.17          4557927         20.62
# 569172          4892900         23.20          4153384         22.73
# 569173          5151715         22.80          4904583         22.33
# 569174           813755         23.75           813757         23.52
#
#         model_id_pred_5  similarity_5                        true_match  \
# 0                297122         15.80                          TEAC R-1
# 1               4569822         16.41                Tivoli Model Three
# 2                293585         19.36                  Tivoli Model One
# 3                535740         21.38  Tivoli Portable Audio Laboratory
# 4                293585         19.84                  Tivoli Model One
# ...                 ...           ...                               ...
# 569170          4898116         15.98                  Blackview Tab 11
# 569171          4153496         19.25                Digma CITI Kids 10
# 569172          4153381         21.23          Xiaomi Redmi Pad 6/128Gb
# 569173          4520337         21.36          Huawei MatePad 10.4 2022
# 569174          2112686         23.52  Samsung Galaxy Tab A 8.0 SM-T385
#
#                            false_match
# 0                       Tangent Uno2go
# 1                     Tivoli Model One
# 2                      Tivoli Model 10
# 3       Tivoli NetWorks Stereo with FM
# 4                      Tivoli Model 10
# ...                                ...
# 569170            Blackview Tab 10 Pro
# 569171              Digma EVE 10 A400T
# 569172        Xiaomi Redmi Pad 4/128Gb
# 569173  Apple iPad Air 2022 Wi-Fi 64GB
# 569174         Prestigio Grace 3201 4G
#
# [569175 rows x 16 columns]

# %%
# imya_kategorii = "чехлы, обложки для гаджетов (телефонов, планшетов etc)"
# imya_kategorii2 = "кухонные мойки"
# imya_kategorii3 = "парфюмерия"
# imya_kategorii4 = "корм для собак"

# df_triplets = df_triplets[df_triplets.category_name != imya_kategorii].reset_index(drop=True)
# df_triplets = df_triplets[df_triplets.category_name != imya_kategorii2].reset_index(drop=True)
# df_triplets = df_triplets[df_triplets.category_name != imya_kategorii3].reset_index(drop=True)
# df_triplets = df_triplets[df_triplets.category_name != imya_kategorii4].reset_index(drop=True)
# df_triplets
# Out:
#                                                      name  model_id  \
# 0                                          Teac R-1 black    293450
# 1           Tivoli Audio Model Three black/silver (M3BLK)    293587
# 2              Tivoli Audio Model One black/black (M1BLK)    293586
# 3       Tivoli Audio Portable Audio Laboratory electri...    293460
# 4             Tivoli Audio Model One white/silver (M1WHT)    293586
# ...                                                   ...       ...
# 569170  Планшет Blackview Tab 11 SE Cortex SC9863A (1....   4898118
# 569171  Планшет Digma CITI Kids 10 MT8321 4C 2/32Gb 10...   4908671
# 569172  Планшет Xiaomi Redmi Pad (6 / 128 Gb / Зеленый...   6196024
# 569173  Планшет HUAWEI MatePad 10.4" (2022) 4+64GB WiF...   4903255
# 569174  Планшет Samsung Galaxy Tab A 8.0 (2017) LTE 16...   2112686
#
#                                      category_name  category_id  \
# 0       радиоприемники, радиобудильники, радиочасы         3903
# 1       радиоприемники, радиобудильники, радиочасы         3903
# 2       радиоприемники, радиобудильники, радиочасы         3903
# 3       радиоприемники, радиобудильники, радиочасы         3903
# 4       радиоприемники, радиобудильники, радиочасы         3903
# ...                                            ...          ...
# 569170       планшетные компьютеры и мини-планшеты       510401
# 569171       планшетные компьютеры и мини-планшеты       510401
# 569172       планшетные компьютеры и мини-планшеты       510401
# 569173       планшетные компьютеры и мини-планшеты       510401
# 569174       планшетные компьютеры и мини-планшеты       510401
#
#         model_id_pred_1  similarity_1  model_id_pred_2  similarity_2  \
# 0                293450         27.50           293451         21.59
# 1                293587         25.80           293525         24.66
# 2                293586         26.59           293584         25.88
# 3                293460         27.23           293588         21.92
# 4                293586         27.31           293584         26.44
# ...                 ...           ...              ...           ...
# 569170          4898118         22.42          4898121         18.06
# 569171          4908671         25.42          4811261         21.78
# 569172          6196024         26.78          6196023         23.31
# 569173          4903255         26.62          4465666         25.14
# 569174          4277007         24.94           813756         24.30
#
#         model_id_pred_3  similarity_3  model_id_pred_4  similarity_4  \
# 0                512755         18.55           512752         16.20
# 1                293585         17.50           293524         16.48
# 2                293456         23.20           293524         19.77
# 3                293589         21.80           535779         21.55
# 4                293456         23.94           293524         20.39
# ...                 ...           ...              ...           ...
# 569170           408043         16.97          4898120         16.94
# 569171          4784078         21.17          4557927         20.62
# 569172          4892900         23.20          4153384         22.73
# 569173          5151715         22.80          4904583         22.33
# 569174           813755         23.75           813757         23.52
#
#         model_id_pred_5  similarity_5                        true_match  \
# 0                297122         15.80                          TEAC R-1
# 1               4569822         16.41                Tivoli Model Three
# 2                293585         19.36                  Tivoli Model One
# 3                535740         21.38  Tivoli Portable Audio Laboratory
# 4                293585         19.84                  Tivoli Model One
# ...                 ...           ...                               ...
# 569170          4898116         15.98                  Blackview Tab 11
# 569171          4153496         19.25                Digma CITI Kids 10
# 569172          4153381         21.23          Xiaomi Redmi Pad 6/128Gb
# 569173          4520337         21.36          Huawei MatePad 10.4 2022
# 569174          2112686         23.52  Samsung Galaxy Tab A 8.0 SM-T385
#
#                            false_match
# 0                       Tangent Uno2go
# 1                     Tivoli Model One
# 2                      Tivoli Model 10
# 3       Tivoli NetWorks Stereo with FM
# 4                      Tivoli Model 10
# ...                                ...
# 569170            Blackview Tab 10 Pro
# 569171              Digma EVE 10 A400T
# 569172        Xiaomi Redmi Pad 4/128Gb
# 569173  Apple iPad Air 2022 Wi-Fi 64GB
# 569174         Prestigio Grace 3201 4G
#
# [569175 rows x 16 columns]

# %%
"""
The file documents_train.tsv contains the training documents and has the following format:
0 text0
1 text1
2 text2
"""

documents = set(list(df_triplets['true_match'])+list(df_triplets['false_match']))
id = [i for i in range(len(documents))]
id_to_document = dict(zip(id, documents))
document_to_id = {y: x for x, y in id_to_document.items()}

documents_train = pd.DataFrame()
documents_train["id"] = id
documents_train["documents"] = list(documents)

# id_to_document
# document_to_id
documents_train.to_csv(f'{dst_fld}/documents_train_{dst_name}.tsv', sep='\t', header=False, index=False)

documents_train
# Out:
#           id              documents
# 0          0         Koss Pro DJ100
# 1          1           Bluedio F800
# 2          2          KingWear LW10
# 3          3       Sony MDR-XB950AP
# 4          4          Qumo Push 220
# ...      ...                    ...
# 28590  28590  Realme GT Neo 3 128Gb
# 28591  28591  Apple iPhone X 256 GB
# 28592  28592      Westone UM PRO 10
# 28593  28593              Colmi B57
# 28594  28594            HTC One X10
#
# [28595 rows x 2 columns]

# %%
"""
The file queries.tsv contains the queries and has the following format:
0 query0
1 query1
2 query2
"""

queries = list(df_triplets.drop_duplicates(subset=['name'], keep="first")['name'])
id = [i for i in range(len(queries))]
id_to_query = dict(zip(id, queries))
query_to_id = {y: x for x, y in id_to_query.items()}

queries_train = pd.DataFrame()
queries_train["id"] = id
queries_train["queries"] = queries

# id_to_query
# query_to_id
queries_train.to_csv(f'{dst_fld}/queries_train_{dst_name}.tsv', sep='\t', header=False, index=False)

queries_train
# Out:
#             id                                            queries
# 0            0                                     Teac R-1 black
# 1            1      Tivoli Audio Model Three black/silver (M3BLK)
# 2            2         Tivoli Audio Model One black/black (M1BLK)
# 3            3  Tivoli Audio Portable Audio Laboratory electri...
# 4            4        Tivoli Audio Model One white/silver (M1WHT)
# ...        ...                                                ...
# 569170  569170  Планшет Blackview Tab 11 SE Cortex SC9863A (1....
# 569171  569171  Планшет Digma CITI Kids 10 MT8321 4C 2/32Gb 10...
# 569172  569172  Планшет Xiaomi Redmi Pad (6 / 128 Gb / Зеленый...
# 569173  569173  Планшет HUAWEI MatePad 10.4" (2022) 4+64GB WiF...
# 569174  569174  Планшет Samsung Galaxy Tab A 8.0 (2017) LTE 16...
#
# [569175 rows x 2 columns]

# %%
queries
# Out:
# ['Teac R-1 black',
#  'Tivoli Audio Model Three black/silver (M3BLK)',
#  'Tivoli Audio Model One black/black (M1BLK)',
#  'Tivoli Audio Portable Audio Laboratory electric blue/silver (PALBLUS)',
#  'Tivoli Audio Model One white/silver (M1WHT)',
#  'Tivoli Audio Model One Maple/Hunter Green (M1GRN)',
#  'Tivoli Audio Model One wenge/beige (M1WNCLB)',
#  'Tivoli Audio Model Three Platinum Series piano black/silver (M3PIANO)',
#  'Tivoli Audio Cappellini Model One acid green/silver (M1GRN)',
#  'Tivoli Audio Cappellini Model One china blue/silver (M1CBL)',
#  'Tivoli Audio Model One frost white/snow white (M1FWSW)',
#  'Tivoli Audio Portable Audio Laboratory electric blue (PALBLU)',
#  'Tivoli Audio Model Two cherry/metallic taupe (M2TPE)',
#  'Tivoli Audio Model 10 Stereo walnut/silver (M10WL)',
#  'Tivoli Audio Model One frost white/sunflower yellow (M1FWSY)',
#  'Tivoli Audio Model Two cherry/silver (M2SLC)',
#  'Tivoli Audio Model Two piano black/silver (M2PIANO)',
#  'Tivoli Audio Portable Audio Laboratory green/gold (PALGRNG)',
#  'Tivoli Audio Portable Audio Laboratory blue/gold (PALBLUG)',
#  'Tivoli Audio Model 10 Stereo Midnight Black/Silver (M10CMB)',
#  'Tivoli Audio Model 10 Stereo Cherry/Silver (M10CCH)',
#  'Tivoli Audio Model 10 Stereo Lines/Silver (M10CL)',
#  'Tivoli Audio Model 10 Stereo Frost White/White (M10CFW)',
#  'Tivoli Audio Model 10 Stereo Chesnut Brown/Silver (M10CCB)',
#  'Tivoli Audio Model 10 Clock Radio Chesnut Brown/Silver (M10CB)',
#  'Tivoli Audio Model 10 Clock Radio Frost White/White (M10FW)',
#  'Tivoli Audio Model 10 Clock Radio Midnight Black/Silver (M10MB)',
#  'Tivoli Audio Model 10 Clock Radio Cherry/Silver (M10CH)',
#  'Tivoli Audio NetWorks Stereo walnut/gold (NCWLG)',
#  'Tivoli Audio NetWorks Stereo with FM Carmine Red/White (NFCCR)',
#  'Tivoli Audio NetWorks Stereo with FM Ocean Blue/White (NFCOB)',
#  'Tivoli Audio NetWorks Stereo with FM Grass Green/White (NFCGG)',
#  'Радиочасы Rolsen RBM302i док-станция для iPHONE/iPOD черный',
#  'Радиочасы с термометром ERISSON RC-2202A черные',
#  'Радиочасы с термометром ERISSON RC-2202A цвет титан',
#  'Радиоприемник RITMIX RPR-7010',
#  'Радиоприемник Rolsen RBM-215MUR синий',
#  'Радиоприемник Rolsen RBM-215MUR красный',
#  'РАДИОБУДИЛЬНИК RITMIX RRC-1004',
#  'РАДИОБУДИЛЬНИК RITMIX RRC-1005',
#  'РАДИОПРИЕМНИК RITMIX RPR-7040 зеленый',
#  'РАДИОПРИЕМНИК RITMIX RPR2400 черный',
#  'РАДИОПРИЕМНИК RITMIX RPR-7020',
#  'РАДИОПРИЕМНИК RITMIX RPR-7040 черный',
#  'Радиобудильник Hyundai H-1623 красная кожа',
#  'Радиоприемник BBK CR140i',
#  'Радиоприемник BBK CR143i',
#  'Tivoli Audio iPAL High Gloss Yellow/Silver',
#  'Радиочасы с USB ERISSON RC-101U черный',
#  'Радиочасы с USB ERISSON RC-101U серый металлик',
#  'Радиочасы с USB ERISSON RC-101U серебристые',
#  'Радиочасы с термометром ERISSON RC-1202 синий металлик',
#  'Радиочасы с термометром ERISSON RC-1206 синий металлик',
#  'Радиочасы с термометром ERISSON RC-1206 серый металлик',
#  'Радиочасы с термометром ERISSON RC-1206 серебристые',
#  'Радиочасы с термометром ERISSON RC-1215P с проекцией, серый металлик',
#  'Радиочасы ERISSON RC-1302 серый металлик',
#  'Радиочасы с термометром ERISSON RC-2206A синий металлик',
#  'Радиочасы с термометром ERISSON RC-2206A серый металлик',
#  'Радиочасы с термометром ERISSON RC-2206A серебристые',
#  'Tivoli Audio Model One oak/wine (M1WOAK)',
#  'Tivoli Audio Model One wenge/silver (M1WNSLV)',
#  'Tivoli Audio Model Three Stereo Platinum Series dark walnut/beige (M3SDKCLA)',
#  'Проекционные часы Oregon Scientific RRA320PN',
#  'Oregon Scientific Проекционные часы Oregon Scientific RRA320PN',
#  'ERISSON Радиочасы с USB ERISSON RC-101U серый металлик',
#  'ERISSON Радиочасы с термометром ERISSON RC-1202 синий металлик',
#  'ERISSON Радиочасы с термометром ERISSON RC-1206 синий металлик',
#  'ERISSON Радиочасы с термометром ERISSON RC-2202A черные',
#  'ERISSON Радиочасы с термометром ERISSON RC-1202 зеленые',
#  'ERISSON Радиочасы с термометром ERISSON RC-2202A цвет титан',
#  'ERISSON Радиочасы с термометром ERISSON RC-2202A зеленые',
#  'RITMIX РАДИОБУДИЛЬНИК RITMIX RRC-1004',
#  'RITMIX РАДИОПРИЕМНИК RITMIX RPR-7040 оранжевый',
#  'BBK Радиоприемник BBK CR140i',
#  'BBK Радиоприемник BBK CR143i',
#  'Philips Радиобудильник Philips AJ3112/12',
#  'Philips Радиобудильник Philips AJ7000/12',
#  'Philips Радиобудильник Philips AJ1003/12',
#  'Philips Радиобудильник Philips AJ3121/12',
#  'Philips Радиобудильник Philips AJ3231/12',
#  'Philips Радиобудильник Philips AJ3551/12',
#  'Радиобудильник Philips AJ3121/12',
#  'Радиобудильник Philips AJ3231/12',
#  'Rolsen Радиоприемник Rolsen RBM-215MUR синий',
#  'Rolsen Радиоприемник Rolsen RBM-215MUR красный',
#  'ERISSON Радиоприемник ERISSON R-2160A синий металлик',
#  'ERISSON Радиоприемник ERISSON R-2160A серый металлик',
#  'Philips Радиоприемник Philips AE1850/00',
#  'Philips Радиоприемник Philips AE2730/12',
#  'Sony Радиоприемник Sony ICF-SW11/S',
#  'Радиоприемник ERISSON R-2160A синий металлик',
#  'Радиоприемник ERISSON R-2160A серебристый',
#  'Радиобудильник Philips AJ3540/12',
#  'Радиоприемник Philips AE2730/12',
#  'Радиоприемник Sony ICF-F12S',
#  'Philips Радиобудильник Philips AJ3500/12',
#  'Радиобудильник Philips AJ3500/12',
#  'Многофункциональные часы Philips AJ7000/12 радиобудильник',
#  'Teac R-5 black',
#  'Многофункциональные часы Philips AJ 3231',
#  'Радиобудильник ERISSON RC-1215P grey',
#  'Радиобудильник ERISSON RC-1215P white',
#  'Многофункциональные часы VITEK VT-3519',
#  'Многофункциональные часы VITEK VT-3504',
#  'Проекционные часы Oregon Scientific RRA320PN черные',
#  'Радиочасы ERISSON RWR-1388 White-Green',
#  'Радиоприемник Sony SRF-18B Black',
#  'Радиоприемник Sony SRF-18W White',
#  'Магнитола Rolsen RBM-411 Orange',
#  'Магнитола Rolsen RBM-412 Black',
#  'Магнитола Rolsen RBM-412 Brown',
#  'Многофункциональные часы Ea2 FP107B',
#  'Радиоприемник RITMIX RPR-7040 Green',
#  'Радиоприемник RITMIX RPR-7040 Orange',
#  'Радиоприемник RITMIX RPR2061 Gray',
#  'Радиоприемник RITMIX RPR2061 Black',
#  'Радиоприемник Rolsen RBM-215MUR Blue',
#  'Радиоприемник Rolsen RBM-215MUR Red',
#  'Многофункциональные часы Philips AJ3400/12 радиобудильник',
#  'Радиоприемник Tivoli Audio Model One black/black (M1BLK)',
#  'Радиоприемник Tivoli Audio Portable Audio Laboratory IPAL electric blue/silver (PALBLUS)',
#  'Радиоприемник Tivoli Audio Portable Audio Laboratory sunset red (PALRED)',
#  'Радиоприемник Tivoli Audio Portable Audio Laboratory neon yellow (PALYEL)',
#  'Радиоприемник Tivoli Audio NetWorks Stereo with FM Chiset/White (NFCCS)',
#  'Радиоприемник Tivoli Audio Model One white/silver (M1WHT)',
#  'Радиоприемник Tivoli Audio Model One classic walnut/beige (M1CLA)',
#  'Радиоприемник Tivoli Audio Model One wenge/beige (M1WNCLB)',
#  'Радиоприемник Tivoli Audio Model One wenge/bronze (M1WNBRZ)',
#  'Радиоприемник Tivoli Audio Model Three white/silver (M3WHT)',
#  'Радиоприемник Tivoli Audio Model Three cherry/silver (M3SLC)',
#  'Радиоприемник Tivoli Audio Cappellini Model One acid green/silver (M1AG)',
#  'Радиоприемник Tivoli Audio Model One frost white/sunflower yellow (M1FWSY)',
#  'Радиоприемник Tivoli Audio Model One frost white/kelly green (M1FWKG)',
#  'Радиоприемник Tivoli Audio Model Two cherry/silver (M2SLC)',
#  'Радиоприемник Tivoli Audio Model Two dark walnut/beige (M2DKCLA)',
#  'Радиоприемник Tivoli Audio Portable Audio Laboratory wine/gold (PALWNEG)',
#  'Радиоприемник Tivoli Audio Portable Audio Laboratory green/gold (PALGRNG)',
#  'Радиоприемник Tivoli Audio Model 10 Stereo Ocean Blue/Silver (M10COB)',
#  'Радиоприемник Tivoli Audio Model 10 Stereo Cherry/Silver (M10CCH)',
#  'Радиоприемник Tivoli Audio Model 10 Stereo Frost White/White (M10CFW)',
#  'Радиоприемник Tivoli Audio Model 10 Clock Radio Chesnut Brown/Silver (M10CB)',
#  'Радиоприемник Tivoli Audio Model 10 Clock Radio Midnight Black/Silver (M10MB)',
#  'Радиоприемник Tivoli Audio Model 10 Clock Radio Aluminum Light/Silver (M10AL)',
#  'Радиоприемник Tivoli Audio NetWorks Internet Version Wenge/Gold (NWNG)',
#  'Радиоприемник Tivoli Audio NetWorks Stereo walnut/gold (NCWLG)',
#  'Радиоприемник Tivoli Audio NetWorks Stereo wenge/gold (NCWNG)',
#  'Радиоприемник Tivoli Audio NetWorks Stereo with FM Stone Gray/White (NFCSG)',
#  'Радиоприемник Tivoli Audio NetWorks Stereo with FM Midnight Black/White (NFCBS)',
#  'Радиоприемник Tivoli Audio iPAL High Gloss Black/Silver',
#  'Радиоприемник Tivoli Audio iPAL White/Silver',
#  'Радиоприемник Teac R-5 red',
#  'Радиоприемник Tivoli Audio Model Three Stereo Platinum Series dark walnut/beige (M3SDKCLA)',
#  'Радиоприемник Tivoli Audio Model Three Stereo Platinum Series piano black/silver (M3SPIANO)',
#  'Радиоприемник Teac R-5 black',
#  'Радиоприемник Teac R-5 white',
#  'Радиоприемник Tivoli Audio PAL BT glossy blue/white',
#  'Радиоприемник Tivoli Audio Model One BT wenge/beige',
#  'Радиоприемник Tivoli Audio Model One walnut/beige + Connector frost white/white',
#  'Радиоприемник Tivoli Audio Model One walnut/beige + ipod/iphone Connector frost white/white',
#  'Радиоприемник Teac R-1 black',
#  'FM Тюнер Teac R-1, красный',
#  'FM Тюнер Teac R-5, красный',
#  'Tivoli Audio Model 10 Stereo Speaker Aluminium Dark/Silver (M10',
#  'Tivoli Audio Model 10 Stereo Speaker Aluminium Light/Silver (M1',
#  'Tivoli Audio Model 10 Stereo Speaker Carmine Red/Silver (M10SCR',
#  'Tivoli Audio Model 10 Stereo Speaker Ocean Blue/Silver (M10SOB)',
#  'Tivoli Audio Model One Platinum Series dark walnut/beige (M1DKC',
#  'Tivoli Audio Portable Audio Laboratory high gloss metallic yell',
#  'Ruark Audio R1 rich walnut',
#  'Tivoli Audio Model One Platinum Series piano black/silver',
#  'Радиоприемник Sangean ATS-909X White/Silver',
#  'Радиоприемник Sangean ATS-909X Black',
#  'Радиоприемник Sangean RCR-9',
#  'Радиоприемник Sangean K-200 Black',
#  'Радиоприемник Prology WR-100',
#  'Радиоприемник Prology WR-200',
#  'Радиоприемник Sangean WR-12BT Walnut',
#  'Радиоприемник Sangean PR-D5P Silver /White',
#  'Радиоприемник SUPRA ST-110 Black',
#  'Радиоприемник SUPRA ST-111 Black',
#  'Радиоприемник SUPRA ST-113 Silver/Blue',
#  'Радиоприемник SUPRA ST-115 Silver',
#  'Радиоприемник SUPRA ST-122 Black',
#  'Радиоприемник Rolsen CR-110',
#  'Радиоприемник Rolsen CR-120W',
#  'Радиоприемник Rolsen CR-140',
#  'Vitek Радиочасы Winx WX-4052',
#  'Vitek Winx WX-4051',
#  'Радиоприемник Rolsen RBM-412BR Brown',
#  'Радиоприемник MAX MR-290 Black 26051',
#  'Радиоприемник Sangean H-201 White',
#  'Плеер teXet TR-3000',
#  'Tivoli Audio Model One BT (M1BTCLA) walnut/beige',
#  'Tivoli Audio Model 10 Aluminum Dark/Silver (M10AD)',
#  'Tivoli Audio Model One BT cherry/silver (M1BTSLC)',
#  'Tivoli Audio iPAL High Gloss Red/Silver (PALIPALR)',
#  'Многофункциональные часы Ea2 FP107T',
#  'Радиоприемник Сигнал БЗРП РП-309',
#  'Радиоприемники Tivoli Audio Model One wenge/bronze (M1WNBRZ)',
#  'Акустические системы Tivoli Audio Model 10 Stereo Speaker Aluminium Dark/Silver (M10',
#  'Акустические системы Tivoli Audio Model 10 Stereo Speaker Aluminium Light/Silver (M1',
#  'Акустические системы Tivoli Audio Model 10 Stereo Speaker Midnight Black/Silver (M10',
#  'Радиоприемники Tangent Uno2go high gloss IceBlue',
#  'Радиоприемники Tangent Uno2go high gloss orange',
#  'Радиоприемники Tivoli Audio Cappellini Model One acid green/silver (M1AG)',
#  'Радиоприемники Tivoli Audio Model 10 Midnight Black/Silver (M10MB)',
#  'Радиоприемники Tivoli Audio Model 10 Stereo Aluminum Dark/Silver (M10CAD)',
#  'Радиоприемники Tivoli Audio Model 10 Stereo Carmine red/silver (M10CCR)',
#  'Радиоприемники Tivoli Audio Model 10 Stereo Cherry/Silver (M10CCH)',
#  'Радиоприемники Tivoli Audio Model One BT black ash/black',
#  'Радиоприемники Tivoli Audio Model One cherry/cobalt blue (M1BLU)',
#  'Радиоприемники Tivoli Audio Model One frost white/kelly green (M1FWKG)',
#  'Радиоприемники Tivoli Audio Model One wenge/beige (M1WNCLB)',
#  'Радиоприемники Tivoli Audio Model Three Platinum Series piano black/silver (M3',
#  'Радиоприемники Tivoli Audio Model Three Stereo Platinum Series dark walnut/bei',
#  'Радиоприемники Tivoli Audio NetWorks Internet Version Cherry/Gold (NCHG)',
#  'Радиоприемники Tivoli Audio NetWorks Speaker Walnut/Gold (NSWLG)',
#  'Радиоприемники Tivoli Audio NetWorks Stereo walnut/gold (NCWLG)',
#  'Радиоприемники Tivoli Audio NetWorks Stereo with FM Lines/White (NFCL)',
#  'Радиоприемники Tivoli Audio NetWorks Stereo with FM Ocean Blue/White (NFCOB)',
#  'Радиоприемники Tivoli Audio NetWorks Stereo with FM V-Stripes/White (NFCVS)',
#  'Радиоприемники Tivoli Audio PAL BT glossy black/white',
#  'Радиоприемники Tivoli Audio PAL BT glossy blue/white',
#  'Радиоприемники Tivoli Audio Portable Audio Laboratory basic black (PALBLK)',
#  'Радиоприемники Tivoli Audio Portable Audio Laboratory earth brown (PALBRN)',
#  'Радиоприемники Tivoli Audio Portable Audio Laboratory high gloss blue',
#  'Радиоприемники Tivoli Audio Portable Audio Laboratory neon yellow (PALYEL)',
#  'Радиоприемники Tivoli Audio Portable Audio Laboratory spring green (PALGRN)',
#  'Многофункциональные часы Vitek VT-3526 ВК',
#  'Многофункциональные часы Vitek VT-3527 BK',
#  'Многофункциональные часы Vitek VT-3505 SR',
#  'Многофункциональные часы Vitek VT-3525 W',
#  'Многофункциональные часы Vitek VT-3516 BK',
#  'Многофункциональные часы Novis NCL-001',
#  'Многофункциональные часы Novis NCR-360',
#  'Многофункциональные часы Philips AJ3700',
#  'Радиоприемник Sangean PR-D4P',
#  'Радиоприемник Teac R-5 Red',
#  'Многофункциональные часы AEG MR 4129 White',
#  'Многофункциональные часы AEG MR 4129 Pink',
#  'Многофункциональные часы AEG TR 4131 Black-Silver',
#  'Многофункциональные часы AEG TR 4131 White-Silver',
#  'Многофункциональные часы AEG MRC 4117',
#  'Радиоприемник Сигнал БЗРП РП-308',
#  'Многофункциональные часы SUPRA SA-36FM',
#  'Многофункциональные часы SUPRA SA-16FM Black-Blue',
#  'Радиоприемник Сигнал БЗРП РП-311',
#  'Многофункциональные часы SUPRA SA-26FM',
#  'Радиобудильник Vitek VT-6600 черный',
#  'Радиобудильник Hyundai H-1552',
#  'Часы Ea2 FP107T c FM-радио, Титаниум, Виво)',
#  'Акустическая система Philips AJ3200/12',
#  'Радиоприемник портативный с mp3 MAX (бронза)',
#  'Многофункциональные часы BVItech BV-Q-17WSU',
#  'Часы Ea2 FP107B c FM-радио',
#  'Часы Ea2 FP107T c FM-радио',
#  'Многофункциональные часы SUPRA SA-42FMP White-White',
#  'Радиоприемник Max MR-310T 30008',
#  'Многофункциональные часы Rolsen CR-200',
#  'Радиоприемник Tivoli Audio Model One Frost White/Ember Red',
#  'Радиоприемник Tivoli Audio Model One Frost White/Sunflower Yellow',
#  'Мини-колонка Rombica Mysound BS-05A / SBS-0005A Aquamarine',
#  'Мини-колонка Rombica Mysound BS-04G / SBS-0004G Grey',
#  'Радиоприемник Сигнал Vikend Fisher',
#  'Радиоприемник Tivoli Audio PAL Electric Blue',
#  'Радиоприемник Tivoli Audio PAL Moonlight Gray',
#  'Радиоприемник Tivoli Audio PAL Neon Yellow',
#  'Радиоприемник Tivoli Audio PAL Red-Silver',
#  'Многофункциональные часы HARPER HRCB-7768',
#  'Гаджет Радио Hama SR-50 для ванной комнаты H-92682',
#  'Гаджет Радио для душа iBest BRC10 Green',
#  'Perfeo Dual Band Sound Ranger 2Вт+сабвуфер, FM+УКВ, MP3-плеер, белая',
#  'Perfeo Dual Band Sound Ranger 2Вт+сабвуфер, FM+УКВ, MP3-плеер, голубая',
#  'Perfeo Dual Band Sound Ranger 2Вт+сабвуфер, FM+УКВ, MP3-плеер, красная',
#  'Портативная колонка Perfeo Dual Band Sound Ranger, голубая 2W+Subwoofer, FM,MP3',
#  'Портативная колонка Perfeo Dual Band Sound Ranger, красная 2W+Subwoofer, FM,MP3',
#  'Портативная колонка Perfeo Dual Band Sound Ranger, черная 2W+Subwoofer, FM,MP3',
#  'Радиоприемник Kipo KB-308AC',
#  'Радиоприемник Kipo KB-988AC',
#  'Радиоприемник Tecsun PL-210',
#  'Радиоприемник Tecsun R202T',
#  'Радиоприемник Tecsun R303',
#  'Гаджет Радио Hama SR-90 для ванной комнаты H-92684',
#  'Радиоприемник Sony ICF-SW11/S',
#  'Радиобудильник Philips AJ3551/12',
#  'Радиоприемник Sony ICF-SW11',
#  'Радиоприемник Сигнал БЗРП РП-204',
#  'Радиоприемник Сигнал БЗРП РП-301',
#  'Радиоприемник Сигнал Vikend Tourist',
#  'Радиоприемник Сигнал БЗРП РП-313',
#  'Радиоприемник Сигнал БЗРП РП\xad-315',
#  'Радиоприемник Сигнал БЗРП РП-314',
#  'Радиоприемник Сигнал Vikend Patriot',
#  'Многофункциональные часы Philips AJ 3551',
#  'Радиоприемник Bosch GML 10,8 V-LI 0601429200',
#  'Радиоприемник SUPRA ST-125',
#  'Радиоприемник GoldStar GR-01URB',
#  'Проекционные часы с красной проекцией Uniel UTP-49YKx',
#  'Часы без проекции Uniel UTR-21WK',
#  'Часы без проекции Uniel UTR-21R',
#  'Часы без проекции Uniel UTR-23BSU',
#  'Часы без проекции Uniel UTR-25WSU',
#  'Часы без проекции Uniel UTR-33RRK',
#  'Часы без проекции Uniel UTR-33GGK',
#  'Многофункциональные часы VITEK VT-6605',
#  'Радиоприемник Сигнал БЗРП РП-318',
#  'Радиоприемник Сигнал БЗРП РП-316',
#  'Радиоприемник Сигнал БЗРП РП-317',
#  'Многофункциональные часы AEG MR 4104 Black',
#  'Радиоприемник Sangean U4 DBT',
#  'Радиоприемник Sangean DDR-62',
#  'Радиоприемник SUPRA ST-120 Black',
#  'Радиоприемник SUPRA ST-116 Black',
#  'Радиоприемник Bosch GML 50 POWER BOX 0601429600',
#  'Радиоприемник Eton Field',
#  'Радиоприемник Сигнал Vikend Tourist Black',
#  'Радиоприемник Сигнал РП-106 Silver',
#  'Многофункциональные часы SUPRA SA-40FM',
#  'Многофункциональные часы AEG MRC 4136 White',
#  'Многофункциональные часы AEG MRC 4140 i',
#  'Многофункциональные часы Hyundai H-1542 Black/Orange',
#  'Многофункциональные часы Hyundai H-1551 Black-Lilac',
#  'Многофункциональные часы Hyundai H-1552 Black-Orange',
#  'Многофункциональные часы Hyundai H-1550 Silver-White',
#  'Радиоприемник Rolsen RFM-100',
#  'Многофункциональные часы Rolsen CR-160W',
#  'Многофункциональные часы Rolsen CR-170W',
#  'Многофункциональные часы Rolsen CR-182',
#  'Многофункциональные часы Rolsen CR-210',
#  'Радиоприемник Philips AE1125',
#  'Радиоприемник Izumi MT-CF4333',
#  'Многофункциональные часы Vitek VT-6604 BK',
#  'Радиобудильник BVItech UTR-33RRKчёрно-синий',
#  'Многофункциональные часы Dialog AH-10',
#  'Многофункциональные часы teXet TRC-309 Black',
#  'Многофункциональные часы teXet TRC-309 White',
#  'Радиоприемник Rolsen RFM-320',
#  'Радиоприемник Sangean WR-12 Walnut',
#  'Радиоприемник Sangean PR-D14 White',
#  'Радиоприемник Sangean WFR-1Di',
#  'Радиоприемник Tivoli Audio Model Two Cherry/Taupe',
#  'Колонка Rombica Mysound BS-05A / SBS-0005A Aquamarine',
#  'Колонка Rombica Mysound BS-04G / SBS-0004G Grey',
#  'Радиоприемник Rolsen RBM-411VI Purple',
#  'Многофункциональные часы Philips AJ 3123',
#  'Многофункциональные часы Philips AJ1000/12',
#  'Радиоприемник Izumi NS-098U-REC',
#  'Радиоприемник Izumi R-739',
#  'Радиоприемник Сигнал Vikend Iron',
#  'Радиоприемник Сигнал Vikend Walk',
#  'Радиоприемник Сигнал РП-109 Black',
#  'Радиоприемник Сигнал РП-107 Black',
#  'Многофункциональные часы Philips AJ 3115',
#  'Радиоприемник Tivoli Audio Model One Frost White/Snow White',
#  'Радиоприемник Tivoli Audio Model Three Black/Silver',
#  'Многофункциональные часы teXet TRC-314 Black',
#  'Радиоприемник teXet TR-103',
#  'Радиоприемник Сигнал electronics Vikend Fisher',
#  'Радиоприемник Сигнал electronics БЗРП РП-313',
#  'Радиоприемник Сигнал electronics БЗРП РП-317',
#  'Радиоприемник Сигнал electronics Vikend Friends',
#  'Радиоприемник Сигнал electronics Vikend Patriot',
#  'Радиоприемник Сигнал electronics Эфир 02 Black',
#  'Радиоприемник Сигнал electronics Vikend Iron',
#  'Радиоприемник Сигнал electronics Vikend Walk',
#  'Радиоприемник teXet TR-303',
#  'Радиоприемник Sangean PR-D5 Silver / White',
#  'Радиоприемник Sangean ATS-405',
#  'Многофункциональные часы Mystery MCR-66 Black',
#  'Многофункциональные часы Mystery MCR-60 Silver',
#  'Uniel UTR-21WK // Метеоприбор Часы без проекции',
#  'Uniel UTR-33BBK // Метеоприбор Часы без проекции',
#  'Uniel UTP-49YKx // Метеоприбор Проекционные часы',
#  'Uniel UTR-23BSU // Метеоприбор Часы без проекции',
#  'Bvitech BV-48GWK // Метеоприбор Часы без проекции',
#  'Bvitech BV-48BWK // Метеоприбор Часы без проекции',
#  'Bvitech BV-46Wxx // Метеоприбор Часы без проекции',
#  'радиоприемник Philips AE-1530',
#  'радиоприемник Philips AJ 3700/12',
#  'радиоприемник Philips AE1850/00',
#  'радиоприемник Rolsen RBM521 SL серебристый',
#  'Автомагнитола Rolsen RBM 215 MUR-Black',
#  'радиоприемник Supra ST-110 black',
#  'радиоприемник Supra SA-28FM Black/red',
#  'радиоприемник Supra ST-109 грецкий орех',
#  'радиоприемник Supra ST-116 black',
#  'радиоприемник Supra SA-36 FM black/red',
#  'радиоприемник Supra ST-120 black',
#  'радиоприемник Tesler CR-330 White',
#  'Радиоприемник SUPRA ST-114 Silver',
#  'Rolsen RBM-411OR',
#  'Радиоприемник Makita BMR102',
#  'радиоприемник Supra ST-114 silver',
#  'Серия Winx Радиочасы Winx WX-4052',
#  'радиоприемник Rolsen RFM-110',
#  'радиоприемник Rolsen RFM-120',
#  'радиоприемник Supra SA-32FM black/amber',
#  'Радиоприемник SUPRA ST-119 Black',
#  'Радиоприемник GoldStar Jazz Silver',
#  'Радиоприемник GoldStar Jazz Black',
#  'магнитола Rolsen RBM 411 VI фиолетовый',
#  'MAX Радиоприемник портативный MR-330',
#  'MAX Радиоприемник портативный MR-331',
#  'радиоприемник Philips AE1850/00 черный',
#  'радиоприемник Philips AE1850/00 белый',
#  'Многофункциональные часы Hyundai H-1633U Red',
#  'Радиоприемник PlayBox Budapest Black PB-13-BK',
#  'Радиоприемник Tivoli Audio Model One Frost White/Kelly Green',
#  'Радиоприемник Tivoli Audio Model Three Cherry/Silver',
#  'Радиоприемник Teac R-5 White',
#  'Радиоприемник SUPRA PAS-3907',
#  'Радиоприемник MAX MR-331',
#  'Часы с красной проекцией Uniel UTP-49YKx',
#  'Unitel UTR-33GGK // Метеоприбор Часы без проекции',
#  'Радиоприемник портативный MAX MR-331',
#  'Многофункциональные часы teXet TRC-307 Black',
#  'Многофункциональные часы teXet TRC-307 White',
#  'Радиоприемник Metabo PowerMaxx RC 602113000',
#  'радиоприемник Rolsen RBM 215 MUR-Black',
#  'радиоприемник Rolsen RBM-217 серебристый',
#  'акустика GoldStar JAZZ black',
#  'акустика GoldStar JAZZ red',
#  'акустика GoldStar JAZZ silver',
#  'радиоприемник Sony SRF-18 черный',
#  'радиоприемник Supra ST-121',
#  'радиоприемник Supra ST-124U',
#  'радиоприемник SONY ICF-SW11/S',
#  'Радиоприемник Eton FRX-4',
#  'радиоприемник Philips AE 1125',
#  'Радиоприемник Kipo KB-409AC',
#  'Радиоприемник Сигнал electronics РП-107 Black',
#  'Многофункциональные часы Oregon Scientific RRM222P Green',
#  'акустика Supra PAS-3907 серый',
#  'Радиоприемник Rolsen RBM-216',
#  'Радиоприемник Сигнал electronics БЗРП РП-311',
#  'Радиоприемник Сигнал electronics БЗРП РП-301',
#  'радиоприемник Tesler CR-320 Black',
#  'Радиоприемник Rolsen RFM-300',
#  'радиоприемник Supra ST-122',
#  'Радиоприемники Tivoli Audio Model One black/black (M1BLK)',
#  'Радиоприемники Tivoli Audio Portable Audio Laboratory pearl white (PALPRL)',
#  'Радиоприемники Tivoli Audio Model One black/silver (M1SLB)',
#  'Радиоприемники Tivoli Audio Model Three classic walnut/beige (M3CLA)',
#  'Радиоприемники Tivoli Audio Model Two cherry/metallic taupe (M2TPE)',
#  'Радиоприемники Tivoli Audio Model Two cherry/silver (M2SLC)',
#  'Радиоприемники Tivoli Audio iPAL High Gloss Green/Silver (PALIPALGG)',
#  'Радиоприемники Tivoli Audio iPAL High Gloss Yellow/Silver (PALIPALGY)',
#  'Радиоприемники Tivoli Audio PAL BT glossy white/white',
#  'Радиоприемники Tivoli Audio PAL BT glossy red/white',
#  'Акустические системы Tivoli Audio Model 10 Stereo Speaker Walnut/Silver (M10SWL)',
#  'Радиоприемники Tivoli Audio Model One BT black/silver (M1BTSLB)',
#  'радиоприемник Panasonic RF-P50EG9-S',
#  'Радиоприемник Сигнал electronics Vikend Tourist Black',
#  'Радиоприемник SUPRA ST-126 Black',
#  'радиоприемник Hyundai H-1634UB белый/голубой',
#  'Метеостанция Vitek VT-6602',
#  'Часы VITEK VT-3504',
#  'Часы VITEK VT-6605',
#  'Часы Rolsen CR-182',
#  'Часы Philips AJ1000/12',
#  'Часы Philips AJ 3551',
#  'Часы Vitek VT-3526 ВК',
#  'Часы SUPRA SA-32FM Black-Amber',
#  'Часы SUPRA SA-38FM',
#  'Часы SUPRA SA-16FM Black-Blue',
#  'Часы SUPRA SA-26FM',
#  'Часы teXet TRC-305 Black',
#  'Часы teXet TRC-307 Black',
#  'Часы Rolsen CR-160W',
#  'Часы Rolsen CR-180',
#  'Часы Rolsen CR-210',
#  'Часы Dialog AH-10',
#  'Часы teXet TRC-309 Black',
#  'Часы teXet TRC-309 White',
#  'Часы teXet TRC-314 Black',
#  'Часы Vitek VT-6608 BK',
#  'Часы Vitek VT-6602 BK',
#  'Часы Mystery MCR-60 Silver',
#  'Часы Сигнал electronics CR-152',
#  'радиоприемник Ritmix RPR-7040',
#  'радиоприемник Tesler CR-250',
#  'радиоприемник Supra ST-126',
#  'Часы Telefunken TF-1636U',
#  'Часы AEG MRC 4136 White',
#  'Часы SUPRA SA-40FM',
#  'Часы Rolsen CR-200',
#  'Радиоприемник Сигнал electronics БЗРП РП\xad-315',
#  'Часы Telefunken TF-1635U',
#  'Радиоприемник Makita BMR 103B',
#  'Часы многофункциональные Philips AJ1000/12',
#  'Часы настольные AEG MRC 4136 White',
#  'Часы настольные SUPRA SA-40FM',
#  'Часы настольные Rolsen CR-200',
#  'Часы многофункциональные Philips AJ 3115',
#  'Часы многофункциональные VITEK VT-3504',
#  'Часы многофункциональные Vitek VT-3526 ВК',
#  'Часы многофункциональные VITEK VT-6605',
#  'Часы многофункциональные Vitek VT-3505 SR',
#  'Часы многофункциональные SUPRA SA-38FM',
#  'Часы многофункциональные SUPRA SA-16FM Black-Blue',
#  'Часы многофункциональные SUPRA SA-26FM',
#  'Часы многофункциональные Oregon Scientific RRM222P Green',
#  'Часы многофункциональные teXet TRC-305 Black',
#  'Часы многофункциональные teXet TRC-307 Black',
#  'Часы многофункциональные MAX CR 2905G',
#  'Часы многофункциональные Rolsen CR-160W',
#  'Часы многофункциональные Rolsen CR-170W',
#  'Часы многофункциональные Rolsen CR-180',
#  'Часы многофункциональные Rolsen CR-210',
#  'Часы многофункциональные Dialog AH-10',
#  'Часы многофункциональные teXet TRC-309 Black',
#  'Часы многофункциональные teXet TRC-309 White',
#  'Часы многофункциональные teXet TRC-314 Black',
#  'Часы многофункциональные Vitek VT-6604 BK',
#  'Часы многофункциональные Vitek VT-6608 BK',
#  'Часы многофункциональные Vitek VT-6602 W',
#  'Часы многофункциональные Mystery MCR-60 Silver',
#  'Часы настольные Telefunken TF-1635U',
#  'Часы настольные Philips AJ 3115',
#  'Часы настольные Vitek VT-3526 ВК',
#  'Часы настольные VITEK VT-6605',
#  'Часы настольные SUPRA SA-38FM',
#  'Часы настольные SUPRA SA-16FM Black-Blue',
#  'Часы настольные SUPRA SA-26FM',
#  'Часы настольные teXet TRC-305 Black',
#  'Часы настольные Rolsen CR-160W',
#  'Часы настольные Rolsen CR-170W',
#  'Часы настольные Rolsen CR-180',
#  'Часы настольные Rolsen CR-210',
#  'Часы настольные Dialog AH-10',
#  'Часы настольные teXet TRC-309 Black',
#  'Часы настольные teXet TRC-309 White',
#  'Часы настольные teXet TRC-314 Black',
#  'Часы настольные Vitek VT-6604 BK',
#  'Часы настольные Vitek VT-6608 BK',
#  'Часы настольные Vitek VT-6602 W',
#  'Часы настольные Mystery MCR-60 Silver',
#  'Часы настольные Сигнал electronics CR-152',
#  'Радиоприемник Eton FRX-5',
#  'Часы настольные SUPRA SA-32FM Black-Amber',
#  'Часы настольные Philips AJ2000',
#  'Радиоприемник SUPRA ST-122 black',
#  'Радиоприемник Sony ICF-S80 White',
#  'радиоприемник Telefunken TF-1625U фиолетовый',
#  'радиоприемник Telefunken TF-1625U оранжевый',
#  'Радиоприемник Сигнал electronics РП-106 Silver',
#  'Радиоприемник с часами Ibest BRC10 cиний',
#  'Радиобудильник BVItech BV-231BKUчёрный',
#  'Радиобудильник BVItech BV-449GPLчёрный',
#  'Радиобудильник Philips AJ1000',
#  'Радиобудильник MAX CR-2904w',
#  'Радиоприемник SUPRA ST-110 black',
#  'Радиоприемник Sony SRF-18 White',
#  'Акустическая система SUPRA PAS-3909 silver',
#  'Радиобудильник SUPRA SA-16FM black/blue',
#  'Радиобудильник SUPRA SA-32FM black/amber',
#  'Радиоприемник Rolsen RFM-110',
#  'Радиоприемник Сигнал electronics БЗРП РП-309',
#  'Часы настольные Philips AJ 3551',
#  'Радиоприемник Сигнал electronics БЗРП РП-318',
#  'Будильник световой PHILIPS HF 3510/70',
#  'Радиоприемник Rolsen CR-100W',
#  'Радиоприемник Сигнал electronics БЗРП РП-308',
#  'Часы настольные Rolsen CR-182',
#  'Радиоприемник Сигнал electronics БЗРП РП-316',
#  'Радиоприемник teXet TR-104 Black',
#  'Радиоприемник Rolsen CR-152',
#  'Радиоприемник Сигнал electronics РП-323',
#  'Часы настольные Philips AJ1000/12',
#  'Радиоприемник MAX M105C Panda Black 26001',
#  'Радиоприемник Panasonic RF-2400EE9-K',
#  'радиоприемник Ritmix RPR-404',
#  'Световой будильник Philips Wake-up Light HF3510',
#  'Радиоприемник Panasonic RF-2400EE-K',
#  'Часы настольные teXet TRC-321',
#  'Радиоприемник Globus GR-371',
#  'Радиоприемник MAX MR-332',
#  'Часы настольные teXet TRC-311 Black',
#  'Радиоприемник Сигнал electronics БЗРП РП-204',
#  'Часы настольные Vitek VT-6602 BK',
#  'Часы настольные teXet TRC-364',
#  'Часы настольные VITEK VT-3504',
#  'Радиоприемник Rolsen CR-142',
#  'Гаджет Радио для душа iBest BRC10 White',
#  'радиоприемник Rolsen RFM-450',
#  'радиоприемник Rolsen RFM-460',
#  'Радиоприемник Perfeo i70 Blue',
#  'Часы настольные Telefunken TF-1503U',
#  'Радиоприемник Perfeo Sound Voyager PF-SV521-OR Orange',
#  'Радиоприемник Perfeo i150',
#  'Радиоприемник Degen DE-1126',
#  'Радиоприемник Сигнал electronics Эфир 08 Black-Gray',
#  'Часы настольные teXet TRC-306',
#  'Радиобудильник Philips AJ 3551',
#  'Магнитола Rolsen RBM-412BL черный 6Вт/MP3/FM(an)/USB/SD/microSD',
#  'Радиоприемник Сигнал electronics Эфир 05 Black',
#  'Радиобудильник Rolsen CR-180',
#  'Радиоприемник Sony SRF-18 Bkack',
#  'Радиочасы Rolsen CR-160',
#  'Rolsen CR-160',
#  'Радиочасы Vitek VT-3520',
#  'Радиочасы Vitek VT-3523',
#  'Радиоприемники Tivoli Audio Model Two white/silver (M2WHT)',
#  'Радиоприемники Tivoli Audio iPAL White/Silver (PALIPAL)',
#  'Радиочасы Vitek VT-3517',
#  'Радиочасы Vitek VT-3527',
#  'Радиочасы Rolsen RFM-200',
#  'Магнитола Rolsen RBM-412BL черная',
#  'Радиоприемник Ritmix RPR-2061 Silver',
#  'Часы teXet TRC-306',
#  'Часы teXet TRC-321',
#  'Часы teXet TRC-364',
#  'Часы Telefunken TF-1503U',
#  'Часы проекционные Призма Oregon Scientific RRM222P с FM-радио',
#  'Радиоприемник MAX Панда с mp3',
#  'Радиобудильник Sony ICF-C1T красный',
#  'Магнитола Rolsen RBM-412BR коричневая',
#  'Радиоприемник Perfeo i70 СИНИЦА (i70-BL)',
#  'Радиоприемник Perfeo Sound Voyager PF-SV521-BL Blue',
#  'Радиочасы Rolsen CR-210',
#  'Радиоприемник Philips AE-1850/00',
#  'Радиоприемник Sony ICF-SW11 Silver',
#  'радио Радиоприемник MAX Панда с mp3',
#  'Радиочасы Vitek VT-6604',
#  'Радиоприемник Rolsen RBM-215MUR',
#  'радиоприемник Hyundai H-1549 (черный с красным)',
#  'Магнитола Rolsen RBM-411OR оранжевый 6Вт/MP3/FM(an)/USB/SD',
#  'Радиоприемник Makita MR052',
#  'Радиоприемник First FA-1903-2 Black',
#  'Радиоприемник First FA-1925-1 Black',
#  'Радиоприемник First FA-1925 Red',
#  'Радиоприемник First FA-1900-2',
#  'Часы First FA-2421-4 Black',
#  'Часы First FA-2419-3',
#  'Часы First FA-2410 Grey',
#  'Часы First FA-2406-4',
#  'Часы First FA-2406-2 White',
#  'Радиоприемник Sangean DDR-66BT Matt Black',
#  'Радиоприемник Sangean WFR-2D',
#  'Радиоприемники QED Q2 blue',
#  'Радиоприемник Perfeo PF-SV922 (SV922YL)',
#  'Радиоприемник Perfeo i70 СИНИЦА (i70-RED)',
#  'радиоприемник Supra SA-30FM Black/red',
#  'Радиоприемники Artsound R3B',
#  'Часы First FA-2416-1',
#  'Радиоприемник Max МR-290',
#  'Радиоприемник Max MR-310T',
#  'Радиоприемник MAX МR-290',
#  'Радиоприемник MAX MR-310T',
#  'Радиоприемник Philips AE1850/00',
#  'Часы First FA-2406-3',
#  'Часы Philips AJ2000',
#  'Часы Philips Wake-up Light HF3520',
#  'радиоприемник Sony ICF-C1T красный',
#  'радиоприемник Ritmix RPR-215',
#  'радиоприемник Ritmix RPR-707',
#  'Радиоприемник Luxele РП-111',
#  'радиоприемник Supra ST-115 silver',
#  'Радиобудильник Max CR-2906W черный',
#  'Колонка Активная Perfeo Sound Ranger (Fm,Flash,Micro Sd)',
#  'радиоприемник Philips AJ2000',
#  'VOX AC30 RADIO портативная колонка - радиоприемник',
#  'радиоприемник Harper HCLK-2041',
#  'радиоприемник Harper HRCB-7760',
#  'радиоприемник Vitek VT-3523 ВК',
#  'радиоприемник Vitek VT-3525 W',
#  'радиоприемник Vitek VT-3527 BK',
#  'радиоприемник Vitek VT-6607 GY',
#  'Радиоприемник Радио для душа iBest BRC10 White',
#  'Радиоприемник SUPRA ST-124U Black',
#  'Часы Vitek VT-3520 ВК',
#  'Радиоприемник Perfeo PF-SV922',
#  'Радиоприемник портативный MAX MR-330',
#  'Радиоприемник Telefunken TF-1634UB White-Blue',
#  'Радиоприемник TELEFUNKEN TF-1541 Black-Orange',
#  'Радиоприемник Telefunken TF-1506 Black-Amber',
#  'Радиоприемник Telefunken TF-1508 Black-Green',
#  'Радиоприемник Telefunken TF-1552 Black-White',
#  'Радиоприемник Telefunken TF-1566U Brown-Orange',
#  'Радиоприемник Telefunken TF-1575U Burgundy-Purple',
#  'Радиоприемник Telefunken TF-1575U Black Wood-Purple',
#  'Радиоприемник Telefunken TF-1571 White-Amber',
#  'Радиоприемник Telefunken TF-1572 Black-Amber',
#  'Радиоприемник Telefunken TF-1573 Black-Amber',
#  'Часы Telefunken TF-1634UB',
#  'Радиоприемник Vitek VT-3587',
#  'Радиоприемник Makita BMR050',
#  'Радиоприемник Telefunken TF-1574 Green-Amber',
#  'Радиоприемник Telefunken TF-1574 Red-Amber',
#  'Радиоприемник Globus GR-221 Red',
#  'Радиоприемник Globus GR-221 Black',
#  'Радиоприемник MAX MR-310T 30008',
#  'Часы First FA-2421-5 Black',
#  'Часы Vitek VT-6604 BK',
#  'Радиоприемник First FA-1903-2 White',
#  'Радиоприемник Telefunken TF-1570 Green-Amber',
#  'Радиоприемник TELEFUNKEN TF-1525 Black-White',
#  'Радиоприемник Bosch Pra Multipower 06039A9000',
#  'Часы Сигнал electronics CR-153',
#  'Часы Сигнал electronics CR-204',
#  'Радиоприемник Telefunken TF-1587 Black-Green',
#  'Радиоприемник SUPRA ST-108 Black',
#  'Радиоприемник First FA-1922',
#  'Часы SUPRA SA-45FM',
#  'Часы Hyundai H-RCL210 Black',
#  'Часы Hyundai H-RCL220 Black',
#  'Радиоприемник Telefunken TF-1586',
#  'Часы SUPRA SA-46FM',
#  'Часы SUPRA SA-44FM',
#  'Радиоприемник Tecsun ICR-110 Black',
#  'Радиоприемник Tecsun ICR-100',
#  'Часы Сигнал electronics CR-169',
#  'Радиоприемник Tecsun Q-3',
#  'Радиоприемник Luxele РП-118',
#  'Радиоприемник First FA-1925-1 Blue',
#  'Радиоприемник Telefunken TF-1634UB',
#  'Радиоприемник Telefunken TF-1634UB Turquoise',
#  'Радиоприемник Tecsun G-88',
#  'Радиоприемник Сигнал electronics БЗРП РП-325-1',
#  'Радиоприемник Hyundai H-SRS120',
#  'Радиоприемник Hyundai H-SRS100 Wenge',
#  'Часы Harper HCLK-2041',
#  'Часы Harper HRCB-7760',
#  'Часы Philips Wake-up Light HF3510/70',
#  'Радиоприемник Camry CR1158BT Black-Brown',
#  'Радиоприемник Telefunken TF-1586 Dark Wood',
#  'Радиоприемник Telefunken TF-1586 Red',
#  'Радиоприемник Telefunken TF-1505 Black-White',
#  'Радиоприемник Telefunken TF-1507 Black',
#  'Радиоприемник Philips AE 2160',
#  'Makita DMR200 Аудиопроигрыватель ак, 10.8-18В,Li-ion,2.8кг,порт USB, Bluetooth,вход AUX,б\\проводной',
#  'Радиоприемник Hyundai H-PSR120',
#  'Магнитола Bosch Pra Multipower 06039A9000',
#  'Sony SRF-18B черный Радиоприемник портативный',
#  'Радиоприемник настольный Hyundai H-SRS100 венге',
#  'Радиоприемник настольный Hyundai H-SRS120 вишня',
#  'Радиоприемник портативный Hyundai H-PSR120 серебристый',
#  'Радиоприемник портативный Hyundai H-RLC130 белый/серый',
#  'Philips AJ3551/12 Радиобудильник',
#  'MYSTERY MCR-78 silver Часы-будильник с РАДИО',
#  'Радиоприемник СИГНАЛ ELECTRONICS РП-232',
#  'RITMIX RPR-3021 черный-серебристый',
#  'Акустическая система с радио Max MR-360',
#  'Колонка Blast BAS-750 10021',
#  'Радиоприемник Tecsun Q-3 Black',
#  'Радиоприемник Tecsun ICR-110 Red',
#  'Радиоприемник Degen DE-321',
#  'Радиоприемник Tecsun Q-3 Red',
#  'Радиоприемник Tecsun Q-3 Blue',
#  'Радиоприемник Tecsun Q-3 Green',
#  'Портативная акустика Perfeo Sound Ranger 4-in-1 Blue',
#  'Радиобудильник Hyundai H-1549 Black',
#  'Радиоприёмник Hyundai H-PSR120',
#  'Радиобудильник Hyundai H-RCL200 Black',
#  'Радиобудильник Hyundai H-RCL210 Black',
#  'Радиобудильник Hyundai H-RCL230 Black',
#  'Радиоприёмник Hyundai H-RLС120',
#  'Радиоприёмник Hyundai H-RLC130',
#  'Радиоприёмник Hyundai H-RLC140',
#  'Радиоприёмник Hyundai H-SRS100',
#  'Радиоприёмник Hyundai H-SRS120',
#  'Радиоприёмник Hyundai H-SRS140',
#  'Радиоприёмник MAX MR-321 Black/Silver',
#  'Радиобудильник Oregon Scientific RRM116 Grey',
#  'Радиобудильник Oregon Scientific RRM116 White',
#  'Радиоприёмник Panasonic RF-3500',
#  'Радиоприёмник Ritmix RPR-101 Black',
#  'Радиобудильник Ritmix RRC-090 White',
#  'Радиобудильник Ritmix RRC-1212 Green',
#  'Радиобудильник Ritmix RRC-1250 White',
#  'Радиобудильник Ritmix RRC-1810 White',
#  'Радиоприёмник Sangean PR-D14',
#  'Радиобудильник Sangean PR-D4 White',
#  'Радиоприёмник Sangean WFR-28C White',
#  'Радиоприемник Sangean WR-22 Silver/Brown',
#  'Радиобудильник Supra SA-44FM',
#  'Радиобудильник Telefunken TF-1575U Bordo',
#  'Радиоприёмник Hyundai H-RLС130',
#  'Радиоприёмник Panasonic RF-P50DEG-S',
#  'Радиоприёмник Sangean WR-11BT Walnut',
#  'Радиоприёмник Сигнал БЗРП РП-304 Black',
#  'Радиоприёмник Сигнал БЗРП РП-320 Light Wood',
#  'Радиоприёмник Сигнал РП-230 Black',
#  'Радиоприёмник Сигнал Эфир-02 Black',
#  'Bosch Ак.радио GML 50 без акк и ЗУ 0601429600',
#  'Радиобудильник Ritmix RRC-616 Green',
#  'Радиобудильник Ritmix RRC-818 Black',
#  'Радиоприёмник Sangean WFR-29C Grey',
#  'Радиобудильник Sangean PR-D5P Black',
#  'Радиобудильник Telefunken TF-1570 Green',
#  'Часы Mystery MCR-21',
#  'Часы Mystery MCR-48',
#  'Часы Mystery MCR-68',
#  'Радиобудильник Telefunken TF-1588 Black',
#  'Радиобудильник Telefunken TF-1591 Black/White',
#  'Радиоприёмник Сигнал Luxele РП-114 White/Pink',
#  'HARPER HDRS-711',
#  'HARPER HDRS-788',
#  'LUXELE РП-114',
#  'PERFEO SOUND RANGER PF-SV922 красный',
#  'PERFEO SOUND RANGER PF-SV922 синий',
#  'PERFEO SOUND RANGER PF-SV922 черный',
#  'PERFEO ЕГЕРЬ FM+/MP3/USB красный (i120-RED)',
#  'PERFEO ЕГЕРЬ FM+/MP3/USB синий (i120-BL)',
#  'SONY ICF-C1B',
#  'VIKEND FRIENDS USB, SD',
#  'VIKEND WALK',
#  'БЗРП РП-301/СИГНАЛ РП-301 USB/SD',
#  'БЗРП РП-304/СИГНАЛ РП-304 USB/SD',
#  'БЗРП РП-306 USB/SD',
#  'ЛИРА РП-248',
#  'СИГНАЛ РП-107',
#  'СИГНАЛ РП-202',
#  'СИГНАЛ РП-221',
#  'СИГНАЛ РП-227',
#  'СИГНАЛ РП-229',
#  'СИГНАЛ РП-230',
#  'СИГНАЛ РП-232',
#  'ARESA AR-3904',
#  'HARPER HRCB-7760',
#  'HARPER HRCB-7768',
#  'MYSTERY MCR-23 черный/красный',
#  'MYSTERY MCR-69 черный/зеленый',
#  'RITMIX RRC-090 белый',
#  'VITEK VT-3520 ВК',
#  'Радиоприёмник Harper HDRS-711',
#  'HYUNDAI H-SRS200 вишня',
#  'Часы Philips AJ 3116',
#  'Радиобудильник Ritmix RRC-616 Red',
#  'RITMIX RPR-191',
#  'LUXELE РП-118 УКВ 64-108МГц, бат. 3*R20, 220V, дисплей, часы, будильник, белый',
#  'БЗРП РП-314 УКВ 64-108МГц, бат.3*R20, 220V, акб 1000mA/h, USB/SD',
#  'БЗРП РП-315 УКВ 88-108МГц, бат.4*R20, 220V, акб 900mA/h, USB/SD/AUX, 2 динамика, дисплей',
#  'БЗРП РП-318 УКВ 64-108МГц, 220V, USB/SD/AUX',
#  'БЗРП РП-324 УКВ 64-108МГц, бат. 2*R20, 220V, USB/microSD/AUX, лупа',
#  'СИГНАЛ РП-233 УКВ 64-108МГц, бат. 2*R20, 220V',
#  'LUXELE РП-111',
#  'Радиоприемник TELEFUNKEN TF-1588',
#  'Радиоприемники MAX MR-340 black edition',
#  'Часы Sony ICF-C1 Black',
#  'Часы Telefunken TF-1508 Black-Green',
#  'Часы Telefunken TF-1572 Black-Amber',
#  'Часы Telefunken TF-1586 Red',
#  'Часы Telefunken TF-1507 Black',
#  'Часы TELEFUNKEN TF-1588',
#  'Часы Telefunken TF-1570 Green-Amber',
#  'Часы Aresa AR-3904',
#  'Портативная акустика Ruark Audio R1 soft white',
#  'LUXELE РП-113 FM 64-108МГц, бат.2*R20, 220V, акб 1000mA/h, USB/SD/microSD/AUX/Bluetooth, белый',
#  'LUXELE РП-114 УКВ 64-108МГц, бат.3*AA, влагозащищенный, бело-розовый',
#  'VIKEND PATRIOT УКВ 64-108МГц, бат. 4*AA, 220V, акб 1400mA/h, USB/SD, 2 светодиодных фонаря',
#  'VIKEND WALK FM 88-108МГц, бат. 2*R20, 220V, акб1300мА/h,USB/SD/microSD/AUX, светодиодный фонарь',
#  'СИГНАЛ РП-230 FM 88-108МГц, бат. 3*R20, 220V, USB/microSD, дисплей, часы, будильник',
#  'СИГНАЛ РП-231 УКВ 64-108МГц, бат. 4*R20, 220V, USB/SD/AUX, светодиодный фонарь',
#  'Радиоприемник 31 ВЕК GD-185',
#  'Радиобудильник Hyundai H-RCL220 Black',
#  'Радиобудильник Harper HCLK-2041 White/Black',
#  'Часы Telefunken TF-1586 Dark Wood',
#  'Радиоприемник Telefunken TF-1583UB Light Wood',
#  'Часы Telefunken TF-1591 Black-White-Red',
#  'Радиоприемник Tecsun G-88 / GR-88',
#  'Радиоприёмник Sangean ATS-405 White',
#  'Часы Hyundai H-RCL200',
#  'Радиоприемник SUPRA ST-19',
#  'Радиоприемник SUPRA ST-15U',
#  'Радиоприемник SUPRA ST-21UR',
#  'Радиоприемник SUPRA ST-11',
#  'Радиобудильник Сигнал CR-169',
#  'Часы Telefunken TF-1503U Turquoise',
#  'Радиоприёмник Сигнал РП-231 Silver',
#  'AC30 RADIO',
#  'Радиоприемник Hyundai H-RCL230',
#  'Часы Hyundai H-RCL230',
#  'Радиоприёмник Сигнал РП-232 White/Black',
#  'Радиоприёмник Hyundai H-SRS160',
#  'Радиоприемник Max МR-321 черный',
#  'Радиоприемник Max MR-360',
#  'Радиобудильник Telefunken TF-1575U Black Wood',
#  'SUPRA ST-19 AM/FM/SW1-2',
#  'SUPRA ST-11 AM/FM',
#  'SUPRA ST-17 AM/FM/SW1-2',
#  'SUPRA SA-46FM черный с красным',
#  'RITMIX RRC-616 красный',
#  'RITMIX RRC-616 черный',
#  'Радиоприёмник Sangean H-201',
#  'Радиобудильник Sangean WR-2 Black',
#  'Радиоприёмник Sangean WR-7 Walnut',
#  'Радиоприёмник Sangean WR-7 White',
#  'Радиобудильник Telefunken TF-1575U Dark Wood',
#  'SUPRA SA-25FM черный с зелёным',
#  'SUPRA SA-45FM черный с зелёным',
#  'Радиоприёмник Сигнал РП-228',
#  'Радиобудильник Hyundai H-RCL220',
#  'Радиоприемник Hyundai H-SRS140',
#  'Радиоприемник TELEFUNKEN TF-1572(черный с янтарным)',
#  'Радиоприемник Hyundai H-SRS160 Cherry',
#  'Радиоприемник Hyundai H-RLC150 White',
#  'Радиоприемник Hyundai H-RLC140 White',
#  'Радиоприемники Vox AC30 radio',
#  'Радиоприёмник AEG MR 4139 BT Black',
#  'Радиобудильник AEG MRC 4143',
#  'Радиобудильник AEG MRC 4151 White',
#  'Радиобудильник Hyundai H-RCL180 Black',
#  'Радиобудильник AEG MRC 4150 Black',
#  'Радиоприёмник AEG WE 4125 White',
#  'Часы Hyundai H-RCL180 Black',
#  'Портативная акустика Ruark Audio R1MK3 rich walnut',
#  'Портативная акустика Ruark Audio R1MK3 soft black',
#  'RITMIX RPR-088 черный',
#  'SVEN SRP-525, серый',
#  'Радиоприемники QED Q2 black',
#  'Радиоприемники QED Q2 white',
#  'Радиоприемник Ritmix RPR-707 Camouflage Green',
#  'Радиоприёмник Hyundai H-PSR200',
#  'Радиоприемник TELEFUNKEN TF-1570(зеленый с янтарным)',
#  'радиоприемник Supra ST-21UR',
#  'радиоприемник Sony ICF-S 80',
#  'радиоприемник Hyundai H-PSR 100',
#  'RITMIX RPR-333 синий',
#  'BLAST BPR-610 шампань',
#  'BLAST BPR-705 черный',
#  'Metabo R\xa012-18\xa0 Радио без АКК и ЗУ 600776850',
#  'Metabo RC 12 Wild Cat AM/FM Радио-ЗУ Li-Ion10,8 В 602113000',
#  'Metabo R\xa012-18\xa0 Радио BT, Bluetooth, без АКК и ЗУ 600777850',
#  'Радиобудильник HARPER HCLK-2041 white led',
#  'Радиобудильник HARPER HRCB-7768 green led',
#  'Радиобудильник HARPER HRCB-7760 white led',
#  'Радиоприемник Harper HDRS-788',
#  'Радиобудильник Harper HCLK-2041',
#  'Радиобудильник Harper HRCB-7768',
#  'Часы Beurer WL30',
#  'WR-11 Wood',
#  'WR-11 Black',
#  'Радиоприемник Hyundai H-RLC130',
#  'SVEN SRP-355',
#  'Часы Telefunken TF-1506 Black-Amber',
#  'Часы First 2409-1-RF',
#  'Часы Beurer WL75',
#  'Радиоприемник Harper HDRS-788 черный',
#  'PERFEO ЕГЕРЬ FM+/MP3/USB коричневый (i120-BK)',
#  'Радиобудильник Oregon Scientific RRM222PN',
#  'HYUNDAI Часы с радио Black H-1535',
#  'MAKITA DMR200 Аудиопроигрыватель ак, {10.8-18В, Li-ion, 2.8кг, порт USB, Bluetooth, вход AUX, б\\проводной}',
#  'Радиоприемник HARPER HDRS-788',
#  'Радиоприемник VIKEND IRON УКВ 64-108МГц, бат. 3*R20, 220V, акб 1800mA/h, USB/SD/AUX, 2 светодиодных фонаря',
#  'Радиоприёмник SUPRA ST-15U AM/FM/SW1-7',
#  'Радиоприёмник SUPRA ST-21UR AM/FM/SW1-7',
#  'Радиоприёмник SUPRA ST-11 AM/FM',
#  'Радиочасы-будильник SUPRA SA-46FM черный с красным',
#  'Радиоприемник SUPRA ST-12 AM/FM/SW1-2',
#  'Радиочасы-будильник SUPRA SA-25FM черный с зелёным',
#  'Радиочасы-будильник SUPRA SA-44FM черный с красным',
#  'Радиоприемник RITMIX RPR-191',
#  'Радиоприемник BLAST BPR-812 шампань',
#  'Радиоприёмник SVEN SRP-355',
#  'радиочасы ARESA AR-3904',
#  'Радиоприемник Sangean WR-11 Walnut',
#  'BVItech BV-Q-17WSU часы с будильником',
#  'BVItech BV-231BKU комнатные часы',
#  'BVItech BV-46Wxx часы с радио',
#  'BVItech BV-48GWK круглые часы',
#  'BVItech BV-48BWK цифровые часы',
#  'Uniel UTP-49YKx электронные часы',
#  'Uniel UTR-21WK настольные часы с радио',
#  'Uniel UTR-23BSU часы-радиобудильник',
#  'Uniel UTR-25WSU стильные настольные часы',
#  'Uniel UTR-33RRK часы с радио',
#  'Oregon RRM116-g часы с радио',
#  'Oregon RRM116-r красные часы',
#  'Oregon RRM116-w компактные часы',
#  'Uniel UTR-21R часы без проекции',
#  'Oregon RRM222PN часы с проекцией на стену и на потолок',
#  'Радиочасы-будильник MYSTERY MCR-48 черный/красный',
#  'Радиочасы-будильник MYSTERY MCR-68 черный/красный',
#  'Радиоприемник BLAST BPR-610 золото',
#  'Радиоприемник BLAST BPR-610 шампань',
#  'Радиоприемник LUXELE РП-116 УКВ 64-108МГц, бат.4*AA, часы, дисплей, полотенце-держатель, влагозащищенный, белый',
#  'Часы Perfeo Foto PF-S6005 White',
#  'Часы настольные Philips Somneo HF3650',
#  'Радиочасы-будильник VITEK VT-3523 ВК',
#  'Радиобудильник Ritmix RRC-959 Black',
#  'Радиоприёмник Harper HDRS-288 Black',
#  'Радиоприёмник Harper HDRS-377 Black',
#  'Радиоприёмник Сигнал БЗРП РП-306 Black',
#  'Радиобудильник MYSTERY MCR-48 black&red.',
#  'Радиобудильник MYSTERY MCR-66 black',
#  'Радиобудильник Telefunken TF-1506 Black',
#  'Радиоприемник SVEN SRP-355 Red',
#  'Радиобудильник Harper HRCB-7760 белый/черный',
#  'Радиобудильник Ritmix RRC-1870T',
#  'Электронные часы Uniel UTP-49YKx с дневной проекцией',
#  'Часы с будильником BVItech BV-Q-17WSU электронные',
#  'Настольные большие часы BVItech BV-251WKU с радио',
#  'Комнатные часы BVItech BV-231BKU с подсветкой',
#  'Часы с радио BVItech BV-46Wxx настольные',
#  'Круглые часы BVItech BV-48GWK С MP3-проигрывателем',
#  'Цифровые часы BVItech BV-48BWK на батарейках',
#  'Настольные часы с радио Uniel UTR-21WK с будильником',
#  'Часы-радиобудильник Uniel UTR-23BSU для гостиной',
#  ...]

# %%
"""
...
The file triples.json contains the training triples and has the following format:
[0, 12692, 48199]
[0, 12693, 17664]
[1, 23783, 21169]
[1, 3796, 17104]
[1, 47897, 30084]
[2, 52241, 54085]
...
The first component is the id of the query, the second one the id of a relevant 
document and the third one the id of an irrelevant document.
"""

with open(f'{dst_fld}/triples_X1_{dst_name}.json', "a") as json:
    for index, row in df_triplets.iterrows():
        query_id = query_to_id[row['name']]
        true_match_id = document_to_id[row['true_match']]
        false_match_id = document_to_id[row['false_match']]

        json.write(f"[{query_id}, {true_match_id}, {false_match_id}]\n")

# %%
"""
Shuffle json and save
"""

def shuffle_wrt_file(output_file_path, lines):
    random.shuffle(lines)
    with open(output_file_path, 'w', encoding='utf-8') as output_file:
        output_file.writelines(lines)

# Открываем исходный файл для чтения
with open(f'{dst_fld}/triples_X1_{dst_name}.json', 'r', encoding='utf-8') as input_file:
    # Читаем строки из исходного файла
    lines = input_file.readlines()

output_file_path = f'{dst_fld}/triples_X1_{dst_name}_shuffle.json'

shuffle_wrt_file(output_file_path, lines)
print(f'Файл {output_file_path} успешно создан с перемешанным порядком строк.')

# %%
lines
