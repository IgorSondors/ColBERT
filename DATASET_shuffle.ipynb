# %%
import random

# Открываем исходный файл для чтения
input_file_path = '/home/sondors/Documents/price/ColBERT_data/13_categories/train/triples_X1_13_categories.json'
with open(input_file_path, 'r', encoding='utf-8') as input_file:
    # Читаем строки из исходного файла
    lines = input_file.readlines()

lines
# Out:
# ['[0, 7560, 12627]\n',
#  '[1, 1262, 26637]\n',
#  '[2, 14213, 28539]\n',
#  '[3, 18949, 22608]\n',
#  '[4, 19088, 1887]\n',
#  '[5, 28671, 17821]\n',
#  '[6, 21380, 26660]\n',
#  '[7, 23909, 10963]\n',
#  '[8, 8699, 18995]\n',
#  '[9, 22020, 1501]\n',
#  '[10, 24910, 10948]\n',
#  '[11, 20688, 26367]\n',
#  '[12, 16091, 9851]\n',
#  '[13, 21384, 3049]\n',
#  '[14, 14572, 21142]\n',
#  '[15, 14498, 4759]\n',
#  '[16, 27772, 6468]\n',
#  '[17, 27655, 14267]\n',
#  '[18, 2919, 10114]\n',
#  '[19, 12043, 4090]\n',
#  '[20, 12781, 11396]\n',
#  '[21, 14732, 27317]\n',
#  '[22, 29717, 8952]\n',
#  '[23, 13116, 3823]\n',
#  '[24, 10698, 12431]\n',
#  '[25, 3713, 3424]\n',
#  '[26, 21276, 19898]\n',
#  '[27, 18790, 18243]\n',
#  '[28, 614, 27302]\n',
#  '[29, 17187, 23472]\n',
#  '[30, 10694, 5075]\n',
#  '[31, 24246, 123]\n',
#  '[32, 25974, 23939]\n',
#  '[33, 23828, 10136]\n',
#  '[34, 26225, 12414]\n',
#  '[35, 133, 6254]\n',
#  '[36, 19248, 21255]\n',
#  '[37, 11046, 9735]\n',
# ...

# %%
# Перемешиваем порядок строк
random.shuffle(lines)

# Открываем новый файл для записи
output_file_path = '/home/sondors/Documents/price/ColBERT_data/13_categories/train/triples_X1_13_categories_shuffle.json'
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    # Записываем перемешанные строки в новый файл
    output_file.writelines(lines)

print(f'Файл {output_file_path} успешно создан с перемешанным порядком строк.')
# Out:
# Файл /home/sondors/Documents/price/ColBERT_data/13_categories/train/triples_X1_13_categories_shuffle.json успешно создан с перемешанным порядком строк.

# %%
lines
# Out:
# ['[334593, 14070, 3274]\n',
#  '[478739, 4062, 3040]\n',
#  '[252046, 8820, 25479]\n',
#  '[485957, 1775, 13466]\n',
#  '[15447, 22068, 12430]\n',
#  '[293662, 15647, 11521]\n',
#  '[611883, 9687, 11771]\n',
#  '[380282, 5091, 4028]\n',
#  '[214323, 13351, 3274]\n',
#  '[206663, 18860, 23085]\n',
#  '[147090, 24697, 20059]\n',
#  '[160630, 5692, 8821]\n',
#  '[93557, 24126, 16680]\n',
#  '[246165, 4478, 20029]\n',
#  '[253832, 28710, 467]\n',
#  '[320854, 24194, 13141]\n',
#  '[554989, 4111, 16351]\n',
#  '[371892, 27479, 24811]\n',
#  '[540617, 1853, 14872]\n',
#  '[412126, 27377, 5801]\n',
#  '[289756, 25308, 14848]\n',
#  '[71636, 10308, 29092]\n',
#  '[526267, 20309, 5250]\n',
#  '[317911, 14448, 26501]\n',
#  '[319543, 29952, 16714]\n',
#  '[485007, 21847, 27885]\n',
#  '[282491, 29640, 25571]\n',
#  '[378192, 22933, 12926]\n',
#  '[572580, 27667, 7414]\n',
#  '[191003, 21401, 22502]\n',
#  '[77555, 2609, 14751]\n',
#  '[471103, 4870, 13062]\n',
#  '[511041, 7037, 11976]\n',
# ...
