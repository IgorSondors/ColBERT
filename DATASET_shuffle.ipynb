# %%
import random

# Открываем исходный файл для чтения
input_file_path = '/mnt/vdb1/Datasets/ColBERT/18_categories/train/triples.json'
with open(input_file_path, 'r', encoding='utf-8') as input_file:
    # Читаем строки из исходного файла
    lines = input_file.readlines()

lines
# Out:
# ['[0, 75365, 31200]\n',
#  '[1, 10063, 2357]\n',
#  '[2, 75593, 13573]\n',
#  '[3, 5930, 72813]\n',
#  '[4, 28315, 45534]\n',
#  '[5, 80087, 46611]\n',
#  '[6, 1271, 46091]\n',
#  '[7, 60335, 75050]\n',
#  '[8, 31357, 13149]\n',
#  '[9, 14698, 14813]\n',
#  '[10, 76365, 3921]\n',
#  '[11, 64228, 37729]\n',
#  '[12, 73898, 44201]\n',
#  '[13, 10762, 22853]\n',
#  '[14, 21603, 40302]\n',
#  '[15, 65612, 25989]\n',
#  '[16, 51930, 15881]\n',
#  '[17, 27155, 55399]\n',
#  '[18, 72240, 30418]\n',
#  '[19, 54051, 29389]\n',
#  '[20, 43909, 53528]\n',
#  '[21, 39797, 57074]\n',
#  '[22, 1308, 37828]\n',
#  '[23, 16189, 77251]\n',
#  '[24, 75066, 73568]\n',
#  '[25, 75236, 49098]\n',
#  '[26, 49420, 78566]\n',
#  '[27, 11108, 45442]\n',
#  '[28, 2986, 78776]\n',
#  '[29, 57570, 60725]\n',
#  '[30, 45102, 15627]\n',
#  '[31, 59193, 6489]\n',
#  '[32, 56852, 6070]\n',
#  '[33, 38911, 71025]\n',
#  '[34, 11883, 1081]\n',
#  '[35, 22210, 58838]\n',
#  '[36, 32241, 54201]\n',
#  '[37, 56896, 23899]\n',
#  '[38, 33596, 11708]\n',
#  '[39, 57755, 28198]\n',
#  '[40, 63733, 2931]\n',
#  '[41, 8968, 37982]\n',
#  '[42, 49217, 30844]\n',
#  '[43, 57570, 60725]\n',
#  '[44, 13662, 76239]\n',
#  '[45, 79373, 72602]\n',
#  '[46, 50163, 71277]\n',
#  '[47, 67466, 34225]\n',
#  '[48, 3382, 53490]\n',
#  '[49, 54975, 29746]\n',
#  '[50, 30130, 17905]\n',
#  '[51, 50320, 59561]\n',
#  '[52, 15081, 40045]\n',
#  '[53, 18147, 11174]\n',
#  '[54, 22981, 54447]\n',
#  '[55, 24105, 42029]\n',
#  '[56, 50157, 31781]\n',
#  '[57, 9111, 79494]\n',
#  '[58, 23532, 43293]\n',
#  '[59, 6881, 50731]\n',
#  '[60, 64390, 5681]\n',
#  '[61, 45394, 56712]\n',
#  '[62, 21364, 257]\n',
#  '[63, 24580, 27841]\n',
#  '[64, 21304, 18711]\n',
#  '[65, 49698, 66183]\n',
#  '[66, 43357, 23179]\n',
#  '[67, 36960, 72877]\n',
#  '[68, 34934, 32246]\n',
#  '[69, 11361, 49098]\n',
#  '[70, 74132, 11749]\n',
#  '[71, 4566, 30883]\n',
#  '[72, 73011, 19992]\n',
#  '[73, 59140, 54558]\n',
#  '[74, 40471, 34566]\n',
#  '[75, 42065, 67006]\n',
#  '[76, 75580, 21084]\n',
#  '[77, 19021, 67872]\n',
#  '[78, 67574, 74983]\n',
#  '[79, 5341, 77793]\n',
#  '[80, 15549, 500]\n',
#  '[81, 18123, 24726]\n',
#  '[82, 51346, 42901]\n',
#  '[83, 37645, 16680]\n',
#  '[84, 34730, 1817]\n',
#  '[85, 27896, 62180]\n',
#  '[86, 30541, 6212]\n',
#  '[87, 19780, 44570]\n',
#  '[88, 29886, 54909]\n',
#  '[89, 28766, 63492]\n',
#  '[90, 42883, 1573]\n',
#  '[91, 8444, 30825]\n',
#  '[92, 68530, 39426]\n',
#  '[93, 7567, 73367]\n',
#  '[94, 470, 35882]\n',
#  '[95, 42378, 60685]\n',
#  '[96, 25178, 491]\n',
#  '[97, 20564, 49834]\n',
#  '[98, 46511, 47528]\n',
#  '[99, 40279, 76599]\n',
#  '[100, 44307, 69986]\n',
#  '[101, 40895, 14712]\n',
#  '[102, 62064, 52882]\n',
#  '[103, 5352, 1717]\n',
#  '[104, 57834, 64786]\n',
#  '[105, 70207, 66993]\n',
#  '[106, 42531, 66878]\n',
#  '[107, 57388, 69122]\n',
#  '[108, 63005, 40334]\n',
#  '[109, 31079, 28676]\n',
#  '[110, 19563, 59099]\n',
#  '[111, 28427, 77928]\n',
#  '[112, 76832, 52714]\n',
#  '[113, 43090, 57510]\n',
#  '[114, 71104, 23417]\n',
#  '[115, 11820, 20097]\n',
#  '[116, 69825, 1519]\n',
#  '[117, 126, 18574]\n',
#  '[118, 7522, 66031]\n',
#  '[119, 58443, 50058]\n',
#  '[120, 64437, 37377]\n',
#  '[121, 50225, 25928]\n',
#  '[122, 38163, 33214]\n',
#  '[123, 14745, 36108]\n',
#  '[124, 79958, 14173]\n',
#  '[125, 9781, 23742]\n',
#  '[126, 33069, 64478]\n',
#  '[127, 32683, 46532]\n',
#  '[128, 39570, 62818]\n',
#  '[129, 1469, 36428]\n',
#  '[130, 67810, 57892]\n',
#  '[131, 78669, 7063]\n',
#  '[132, 66325, 54030]\n',
#  '[133, 12142, 57986]\n',
#  '[134, 7556, 63520]\n',
#  '[135, 17819, 33746]\n',
#  '[136, 40210, 43896]\n',
#  '[137, 51852, 27193]\n',
#  '[138, 75865, 35811]\n',
#  '[139, 56246, 29276]\n',
#  '[140, 67027, 6601]\n',
#  '[141, 46347, 58670]\n',
#  '[142, 59209, 67844]\n',
#  '[143, 73935, 62660]\n',
#  '[144, 51547, 2517]\n',
#  '[145, 163, 48812]\n',
#  '[146, 71077, 15896]\n',
#  '[147, 76052, 71368]\n',
#  '[148, 9459, 30920]\n',
#  '[149, 70511, 41446]\n',
#  '[150, 32706, 50162]\n',
#  '[151, 54854, 35124]\n',
#  '[152, 20390, 46398]\n',
#  '[153, 77589, 79802]\n',
#  '[154, 13050, 4246]\n',
#  '[155, 36145, 5986]\n',
#  '[156, 18123, 24726]\n',
#  '[157, 1585, 21005]\n',
#  '[158, 48568, 4381]\n',
#  '[159, 48570, 55271]\n',
#  '[160, 27999, 61212]\n',
#  '[161, 3970, 78337]\n',
#  '[162, 48265, 53205]\n',
#  '[163, 18359, 13515]\n',
#  '[164, 55843, 55473]\n',
#  '[165, 76512, 44322]\n',
#  '[166, 50609, 30772]\n',
#  '[167, 78900, 20068]\n',
#  '[168, 49456, 6064]\n',
#  '[169, 45940, 55071]\n',
#  '[170, 17287, 12329]\n',
#  '[171, 30720, 24760]\n',
#  '[172, 60122, 56120]\n',
#  '[173, 59097, 65689]\n',
#  '[174, 62180, 27896]\n',
#  '[175, 20508, 46199]\n',
#  '[176, 11963, 13189]\n',
#  '[177, 59584, 58679]\n',
#  '[178, 9863, 77868]\n',
#  '[179, 60697, 20222]\n',
#  '[180, 16629, 56758]\n',
#  '[181, 62072, 69642]\n',
#  '[182, 40565, 4978]\n',
#  '[183, 2650, 37661]\n',
#  '[184, 30937, 17738]\n',
#  '[185, 49269, 48656]\n',
#  '[186, 63875, 8901]\n',
#  '[187, 79774, 73468]\n',
#  '[188, 28631, 46026]\n',
#  '[189, 1462, 4443]\n',
#  '[190, 33648, 65259]\n',
#  '[191, 4807, 70302]\n',
#  '[192, 52270, 1610]\n',
#  '[193, 491, 25178]\n',
#  '[194, 10882, 24628]\n',
#  '[195, 1978, 43686]\n',
#  '[196, 36734, 56933]\n',
#  '[197, 23591, 27167]\n',
#  '[198, 2779, 42892]\n',
#  '[199, 3019, 6945]\n',
#  '[200, 78852, 4656]\n',
#  '[201, 44559, 61219]\n',
#  '[202, 20985, 38467]\n',
#  '[203, 32632, 39515]\n',
#  '[204, 41177, 69989]\n',
#  '[205, 21116, 43715]\n',
#  '[206, 17287, 57249]\n',
#  '[207, 31506, 66318]\n',
#  '[208, 38031, 6617]\n',
#  '[209, 61118, 41468]\n',
#  '[210, 8371, 24278]\n',
#  '[211, 67728, 40583]\n',
#  '[212, 33706, 20945]\n',
#  '[213, 27334, 22175]\n',
#  '[214, 10809, 772]\n',
#  '[215, 22784, 77811]\n',
#  '[216, 2608, 66159]\n',
#  '[217, 26055, 22982]\n',
#  '[218, 76723, 9853]\n',
#  '[219, 7202, 25387]\n',
#  '[220, 21680, 30348]\n',
#  '[221, 70900, 32623]\n',
#  '[222, 60894, 67671]\n',
#  '[223, 47337, 43123]\n',
#  '[224, 32205, 68316]\n',
#  '[225, 61621, 50188]\n',
#  '[226, 935, 61572]\n',
#  '[227, 29733, 57487]\n',
#  '[228, 39583, 29347]\n',
#  '[229, 52753, 61607]\n',
#  '[230, 68682, 25465]\n',
#  '[231, 51688, 66434]\n',
#  '[232, 14400, 445]\n',
#  '[233, 31685, 77254]\n',
#  '[234, 7444, 12179]\n',
#  '[235, 11273, 51543]\n',
#  '[236, 15158, 12767]\n',
#  '[237, 15273, 48291]\n',
#  '[238, 37614, 54836]\n',
#  '[239, 42680, 63733]\n',
#  '[240, 72673, 71419]\n',
#  '[241, 9697, 32922]\n',
#  '[242, 27972, 48809]\n',
#  '[243, 69939, 28254]\n',
#  '[244, 62763, 18260]\n',
#  '[245, 55611, 30269]\n',
#  '[246, 19324, 43789]\n',
#  '[247, 77537, 76200]\n',
#  '[248, 40895, 14712]\n',
#  '[249, 49302, 48555]\n',
#  '[250, 74970, 57013]\n',
#  '[251, 48073, 46624]\n',
#  '[252, 39141, 44247]\n',
#  '[253, 17125, 78223]\n',
#  '[254, 257, 79964]\n',
#  '[255, 49302, 20790]\n',
#  '[256, 9694, 77092]\n',
#  '[257, 36620, 3520]\n',
#  '[258, 1278, 46144]\n',
#  '[259, 78586, 55922]\n',
#  '[260, 40154, 36655]\n',
#  '[261, 74970, 54075]\n',
#  '[262, 21066, 41399]\n',
#  '[263, 8904, 51057]\n',
#  '[264, 30048, 40253]\n',
#  '[265, 14462, 9397]\n',
#  '[266, 22162, 7471]\n',
#  '[267, 73981, 29851]\n',
#  '[268, 68571, 38720]\n',
#  '[269, 50315, 62734]\n',
#  '[270, 9197, 30041]\n',
#  '[271, 78101, 79160]\n',
#  '[272, 36542, 45186]\n',
#  '[273, 64024, 1447]\n',
#  '[274, 43357, 8727]\n',
#  '[275, 76058, 27763]\n',
#  '[276, 31313, 42078]\n',
#  '[277, 66866, 40271]\n',
#  '[278, 71416, 10214]\n',
#  '[279, 870, 20058]\n',
#  '[280, 65546, 31601]\n',
#  '[281, 9025, 50481]\n',
#  '[282, 13390, 39302]\n',
#  '[283, 49091, 15803]\n',
#  '[284, 24140, 34851]\n',
#  '[285, 29349, 36745]\n',
#  '[286, 68348, 37473]\n',
#  '[287, 10052, 74513]\n',
#  '[288, 25947, 74708]\n',
#  '[289, 52461, 46047]\n',
#  '[290, 15924, 5024]\n',
#  '[291, 532, 523]\n',
#  '[292, 77251, 16189]\n',
#  '[293, 66866, 37024]\n',
#  '[294, 16612, 7212]\n',
#  '[295, 24644, 5706]\n',
#  '[296, 9226, 16285]\n',
#  '[297, 47645, 11746]\n',
#  '[298, 72346, 41052]\n',
#  '[299, 32699, 22962]\n',
#  '[300, 59546, 72679]\n',
#  '[301, 30987, 73241]\n',
#  '[302, 67855, 18367]\n',
#  '[303, 34796, 35761]\n',
#  '[304, 60423, 78331]\n',
#  '[305, 24940, 6965]\n',
#  '[306, 46641, 7169]\n',
#  '[307, 37737, 55746]\n',
#  '[308, 9694, 77092]\n',
#  '[309, 21390, 27334]\n',
#  '[310, 49821, 35586]\n',
#  '[311, 18450, 24616]\n',
#  '[312, 470, 35882]\n',
#  '[313, 63166, 34055]\n',
#  '[314, 26494, 77931]\n',
#  '[315, 43971, 6588]\n',
#  '[316, 2985, 47397]\n',
#  '[317, 50502, 4836]\n',
#  '[318, 68555, 57964]\n',
#  '[319, 15858, 41755]\n',
#  '[320, 48361, 56556]\n',
#  '[321, 62756, 70758]\n',
#  '[322, 33924, 71543]\n',
#  '[323, 64500, 54774]\n',
#  '[324, 23591, 27167]\n',
#  '[325, 50466, 9618]\n',
#  '[326, 29903, 25188]\n',
#  '[327, 51688, 66434]\n',
#  '[328, 25168, 77251]\n',
#  '[329, 69058, 57451]\n',
#  '[330, 31531, 70680]\n',
#  '[331, 52512, 48940]\n',
#  '[332, 78727, 74183]\n',
#  '[333, 18517, 7648]\n',
#  '[334, 50203, 39067]\n',
#  '[335, 70153, 46396]\n',
#  '[336, 27901, 28940]\n',
#  '[337, 66727, 30415]\n',
#  '[338, 57392, 9413]\n',
#  '[339, 58258, 77584]\n',
#  '[340, 8444, 54638]\n',
#  '[341, 63520, 7556]\n',
#  '[342, 55085, 76422]\n',
#  '[343, 39466, 7549]\n',
#  '[344, 28426, 5980]\n',
#  '[345, 58596, 1343]\n',
#  '[346, 12683, 75736]\n',
#  '[347, 14900, 67948]\n',
#  '[348, 32144, 17492]\n',
#  '[349, 79144, 8580]\n',
#  '[350, 51226, 69294]\n',
#  '[351, 72448, 19062]\n',
#  '[352, 78896, 72571]\n',
#  '[353, 2328, 65624]\n',
#  '[354, 31506, 66318]\n',
#  '[355, 8166, 62551]\n',
#  '[356, 19190, 32350]\n',
#  '[357, 14376, 65799]\n',
#  '[358, 42327, 32868]\n',
#  '[359, 2288, 10533]\n',
#  '[360, 55651, 64616]\n',
#  '[361, 2501, 884]\n',
#  '[362, 20118, 48750]\n',
#  '[363, 26725, 40959]\n',
#  '[364, 69709, 55787]\n',
#  '[365, 23200, 23047]\n',
#  '[366, 12524, 21864]\n',
#  '[367, 70638, 38522]\n',
#  '[368, 17287, 12329]\n',
#  '[369, 26985, 69330]\n',
#  '[370, 14036, 51850]\n',
#  '[371, 1988, 9863]\n',
#  '[372, 45407, 25389]\n',
#  '[373, 33593, 41315]\n',
#  '[374, 70207, 66993]\n',
#  '[375, 54250, 77582]\n',
#  '[376, 53018, 9882]\n',
#  '[377, 26577, 23233]\n',
#  '[378, 25412, 12745]\n',
#  '[379, 53485, 31700]\n',
#  '[380, 68682, 25465]\n',
#  '[381, 9336, 10796]\n',
#  '[382, 23817, 76249]\n',
#  '[383, 491, 25178]\n',
#  '[384, 75342, 35223]\n',
#  '[385, 65094, 73533]\n',
#  '[386, 28330, 29794]\n',
#  '[387, 15760, 43901]\n',
#  '[388, 79550, 74702]\n',
#  '[389, 65777, 76157]\n',
#  '[390, 14851, 17536]\n',
#  '[391, 5930, 72813]\n',
#  '[392, 35743, 17571]\n',
#  '[393, 59140, 7369]\n',
#  '[394, 3438, 50463]\n',
#  '[395, 10454, 11150]\n',
#  '[396, 65052, 70343]\n',
#  '[397, 8904, 51057]\n',
#  '[398, 18988, 54438]\n',
#  '[399, 70142, 32460]\n',
#  '[400, 3382, 76694]\n',
#  '[401, 56613, 66017]\n',
#  '[402, 19780, 44570]\n',
#  '[403, 4249, 4622]\n',
#  '[404, 38331, 51176]\n',
#  '[405, 889, 37220]\n',
#  '[406, 11789, 6084]\n',
#  '[407, 60693, 26904]\n',
#  '[408, 17325, 69272]\n',
#  '[409, 22162, 7471]\n',
#  '[410, 71469, 72995]\n',
#  '[411, 1947, 9846]\n',
#  '[412, 23360, 64605]\n',
#  '[413, 34738, 12062]\n',
#  '[414, 43616, 42522]\n',
#  '[415, 41313, 22429]\n',
#  '[416, 50617, 47477]\n',
#  '[417, 43622, 17057]\n',
#  '[418, 11365, 40896]\n',
#  '[419, 38447, 21589]\n',
#  '[420, 74236, 78787]\n',
#  '[421, 18112, 33056]\n',
#  '[422, 63379, 37882]\n',
#  '[423, 20390, 46398]\n',
#  '[424, 38928, 16202]\n',
#  '[425, 16630, 53686]\n',
#  '[426, 5054, 34240]\n',
#  '[427, 75861, 63848]\n',
#  '[428, 74702, 66180]\n',
#  '[429, 25129, 25227]\n',
#  '[430, 52256, 52647]\n',
#  '[431, 72452, 13404]\n',
#  '[432, 7369, 59140]\n',
#  '[433, 41432, 44572]\n',
#  '[434, 11693, 66234]\n',
#  '[435, 57637, 66341]\n',
#  '[436, 24048, 44208]\n',
#  '[437, 38250, 5828]\n',
#  '[438, 65166, 55513]\n',
#  '[439, 17226, 43692]\n',
#  '[440, 57572, 47782]\n',
#  '[441, 61897, 21320]\n',
#  '[442, 19780, 51295]\n',
#  '[443, 66157, 57820]\n',
#  '[444, 1019, 23980]\n',
#  '[445, 43898, 63441]\n',
#  '[446, 20245, 30160]\n',
#  '[447, 59140, 7369]\n',
#  '[448, 53269, 11860]\n',
#  '[449, 34800, 67932]\n',
#  '[450, 2106, 68255]\n',
#  '[451, 23998, 33430]\n',
#  '[452, 28188, 5376]\n',
#  '[453, 34234, 1166]\n',
#  '[454, 57392, 60089]\n',
#  '[455, 10164, 25845]\n',
#  '[456, 53803, 38522]\n',
#  '[457, 58175, 11595]\n',
#  '[458, 25227, 36030]\n',
#  '[459, 76623, 17502]\n',
#  '[460, 75252, 4634]\n',
#  '[461, 14732, 26589]\n',
#  '[462, 30773, 41339]\n',
#  '[463, 35743, 17571]\n',
#  '[464, 30193, 44586]\n',
#  '[465, 31463, 2613]\n',
#  '[466, 1045, 64952]\n',
#  '[467, 55473, 25757]\n',
#  '[468, 19190, 58175]\n',
#  '[469, 52138, 73650]\n',
#  '[470, 6615, 73040]\n',
#  '[471, 79312, 4622]\n',
#  '[472, 24940, 6965]\n',
#  '[473, 8774, 51484]\n',
#  '[474, 24940, 6965]\n',
#  '[475, 17093, 24565]\n',
#  '[476, 32452, 48589]\n',
#  '[477, 48534, 16505]\n',
#  '[478, 32969, 16680]\n',
#  '[479, 37044, 44402]\n',
#  '[480, 58818, 24296]\n',
#  '[481, 57163, 64633]\n',
#  '[482, 57740, 37452]\n',
#  '[483, 68681, 43938]\n',
#  '[484, 45048, 20315]\n',
#  '[485, 2295, 54609]\n',
#  '[486, 33421, 2902]\n',
#  '[487, 63520, 52817]\n',
#  '[488, 40964, 61573]\n',
#  '[489, 48640, 17007]\n',
#  '[490, 1519, 69825]\n',
#  '[491, 63964, 48085]\n',
#  '[492, 17492, 36872]\n',
#  '[493, 53105, 27747]\n',
#  '[494, 6738, 28171]\n',
#  '[495, 69628, 5746]\n',
#  '[496, 18275, 77272]\n',
#  '[497, 70385, 38238]\n',
#  '[498, 52334, 71447]\n',
#  '[499, 19190, 58175]\n',
#  '[500, 8904, 51057]\n',
#  '[501, 20374, 19202]\n',
#  '[502, 70678, 33922]\n',
#  '[503, 13303, 46987]\n',
#  '[504, 19494, 40087]\n',
#  '[505, 74200, 25188]\n',
#  '[506, 46304, 53719]\n',
#  '[507, 25613, 47056]\n',
#  '[508, 51688, 66434]\n',
#  '[509, 1873, 74589]\n',
#  '[510, 24295, 35970]\n',
#  '[511, 69709, 59017]\n',
#  '[512, 7540, 11982]\n',
#  '[513, 46111, 71306]\n',
#  '[514, 28872, 47314]\n',
#  '[515, 46175, 42755]\n',
#  '[516, 63787, 50546]\n',
#  '[517, 48521, 713]\n',
#  '[518, 9644, 27965]\n',
#  '[519, 74948, 48431]\n',
#  '[520, 13998, 734]\n',
#  '[521, 27827, 64829]\n',
#  '[522, 59794, 2159]\n',
#  '[523, 18986, 13201]\n',
#  '[524, 21465, 47847]\n',
#  '[525, 14274, 38209]\n',
#  '[526, 70020, 72297]\n',
#  '[527, 76830, 29731]\n',
#  '[528, 29529, 47443]\n',
#  '[529, 19098, 50209]\n',
#  '[530, 22249, 48062]\n',
#  '[531, 38572, 78842]\n',
#  '[532, 21778, 55477]\n',
#  '[533, 19958, 34269]\n',
#  '[534, 25188, 29903]\n',
#  '[535, 71518, 66148]\n',
#  '[536, 62158, 58916]\n',
#  '[537, 14745, 36108]\n',
#  '[538, 29276, 56246]\n',
#  '[539, 30541, 54638]\n',
#  '[540, 49552, 48920]\n',
#  '[541, 77570, 49343]\n',
#  '[542, 51283, 6213]\n',
#  '[543, 18123, 24726]\n',
#  '[544, 3382, 53490]\n',
#  '[545, 56005, 51100]\n',
#  '[546, 28952, 59912]\n',
#  '[547, 43448, 21192]\n',
#  '[548, 43649, 22830]\n',
#  '[549, 64616, 55651]\n',
#  '[550, 42509, 17347]\n',
#  '[551, 43268, 54441]\n',
#  '[552, 51234, 8607]\n',
#  '[553, 69352, 32177]\n',
#  '[554, 16085, 79253]\n',
#  '[555, 32822, 197]\n',
#  '[556, 185, 69696]\n',
#  '[557, 30541, 6212]\n',
#  '[558, 73670, 74145]\n',
#  '[559, 48218, 9385]\n',
#  '[560, 5819, 27972]\n',
#  '[561, 40166, 40183]\n',
#  '[562, 38152, 41738]\n',
#  '[563, 15216, 66554]\n',
#  '[564, 70906, 30696]\n',
#  '[565, 63328, 16752]\n',
#  '[566, 57570, 60725]\n',
#  '[567, 26425, 72452]\n',
#  '[568, 52848, 10111]\n',
#  '[569, 68519, 19808]\n',
#  '[570, 14411, 17830]\n',
#  '[571, 51244, 17837]\n',
#  '[572, 47545, 44729]\n',
#  '[573, 51225, 24900]\n',
#  '[574, 3244, 39597]\n',
#  '[575, 21224, 58257]\n',
#  '[576, 71577, 39916]\n',
#  '[577, 48811, 33882]\n',
#  '[578, 41894, 74942]\n',
#  '[579, 54558, 29276]\n',
#  '[580, 7350, 52497]\n',
#  '[581, 5824, 11577]\n',
#  '[582, 4613, 36118]\n',
#  '[583, 71790, 12638]\n',
#  '[584, 24110, 54703]\n',
#  '[585, 50663, 26348]\n',
#  '[586, 41572, 28252]\n',
#  '[587, 73016, 78201]\n',
#  '[588, 28370, 5057]\n',
#  '[589, 8904, 25129]\n',
#  '[590, 58041, 67212]\n',
#  '[591, 73570, 78632]\n',
#  '[592, 61165, 80086]\n',
#  '[593, 47905, 27201]\n',
#  '[594, 38277, 74744]\n',
#  '[595, 38720, 33329]\n',
#  '[596, 44946, 57048]\n',
#  '[597, 19934, 46211]\n',
#  '[598, 4511, 74890]\n',
#  '[599, 12238, 12639]\n',
#  '[600, 45293, 34360]\n',
#  '[601, 70781, 65969]\n',
#  '[602, 27500, 6681]\n',
#  '[603, 25862, 24971]\n',
#  '[604, 8773, 38467]\n',
#  '[605, 64072, 24555]\n',
#  '[606, 27009, 67589]\n',
#  '[607, 66990, 53731]\n',
#  '[608, 3445, 62227]\n',
#  '[609, 56896, 23899]\n',
#  '[610, 23693, 46149]\n',
#  '[611, 25186, 47937]\n',
#  '[612, 24692, 64168]\n',
#  '[613, 54669, 71682]\n',
#  '[614, 61379, 23089]\n',
#  '[615, 61996, 55630]\n',
#  '[616, 42257, 29243]\n',
#  '[617, 21390, 27334]\n',
#  '[618, 9004, 20408]\n',
#  '[619, 31762, 66238]\n',
#  '[620, 61848, 62246]\n',
#  '[621, 13873, 20453]\n',
#  '[622, 7174, 19655]\n',
#  '[623, 52996, 30444]\n',
#  '[624, 58846, 56173]\n',
#  '[625, 25877, 60782]\n',
#  '[626, 74580, 55030]\n',
#  '[627, 52449, 27999]\n',
#  '[628, 79741, 79240]\n',
#  '[629, 55843, 55473]\n',
#  '[630, 70855, 6142]\n',
#  '[631, 75901, 34906]\n',
#  '[632, 12970, 58468]\n',
#  '[633, 77603, 11530]\n',
#  '[634, 35882, 470]\n',
#  '[635, 65698, 28319]\n',
#  '[636, 36056, 15566]\n',
#  '[637, 21598, 43307]\n',
#  '[638, 65183, 8338]\n',
#  '[639, 16789, 51602]\n',
#  '[640, 23292, 55770]\n',
#  '[641, 7556, 47563]\n',
#  '[642, 19934, 27034]\n',
#  '[643, 12908, 14180]\n',
#  '[644, 37451, 49723]\n',
#  '[645, 17723, 74591]\n',
#  '[646, 26740, 38447]\n',
#  '[647, 32699, 60835]\n',
#  '[648, 26904, 60020]\n',
#  '[649, 46641, 7169]\n',
#  '[650, 32764, 34605]\n',
#  '[651, 30844, 49217]\n',
#  '[652, 3772, 36992]\n',
#  '[653, 13741, 60378]\n',
#  '[654, 35347, 25747]\n',
#  '[655, 21603, 5092]\n',
#  '[656, 23786, 14284]\n',
#  '[657, 69042, 54334]\n',
#  '[658, 48148, 75320]\n',
#  '[659, 44372, 37709]\n',
#  '[660, 25241, 10157]\n',
#  '[661, 64176, 53809]\n',
#  '[662, 57014, 16306]\n',
#  '[663, 47563, 71131]\n',
#  '[664, 52002, 54739]\n',
#  '[665, 30649, 12889]\n',
#  '[666, 480, 26091]\n',
#  '[667, 44742, 65045]\n',
#  '[668, 69240, 25361]\n',
#  '[669, 37281, 72802]\n',
#  '[670, 25227, 25129]\n',
#  '[671, 52229, 71176]\n',
#  '[672, 74927, 57526]\n',
#  '[673, 61727, 7170]\n',
#  '[674, 39437, 55406]\n',
#  '[675, 17818, 53093]\n',
#  '[676, 55125, 40724]\n',
#  '[677, 10102, 67408]\n',
#  '[678, 68776, 37320]\n',
#  '[679, 58821, 35830]\n',
#  '[680, 67186, 46957]\n',
#  '[681, 74584, 923]\n',
#  '[682, 75375, 22365]\n',
#  '[683, 24569, 70571]\n',
#  '[684, 28170, 23663]\n',
#  '[685, 77415, 13100]\n',
#  '[686, 4249, 4622]\n',
#  '[687, 62793, 75788]\n',
#  '[688, 5527, 30691]\n',
#  '[689, 5026, 3335]\n',
#  '[690, 79183, 24310]\n',
#  '[691, 24612, 75005]\n',
#  '[692, 12497, 60651]\n',
#  '[693, 1468, 13262]\n',
#  '[694, 10471, 21493]\n',
#  '[695, 32822, 197]\n',
#  '[696, 34056, 74524]\n',
#  '[697, 12397, 34659]\n',
#  '[698, 43561, 51701]\n',
#  '[699, 75340, 53117]\n',
#  '[700, 41812, 65923]\n',
#  '[701, 32167, 19867]\n',
#  '[702, 4010, 24537]\n',
#  '[703, 34573, 5869]\n',
#  '[704, 61916, 29745]\n',
#  '[705, 59763, 72949]\n',
#  '[706, 5055, 10186]\n',
#  '[707, 26244, 44789]\n',
#  '[708, 14544, 63133]\n',
#  '[709, 42412, 7373]\n',
#  '[710, 51539, 73842]\n',
#  '[711, 51161, 18966]\n',
#  '[712, 39912, 68511]\n',
#  '[713, 49236, 6545]\n',
#  '[714, 64723, 61731]\n',
#  '[715, 74733, 43033]\n',
#  '[716, 22799, 45210]\n',
#  '[717, 50766, 44208]\n',
#  '[718, 26750, 72460]\n',
#  '[719, 57264, 31766]\n',
#  '[720, 36056, 57264]\n',
#  '[721, 19780, 51295]\n',
#  '[722, 55527, 79344]\n',
#  '[723, 36585, 3484]\n',
#  '[724, 32073, 54380]\n',
#  '[725, 75421, 78851]\n',
#  '[726, 38972, 27940]\n',
#  '[727, 21958, 1806]\n',
#  '[728, 44239, 79391]\n',
#  '[729, 16532, 47383]\n',
#  '[730, 54558, 29276]\n',
#  '[731, 71325, 25848]\n',
#  '[732, 61579, 63787]\n',
#  '[733, 41572, 45692]\n',
#  '[734, 31779, 50419]\n',
#  '[735, 27023, 71661]\n',
#  '[736, 51964, 68682]\n',
#  '[737, 48164, 38724]\n',
#  '[738, 79427, 8115]\n',
#  '[739, 49707, 13965]\n',
#  '[740, 19524, 58836]\n',
#  '[741, 22727, 33903]\n',
#  '[742, 4817, 10758]\n',
#  '[743, 76459, 74398]\n',
#  '[744, 19725, 2838]\n',
#  '[745, 17836, 74881]\n',
#  '[746, 38697, 25967]\n',
#  '[747, 4416, 61333]\n',
#  '[748, 34608, 46182]\n',
#  '[749, 34072, 27292]\n',
#  '[750, 15163, 58402]\n',
#  '[751, 16912, 22400]\n',
#  '[752, 39374, 57740]\n',
#  '[753, 4789, 74245]\n',
#  '[754, 19976, 29504]\n',
#  '[755, 50962, 67021]\n',
#  '[756, 2967, 20622]\n',
#  '[757, 21958, 1806]\n',
#  '[758, 31632, 54804]\n',
#  '[759, 42638, 4009]\n',
#  '[760, 667, 7098]\n',
#  '[761, 49655, 75193]\n',
#  '[762, 78597, 70793]\n',
#  '[763, 25129, 25227]\n',
#  '[764, 38700, 75458]\n',
#  '[765, 56832, 3961]\n',
#  '[766, 6736, 46750]\n',
#  '[767, 31762, 66238]\n',
#  '[768, 3689, 44965]\n',
#  '[769, 61902, 27524]\n',
#  '[770, 72283, 57632]\n',
#  '[771, 37155, 24809]\n',
#  '[772, 36280, 53138]\n',
#  '[773, 16250, 47719]\n',
#  '[774, 59710, 72943]\n',
#  '[775, 71431, 46975]\n',
#  '[776, 20271, 65422]\n',
#  '[777, 37403, 2850]\n',
#  '[778, 53787, 10296]\n',
#  '[779, 16899, 49556]\n',
#  '[780, 75400, 26437]\n',
#  '[781, 40081, 13816]\n',
#  '[782, 53763, 26704]\n',
#  '[783, 4430, 75188]\n',
#  '[784, 64265, 29002]\n',
#  '[785, 45102, 15627]\n',
#  '[786, 60007, 11781]\n',
#  '[787, 57249, 17287]\n',
#  '[788, 20709, 19469]\n',
#  '[789, 19780, 44570]\n',
#  '[790, 23614, 33350]\n',
#  '[791, 25227, 25129]\n',
#  '[792, 19739, 3244]\n',
#  '[793, 13449, 37253]\n',
#  '[794, 30571, 62605]\n',
#  '[795, 48421, 25185]\n',
#  '[796, 11003, 50603]\n',
#  '[797, 59964, 797]\n',
#  '[798, 70113, 20213]\n',
#  '[799, 74385, 74141]\n',
#  '[800, 8739, 22961]\n',
#  '[801, 8007, 14446]\n',
#  '[802, 49857, 37993]\n',
#  '[803, 57354, 44335]\n',
#  '[804, 21894, 30942]\n',
#  '[805, 36418, 6163]\n',
#  '[806, 7993, 18438]\n',
#  '[807, 59546, 1873]\n',
#  '[808, 60227, 50528]\n',
#  '[809, 13304, 79923]\n',
#  '[810, 3095, 62260]\n',
#  '[811, 54230, 58233]\n',
#  '[812, 1227, 71252]\n',
#  '[813, 18889, 42660]\n',
#  '[814, 1011, 48398]\n',
#  '[815, 59855, 17709]\n',
#  '[816, 39583, 29347]\n',
#  '[817, 30541, 6212]\n',
#  '[818, 24229, 4967]\n',
#  '[819, 455, 69503]\n',
#  '[820, 22961, 76203]\n',
#  '[821, 78790, 55405]\n',
#  '[822, 79665, 45751]\n',
#  '[823, 44606, 3598]\n',
#  '[824, 21675, 14225]\n',
#  '[825, 32336, 20418]\n',
#  '[826, 32718, 79561]\n',
#  '[827, 51964, 68682]\n',
#  '[828, 23752, 33791]\n',
#  '[829, 23548, 40822]\n',
#  '[830, 7239, 67508]\n',
#  '[831, 48321, 27312]\n',
#  '[832, 5930, 72813]\n',
#  '[833, 15235, 60258]\n',
#  '[834, 18215, 50761]\n',
#  '[835, 48347, 22162]\n',
#  '[836, 24644, 5706]\n',
#  '[837, 80170, 39539]\n',
#  '[838, 11395, 39782]\n',
#  '[839, 76924, 23279]\n',
#  '[840, 17287, 57249]\n',
#  '[841, 32124, 28282]\n',
#  '[842, 34076, 27372]\n',
#  '[843, 57173, 28142]\n',
#  '[844, 35623, 75867]\n',
#  '[845, 21362, 13837]\n',
#  '[846, 18964, 67436]\n',
#  '[847, 54558, 59140]\n',
#  '[848, 49707, 13965]\n',
#  '[849, 42680, 63733]\n',
#  '[850, 65196, 8868]\n',
#  '[851, 11273, 28283]\n',
#  '[852, 31327, 69415]\n',
#  '[853, 70257, 67738]\n',
#  '[854, 24798, 609]\n',
#  '[855, 59546, 72679]\n',
#  '[856, 1491, 16756]\n',
#  '[857, 9336, 10796]\n',
#  '[858, 70278, 49568]\n',
#  '[859, 53690, 64176]\n',
#  '[860, 26494, 77931]\n',
#  '[861, 68210, 71990]\n',
#  '[862, 44094, 72847]\n',
#  '[863, 59078, 49121]\n',
#  '[864, 59140, 7369]\n',
#  '[865, 34959, 49524]\n',
#  '[866, 4953, 58894]\n',
#  '[867, 23126, 48323]\n',
#  '[868, 6139, 3438]\n',
#  '[869, 71556, 38987]\n',
#  '[870, 10620, 7918]\n',
#  '[871, 73632, 76036]\n',
#  '[872, 61949, 26929]\n',
#  '[873, 60152, 17606]\n',
#  '[874, 79181, 73693]\n',
#  '[875, 66321, 26551]\n',
#  '[876, 46773, 53246]\n',
#  '[877, 18136, 71925]\n',
#  '[878, 29276, 56246]\n',
#  '[879, 76780, 1100]\n',
#  '[880, 68792, 38220]\n',
#  '[881, 56313, 20280]\n',
#  '[882, 35426, 7259]\n',
#  '[883, 74000, 44117]\n',
#  '[884, 21602, 76423]\n',
#  '[885, 25744, 16236]\n',
#  '[886, 40199, 21382]\n',
#  '[887, 25350, 60423]\n',
#  '[888, 36324, 44239]\n',
#  '[889, 12321, 5955]\n',
#  '[890, 16830, 18961]\n',
#  '[891, 27292, 70758]\n',
#  '[892, 4119, 49486]\n',
#  '[893, 56762, 36392]\n',
#  '[894, 52189, 63000]\n',
#  '[895, 65196, 4156]\n',
#  '[896, 57001, 59625]\n',
#  '[897, 41304, 53243]\n',
#  '[898, 50434, 79809]\n',
#  '[899, 24555, 1031]\n',
#  '[900, 24129, 62845]\n',
#  '[901, 383, 69262]\n',
#  '[902, 65933, 32]\n',
#  '[903, 55542, 23239]\n',
#  '[904, 78394, 64386]\n',
#  '[905, 5761, 61419]\n',
#  '[906, 42755, 58759]\n',
#  '[907, 75861, 78215]\n',
#  '[908, 21929, 3772]\n',
#  '[909, 23557, 78108]\n',
#  '[910, 25149, 21411]\n',
#  '[911, 40789, 61087]\n',
#  '[912, 38501, 37644]\n',
#  '[913, 17377, 6061]\n',
#  '[914, 49269, 48656]\n',
#  '[915, 68205, 21390]\n',
#  '[916, 33411, 17782]\n',
#  '[917, 44950, 34247]\n',
#  '[918, 44426, 74627]\n',
#  '[919, 35184, 1826]\n',
#  '[920, 66434, 61178]\n',
#  '[921, 68788, 23317]\n',
#  '[922, 63859, 3246]\n',
#  '[923, 8904, 25129]\n',
#  '[924, 45777, 34686]\n',
#  '[925, 19021, 76829]\n',
#  '[926, 62246, 24795]\n',
#  '[927, 77902, 60838]\n',
#  '[928, 78293, 55908]\n',
#  '[929, 13125, 10934]\n',
#  '[930, 39549, 644]\n',
#  '[931, 14005, 53097]\n',
#  '[932, 68705, 56912]\n',
#  '[933, 77437, 57513]\n',
#  '[934, 61848, 62246]\n',
#  '[935, 36699, 48316]\n',
#  '[936, 36555, 8604]\n',
#  '[937, 62495, 21057]\n',
#  '[938, 45175, 41815]\n',
#  '[939, 43234, 40056]\n',
#  '[940, 72032, 18877]\n',
#  '[941, 68174, 46276]\n',
#  '[942, 1100, 6139]\n',
#  '[943, 12891, 67794]\n',
#  '[944, 12111, 21305]\n',
#  '[945, 59553, 71909]\n',
#  '[946, 62763, 60280]\n',
#  '[947, 77830, 50562]\n',
#  '[948, 35970, 3445]\n',
#  '[949, 17578, 58330]\n',
#  '[950, 45196, 56972]\n',
#  '[951, 38801, 23010]\n',
#  '[952, 66817, 23107]\n',
#  '[953, 29794, 28330]\n',
#  '[954, 78443, 76506]\n',
#  '[955, 436, 19524]\n',
#  '[956, 33785, 49708]\n',
#  '[957, 77537, 53044]\n',
#  '[958, 46738, 40074]\n',
#  '[959, 37403, 2850]\n',
#  '[960, 7659, 78038]\n',
#  '[961, 21127, 1987]\n',
#  '[962, 68615, 47346]\n',
#  '[963, 15481, 5432]\n',
#  '[964, 23728, 17655]\n',
#  '[965, 60942, 32627]\n',
#  '[966, 66738, 42423]\n',
#  '[967, 52994, 48685]\n',
#  '[968, 30902, 19599]\n',
#  '[969, 61265, 14645]\n',
#  '[970, 63513, 6053]\n',
#  '[971, 56391, 74304]\n',
#  '[972, 26600, 35484]\n',
#  '[973, 64573, 30119]\n',
#  '[974, 47707, 68303]\n',
#  '[975, 30119, 32706]\n',
#  '[976, 25413, 37014]\n',
#  '[977, 66318, 17304]\n',
#  '[978, 78138, 11812]\n',
#  '[979, 53123, 75321]\n',
#  '[980, 55295, 44372]\n',
#  '[981, 46351, 51014]\n',
#  '[982, 43561, 34666]\n',
#  '[983, 38466, 36094]\n',
#  '[984, 19066, 12589]\n',
#  '[985, 27736, 66129]\n',
#  '[986, 28213, 52741]\n',
#  '[987, 8904, 25129]\n',
#  '[988, 76721, 65916]\n',
#  '[989, 6212, 15095]\n',
#  '[990, 78936, 30260]\n',
#  '[991, 797, 57267]\n',
#  '[992, 3884, 4497]\n',
#  '[993, 31766, 12911]\n',
#  '[994, 13803, 21248]\n',
#  '[995, 46862, 34681]\n',
#  '[996, 1489, 9079]\n',
#  '[997, 57013, 74970]\n',
#  '[998, 67480, 74483]\n',
#  '[999, 65538, 4416]\n',
#  ...]

# %%
# Перемешиваем порядок строк
random.shuffle(lines)

# Открываем новый файл для записи
output_file_path = '/mnt/vdb1/Datasets/ColBERT/18_categories/train/triples_shuffle.json'
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    # Записываем перемешанные строки в новый файл
    output_file.writelines(lines)

print(f'Файл {output_file_path} успешно создан с перемешанным порядком строк.')
# Out:
# Файл /mnt/vdb1/Datasets/ColBERT/18_categories/train/triples_shuffle.json успешно создан с перемешанным порядком строк.

# %%
lines
# Out:
# ['[336752, 71822, 53002]\n',
#  '[409540, 55385, 24864]\n',
#  '[593370, 5852, 33509]\n',
#  '[557139, 32144, 17492]\n',
#  '[1162586, 76228, 9046]\n',
#  '[94729, 29276, 56246]\n',
#  '[434514, 53490, 53606]\n',
#  '[964189, 36266, 24847]\n',
#  '[593746, 23188, 64649]\n',
#  '[17834, 64302, 27845]\n',
#  '[1140691, 23857, 46957]\n',
#  '[217253, 74589, 1873]\n',
#  '[527923, 45164, 27022]\n',
#  '[474301, 69102, 26463]\n',
#  '[60868, 6615, 73040]\n',
#  '[612067, 1653, 15705]\n',
#  '[1110589, 16099, 69280]\n',
#  '[663213, 12223, 16816]\n',
#  '[1135482, 40471, 34566]\n',
#  '[70498, 20988, 45052]\n',
#  '[260691, 14211, 37645]\n',
#  '[105446, 16097, 4979]\n',
#  '[276995, 25005, 815]\n',
#  '[881323, 72473, 67759]\n',
#  '[681439, 52476, 49136]\n',
#  '[160705, 19905, 23951]\n',
#  '[964925, 131, 17295]\n',
#  '[589829, 51666, 57748]\n',
#  '[598037, 38901, 782]\n',
#  '[975232, 1614, 51469]\n',
#  '[212550, 73792, 23477]\n',
#  '[69078, 26098, 76847]\n',
#  '[164925, 52011, 65783]\n',
#  '[120562, 29519, 65064]\n',
#  '[478702, 76978, 67737]\n',
#  '[682758, 3196, 14732]\n',
#  '[618329, 22299, 51433]\n',
#  '[986868, 12583, 26865]\n',
#  '[1019274, 20985, 54553]\n',
#  '[132183, 69360, 31527]\n',
#  '[806713, 36621, 57147]\n',
#  '[691664, 20903, 13787]\n',
#  '[758417, 64072, 24555]\n',
#  '[898825, 78662, 44939]\n',
#  '[47415, 47354, 66340]\n',
#  '[898005, 7893, 32717]\n',
#  '[1108202, 44938, 80114]\n',
#  '[857028, 55435, 7327]\n',
#  '[398264, 8844, 57865]\n',
#  '[389937, 27281, 199]\n',
#  '[1170763, 37495, 10005]\n',
#  '[402206, 42324, 26753]\n',
#  '[113776, 27072, 26732]\n',
#  '[84587, 39131, 19158]\n',
#  '[1163942, 44270, 60397]\n',
#  '[759537, 34934, 32246]\n',
#  '[202322, 6531, 64842]\n',
#  '[558028, 34269, 61199]\n',
#  '[755182, 55781, 16624]\n',
#  '[733791, 67346, 18016]\n',
#  '[722778, 51848, 43368]\n',
#  '[226720, 21127, 1987]\n',
#  '[519856, 51664, 54452]\n',
#  '[518112, 61953, 8773]\n',
#  '[732339, 68828, 8194]\n',
#  '[155990, 28033, 23021]\n',
#  '[27003, 18969, 10149]\n',
#  '[196866, 48811, 33882]\n',
#  '[626469, 32671, 76202]\n',
#  '[901737, 48347, 6079]\n',
#  '[590518, 51656, 79040]\n',
#  '[286089, 59546, 1873]\n',
#  '[301178, 18050, 78240]\n',
#  '[64434, 39951, 36684]\n',
#  '[322439, 24021, 18083]\n',
#  '[249638, 24175, 17538]\n',
#  '[751258, 72111, 68490]\n',
#  '[338817, 42890, 66560]\n',
#  '[1077380, 39141, 44247]\n',
#  '[885560, 73673, 57688]\n',
#  '[144110, 50172, 45021]\n',
#  '[286060, 37948, 27282]\n',
#  '[220870, 62885, 29956]\n',
#  '[67698, 52761, 47612]\n',
#  '[66336, 9391, 31303]\n',
#  '[665671, 48265, 53205]\n',
#  '[1136468, 54569, 27750]\n',
#  '[908321, 45804, 52083]\n',
#  '[697223, 16324, 22880]\n',
#  '[616087, 27513, 69531]\n',
#  '[174180, 74245, 35]\n',
#  '[999993, 52978, 61399]\n',
#  '[329618, 65313, 61221]\n',
#  '[393782, 13543, 11987]\n',
#  '[209429, 45033, 53137]\n',
#  '[1151722, 7204, 56061]\n',
#  '[1173677, 31212, 5402]\n',
#  '[289320, 24426, 22818]\n',
#  '[1095538, 9246, 37416]\n',
#  '[924095, 75050, 40142]\n',
#  '[371015, 34434, 66540]\n',
#  '[534007, 48421, 6545]\n',
#  '[141966, 49707, 13965]\n',
#  '[1123288, 56655, 23795]\n',
#  '[315310, 35727, 37369]\n',
#  '[376243, 76332, 2851]\n',
#  '[685951, 55629, 19223]\n',
#  '[345814, 63520, 7556]\n',
#  '[1128956, 34545, 20501]\n',
#  '[595160, 35699, 59301]\n',
#  '[693303, 63000, 20280]\n',
#  '[957682, 6285, 6067]\n',
#  '[667031, 54700, 71454]\n',
#  '[15611, 12118, 31696]\n',
#  '[171278, 13326, 61411]\n',
#  '[920340, 72046, 49466]\n',
#  '[246621, 20985, 54553]\n',
#  '[558017, 2312, 27134]\n',
#  '[567985, 56084, 30012]\n',
#  '[894595, 22249, 42170]\n',
#  '[297213, 5377, 56794]\n',
#  '[78043, 26312, 45865]\n',
#  '[1164276, 6160, 11719]\n',
#  '[843276, 73041, 61635]\n',
#  '[267245, 49193, 59229]\n',
#  '[1171093, 72044, 35121]\n',
#  '[1092123, 34143, 11208]\n',
#  '[656349, 19190, 32350]\n',
#  '[966413, 74700, 44740]\n',
#  '[1017664, 43902, 4393]\n',
#  '[1165665, 52949, 6573]\n',
#  '[731374, 40093, 56953]\n',
#  '[432722, 32124, 28282]\n',
#  '[560286, 470, 36932]\n',
#  '[966043, 44498, 33811]\n',
#  '[471761, 39779, 41018]\n',
#  '[1007746, 37198, 68552]\n',
#  '[849485, 72049, 11820]\n',
#  '[533570, 11970, 70796]\n',
#  '[451757, 17287, 57249]\n',
#  '[441971, 48709, 76303]\n',
#  '[917741, 73272, 44515]\n',
#  '[713242, 45937, 78087]\n',
#  '[931948, 39999, 55837]\n',
#  '[419191, 27951, 78371]\n',
#  '[947650, 27445, 36397]\n',
#  '[1177377, 37644, 38501]\n',
#  '[478029, 50137, 34281]\n',
#  '[513096, 2898, 73259]\n',
#  '[742703, 20936, 9158]\n',
#  '[1570, 32684, 50712]\n',
#  '[238545, 14792, 50673]\n',
#  '[1169853, 52692, 26449]\n',
#  '[160818, 4522, 45951]\n',
#  '[495935, 40791, 14923]\n',
#  '[531738, 59040, 17992]\n',
#  '[339203, 6577, 40592]\n',
#  '[637850, 2042, 44955]\n',
#  '[180683, 59150, 6722]\n',
#  '[539412, 10964, 7463]\n',
#  '[131634, 6965, 67090]\n',
#  '[687032, 14350, 77982]\n',
#  '[298903, 1619, 52894]\n',
#  '[662680, 44938, 80114]\n',
#  '[914045, 74182, 63765]\n',
#  '[152130, 68213, 65154]\n',
#  '[107509, 60971, 51464]\n',
#  '[783190, 37756, 16319]\n',
#  '[619213, 9891, 37804]\n',
#  '[521255, 9345, 52418]\n',
#  '[612519, 26148, 65701]\n',
#  '[901258, 75022, 48232]\n',
#  '[503263, 70645, 18294]\n',
#  '[950088, 6715, 52739]\n',
#  '[916124, 32077, 45134]\n',
#  '[356731, 3902, 61612]\n',
#  '[541116, 15256, 40835]\n',
#  '[820178, 51447, 72466]\n',
#  '[249105, 9336, 10796]\n',
#  '[728377, 76349, 42074]\n',
#  '[203877, 41481, 30571]\n',
#  '[301258, 532, 523]\n',
#  '[120223, 72895, 12189]\n',
#  '[77523, 15276, 74213]\n',
#  '[479466, 42925, 54667]\n',
#  '[354827, 11092, 28497]\n',
#  '[441157, 18389, 50578]\n',
#  '[1116311, 12405, 21970]\n',
#  '[277769, 41360, 53525]\n',
#  '[641467, 76830, 29731]\n',
#  '[567395, 9290, 80071]\n',
#  '[607172, 72584, 1796]\n',
#  '[898650, 46546, 49717]\n',
#  '[250569, 32983, 1116]\n',
#  '[623910, 972, 42749]\n',
#  '[245439, 29017, 46622]\n',
#  '[443298, 48811, 63452]\n',
#  '[1018053, 1459, 28058]\n',
#  '[1008528, 28940, 57453]\n',
#  '[1001122, 55129, 30955]\n',
#  '[1074747, 36571, 15429]\n',
#  '[114099, 14513, 37749]\n',
#  '[666374, 45499, 5080]\n',
#  '[404225, 51295, 19780]\n',
#  '[730664, 7033, 66622]\n',
#  '[706968, 71973, 59821]\n',
#  '[783168, 23054, 32744]\n',
#  '[234601, 35032, 72960]\n',
#  '[730178, 12061, 23422]\n',
#  '[777510, 2134, 75468]\n',
#  '[173404, 61139, 56262]\n',
#  '[258126, 57904, 51889]\n',
#  '[71030, 47165, 19933]\n',
#  '[762244, 25733, 71127]\n',
#  '[264025, 8377, 6866]\n',
#  '[86111, 76332, 74589]\n',
#  '[754302, 17811, 8353]\n',
#  '[322543, 17789, 41584]\n',
#  '[464401, 78531, 9036]\n',
#  '[451599, 18137, 47286]\n',
#  '[101315, 40992, 6680]\n',
#  '[835059, 75699, 68186]\n',
#  '[630840, 70511, 41446]\n',
#  '[1149977, 51136, 39016]\n',
#  '[838934, 3708, 3832]\n',
#  '[356078, 14310, 79579]\n',
#  '[639218, 60136, 26108]\n',
#  '[569951, 6690, 41609]\n',
#  '[535218, 35564, 26854]\n',
#  '[708565, 1035, 44277]\n',
#  '[947405, 52410, 68500]\n',
#  '[546919, 57286, 20118]\n',
#  '[543432, 43099, 2702]\n',
#  '[939791, 56092, 55042]\n',
#  '[404370, 32662, 50773]\n',
#  '[933296, 70316, 44181]\n',
#  '[300454, 40012, 22076]\n',
#  '[658129, 38148, 63518]\n',
#  '[846153, 40895, 21621]\n',
#  '[104787, 33386, 74830]\n',
#  '[446613, 40704, 19979]\n',
#  '[478513, 7078, 21671]\n',
#  '[1098457, 2817, 11765]\n',
#  '[818108, 64625, 42942]\n',
#  '[390919, 48015, 68881]\n',
#  '[121397, 37248, 46898]\n',
#  '[786494, 20271, 65422]\n',
#  '[336704, 21738, 74781]\n',
#  '[183390, 5281, 66881]\n',
#  '[10010, 25404, 66480]\n',
#  '[832659, 32194, 45977]\n',
#  '[1166123, 54558, 29276]\n',
#  '[417576, 4211, 19277]\n',
#  '[136521, 76138, 26848]\n',
#  '[743552, 26425, 72452]\n',
#  '[198723, 61033, 63151]\n',
#  '[292595, 49217, 51782]\n',
#  '[196699, 64564, 48230]\n',
#  '[96229, 3848, 21465]\n',
#  '[38278, 29180, 19692]\n',
#  '[572227, 12638, 71790]\n',
#  '[215171, 55293, 62589]\n',
#  '[1021140, 68120, 41017]\n',
#  '[1019272, 78111, 38448]\n',
#  '[518096, 38107, 35135]\n',
#  '[302262, 5407, 19717]\n',
#  '[22531, 59749, 24466]\n',
#  '[457059, 68855, 29941]\n',
#  '[210517, 75832, 71028]\n',
#  '[240630, 63054, 33685]\n',
#  '[404970, 34293, 24410]\n',
#  '[914879, 31463, 25747]\n',
#  '[592451, 12504, 75796]\n',
#  '[271313, 45351, 29905]\n',
#  '[1088239, 16478, 59967]\n',
#  '[40224, 67265, 67471]\n',
#  '[122415, 50190, 31762]\n',
#  '[1090479, 20482, 33520]\n',
#  '[627990, 18058, 34159]\n',
#  '[730333, 1873, 59546]\n',
#  '[1136301, 45355, 46126]\n',
#  '[1078309, 45293, 34360]\n',
#  '[227673, 11269, 70486]\n',
#  '[769996, 1568, 52132]\n',
#  '[33629, 16477, 850]\n',
#  '[1053075, 24644, 5706]\n',
#  '[154528, 45990, 72391]\n',
#  '[549622, 54787, 67749]\n',
#  '[742624, 11361, 49098]\n',
#  '[900389, 58939, 69074]\n',
#  '[88595, 46548, 48175]\n',
#  '[218077, 65699, 26895]\n',
#  '[481032, 46253, 68205]\n',
#  '[38010, 10510, 18241]\n',
#  '[849800, 64318, 76819]\n',
#  '[281908, 15272, 18732]\n',
#  '[171836, 46159, 46863]\n',
#  '[908548, 68025, 52600]\n',
#  '[519369, 14745, 62103]\n',
#  '[312489, 13724, 60591]\n',
#  '[164024, 22881, 26707]\n',
#  '[834997, 57986, 12142]\n',
#  '[605379, 31453, 76449]\n',
#  '[298388, 43686, 29129]\n',
#  '[520119, 68025, 52600]\n',
#  '[269459, 40942, 77733]\n',
#  '[112981, 350, 70336]\n',
#  '[1035148, 71580, 53719]\n',
#  '[676032, 37282, 77140]\n',
#  '[65185, 65471, 5055]\n',
#  '[603357, 197, 46761]\n',
#  '[248571, 42689, 45092]\n',
#  '[1109890, 26989, 13446]\n',
#  '[983, 38466, 36094]\n',
#  '[670639, 31806, 61228]\n',
#  '[693284, 66387, 15237]\n',
#  '[389604, 13620, 51295]\n',
#  '[165693, 77977, 72749]\n',
#  '[575104, 68136, 27060]\n',
#  '[958802, 69927, 78652]\n',
#  '[879098, 12593, 6071]\n',
#  '[913755, 75008, 49655]\n',
#  '[511042, 42901, 68064]\n',
#  '[189306, 42074, 55600]\n',
#  '[88067, 62479, 20975]\n',
#  '[180457, 73778, 13852]\n',
#  '[523455, 55129, 30955]\n',
#  '[160856, 20985, 38467]\n',
#  '[555534, 75236, 49098]\n',
#  '[207918, 76044, 33232]\n',
#  '[731536, 53442, 19000]\n',
#  '[776642, 46388, 75370]\n',
#  '[316367, 45178, 18418]\n',
#  '[751342, 3773, 48282]\n',
#  '[992822, 17287, 12329]\n',
#  '[74900, 1011, 48398]\n',
#  '[97098, 34814, 49580]\n',
#  '[1002997, 7531, 59805]\n',
#  '[898597, 76060, 11444]\n',
#  '[412128, 39121, 40823]\n',
#  '[504226, 71805, 26378]\n',
#  '[826320, 108, 34841]\n',
#  '[849423, 50470, 50440]\n',
#  '[716062, 12749, 62835]\n',
#  '[653029, 75375, 22365]\n',
#  '[290828, 30292, 72797]\n',
#  '[835857, 19780, 44570]\n',
#  '[300497, 9600, 49275]\n',
#  '[48939, 75785, 61671]\n',
#  '[622466, 77277, 76324]\n',
#  '[568132, 74876, 69435]\n',
#  '[1127785, 7958, 64974]\n',
#  '[219988, 67345, 65679]\n',
#  '[320331, 17287, 12329]\n',
#  '[245142, 66855, 55850]\n',
#  '[192267, 44091, 77748]\n',
#  '[239748, 10916, 54060]\n',
#  '[330113, 61076, 11581]\n',
#  '[616624, 67818, 59094]\n',
#  '[410001, 69399, 31604]\n',
#  '[1167997, 46566, 76685]\n',
#  '[615018, 51711, 9040]\n',
#  '[1027799, 26491, 28184]\n',
#  '[634329, 56816, 74024]\n',
#  '[95540, 63827, 55726]\n',
#  '[394925, 78123, 30403]\n',
#  '[891959, 49009, 25027]\n',
#  '[1173144, 79711, 28885]\n',
#  '[562103, 58268, 68618]\n',
#  '[563932, 23617, 31525]\n',
#  '[297271, 30228, 39654]\n',
#  '[58521, 43315, 52781]\n',
#  '[1052249, 65422, 54433]\n',
#  '[546487, 55843, 55473]\n',
#  '[616697, 49212, 18929]\n',
#  '[736301, 4024, 67050]\n',
#  '[117245, 46660, 20590]\n',
#  '[189115, 68568, 38117]\n',
#  '[1030735, 37643, 41555]\n',
#  '[823453, 7567, 73367]\n',
#  '[1104733, 23749, 10663]\n',
#  '[787207, 60566, 63486]\n',
#  '[270276, 64786, 31847]\n',
#  '[815133, 35228, 3357]\n',
#  '[1067268, 27444, 68631]\n',
#  '[712775, 51346, 42901]\n',
#  '[483786, 46051, 59883]\n',
#  '[300030, 15811, 2058]\n',
#  '[190121, 65371, 62916]\n',
#  '[1127027, 72049, 12540]\n',
#  '[867978, 51842, 7052]\n',
#  '[1112906, 77537, 76200]\n',
#  '[1008149, 18960, 38206]\n',
#  '[252314, 61380, 69002]\n',
#  '[979844, 4953, 58894]\n',
#  '[388849, 72384, 7871]\n',
#  '[307894, 2372, 66272]\n',
#  '[202600, 6615, 76368]\n',
#  '[897902, 24420, 60281]\n',
#  '[624750, 52526, 43441]\n',
#  '[1085266, 43498, 55632]\n',
#  '[459653, 48347, 22162]\n',
#  '[109684, 71638, 38696]\n',
#  '[197082, 61212, 79255]\n',
#  '[522815, 43384, 47981]\n',
#  '[135861, 65924, 51666]\n',
#  '[466587, 29713, 11696]\n',
#  '[473589, 78312, 73313]\n',
#  '[920620, 29040, 64055]\n',
#  '[248916, 39255, 43870]\n',
#  '[203374, 55570, 35126]\n',
#  '[868927, 4140, 4501]\n',
#  '[587348, 75805, 35365]\n',
#  '[276299, 20066, 10361]\n',
#  '[659585, 64409, 38431]\n',
#  '[813497, 59679, 45749]\n',
#  '[341436, 48498, 2387]\n',
#  '[543051, 45848, 54127]\n',
#  '[788200, 59773, 37452]\n',
#  '[847029, 28692, 76065]\n',
#  '[59100, 79754, 53801]\n',
#  '[74021, 19853, 63580]\n',
#  '[6657, 69240, 25361]\n',
#  '[708079, 33850, 49007]\n',
#  '[521065, 21382, 22928]\n',
#  '[163653, 15216, 66554]\n',
#  '[399372, 50994, 49236]\n',
#  '[412046, 359, 11666]\n',
#  '[953890, 465, 18130]\n',
#  '[619980, 2775, 48020]\n',
#  '[531036, 47563, 7556]\n',
#  '[432688, 64203, 72375]\n',
#  '[741047, 59408, 22530]\n',
#  '[594003, 13273, 37309]\n',
#  '[889367, 24644, 5706]\n',
#  '[861237, 2025, 7789]\n',
#  '[528153, 2526, 78586]\n',
#  '[175736, 74831, 11275]\n',
#  '[1118756, 9416, 69192]\n',
#  '[849969, 77830, 50562]\n',
#  '[410413, 32124, 28282]\n',
#  '[1071343, 43435, 42040]\n',
#  '[261616, 64252, 74002]\n',
#  '[975404, 60153, 58763]\n',
#  '[1001246, 57265, 13807]\n',
#  '[97994, 16530, 17167]\n',
#  '[170184, 29243, 74636]\n',
#  '[1101353, 27403, 35932]\n',
#  '[506727, 43389, 43182]\n',
#  '[942499, 4255, 52462]\n',
#  '[183055, 7701, 12987]\n',
#  '[360128, 40809, 4613]\n',
#  '[595474, 20488, 69580]\n',
#  '[339184, 45751, 35743]\n',
#  '[851171, 17861, 44082]\n',
#  '[541939, 47120, 28179]\n',
#  '[1009823, 6321, 22869]\n',
#  '[528946, 19091, 33744]\n',
#  '[867361, 70793, 77956]\n',
#  '[977073, 51447, 72466]\n',
#  '[788462, 32158, 52652]\n',
#  '[261574, 31762, 50190]\n',
#  '[314271, 27729, 33742]\n',
#  '[1026261, 16475, 72975]\n',
#  '[639028, 12213, 63890]\n',
#  '[359700, 40351, 36773]\n',
#  '[299286, 23990, 33358]\n',
#  '[717124, 11890, 12556]\n',
#  '[1176500, 48945, 21822]\n',
#  '[312843, 69213, 4891]\n',
#  '[654372, 68621, 10234]\n',
#  '[23441, 36091, 26425]\n',
#  '[285593, 60169, 58373]\n',
#  '[1119358, 65779, 39436]\n',
#  '[332361, 28762, 24988]\n',
#  '[743294, 77337, 74049]\n',
#  '[283276, 51706, 22363]\n',
#  '[959018, 49193, 59229]\n',
#  '[914011, 54669, 71682]\n',
#  '[1132945, 12116, 67038]\n',
#  '[417248, 13303, 46987]\n',
#  '[874117, 58535, 15542]\n',
#  '[481562, 20614, 64763]\n',
#  '[53225, 25465, 23532]\n',
#  '[411136, 57519, 57804]\n',
#  '[585888, 36844, 74496]\n',
#  '[516809, 61129, 47372]\n',
#  '[546335, 8747, 66326]\n',
#  '[706306, 36799, 42787]\n',
#  '[1129930, 17343, 20125]\n',
#  '[567642, 77146, 52880]\n',
#  '[992422, 38038, 9240]\n',
#  '[249247, 54050, 72019]\n',
#  '[970443, 8722, 73250]\n',
#  '[109923, 52797, 43051]\n',
#  '[436814, 59844, 1619]\n',
#  '[604914, 10164, 77958]\n',
#  '[325954, 46863, 27217]\n',
#  '[566762, 76141, 4079]\n',
#  '[419875, 1813, 37513]\n',
#  '[357193, 58416, 22196]\n',
#  '[115737, 55129, 30955]\n',
#  '[584075, 50672, 50568]\n',
#  '[187193, 63697, 57725]\n',
#  '[107605, 32407, 6618]\n',
#  '[88801, 30541, 54638]\n',
#  '[902217, 9952, 61758]\n',
#  '[969951, 61419, 5761]\n',
#  '[582708, 2613, 39141]\n',
#  '[536099, 28762, 56161]\n',
#  '[1013029, 4140, 55933]\n',
#  '[1075704, 77537, 76200]\n',
#  '[1113783, 25229, 59187]\n',
#  '[410946, 40565, 6038]\n',
#  '[472502, 11746, 47645]\n',
#  '[490553, 60456, 1378]\n',
#  '[281182, 32506, 30165]\n',
#  '[879154, 36883, 46597]\n',
#  '[208269, 25129, 25227]\n',
#  '[418756, 65630, 75833]\n',
#  '[773796, 44922, 11862]\n',
#  '[146551, 43498, 55632]\n',
#  '[455008, 56797, 46019]\n',
#  '[967997, 3990, 79130]\n',
#  '[767222, 32623, 70900]\n',
#  '[1041657, 43743, 70403]\n',
#  '[401963, 15719, 74717]\n',
#  '[744398, 58058, 32057]\n',
#  '[651069, 68662, 53992]\n',
#  '[799174, 56556, 37638]\n',
#  '[84788, 53829, 4121]\n',
#  '[1008247, 38447, 21589]\n',
#  '[68622, 58150, 52126]\n',
#  '[355734, 74784, 67884]\n',
#  '[183531, 52739, 6715]\n',
#  '[243812, 48778, 16535]\n',
#  '[908030, 10219, 14382]\n',
#  '[1084170, 31009, 30712]\n',
#  '[233283, 74806, 23426]\n',
#  '[766880, 15056, 57059]\n',
#  '[909159, 74245, 35]\n',
#  '[321716, 57786, 40578]\n',
#  '[960041, 37587, 30554]\n',
#  '[983443, 60238, 19183]\n',
#  '[557165, 76978, 67737]\n',
#  '[772049, 58821, 19245]\n',
#  '[150409, 18709, 1653]\n',
#  '[97375, 6135, 43425]\n',
#  '[594507, 9111, 8888]\n',
#  '[252203, 12739, 78760]\n',
#  '[191158, 34105, 68413]\n',
#  '[744170, 15451, 43767]\n',
#  '[444243, 57991, 74071]\n',
#  '[333750, 377, 25498]\n',
#  '[139368, 16354, 9718]\n',
#  '[373225, 68855, 29941]\n',
#  '[897729, 658, 49439]\n',
#  '[875177, 39504, 54352]\n',
#  '[145197, 20985, 54553]\n',
#  '[164542, 56246, 29276]\n',
#  '[842251, 63520, 52817]\n',
#  '[1090950, 43629, 10510]\n',
#  '[1054139, 48616, 51611]\n',
#  '[955427, 78652, 69927]\n',
#  '[909431, 18388, 34095]\n',
#  '[59345, 52215, 20856]\n',
#  '[435576, 37454, 18302]\n',
#  '[1149603, 46253, 56350]\n',
#  '[113046, 28832, 36468]\n',
#  '[455549, 72049, 11820]\n',
#  '[263335, 47630, 9965]\n',
#  '[804984, 25413, 37014]\n',
#  '[1040566, 14788, 79000]\n',
#  '[312275, 45934, 32876]\n',
#  '[911395, 14601, 70412]\n',
#  '[801980, 76739, 58472]\n',
#  '[1127323, 15777, 74143]\n',
#  '[204444, 37416, 70461]\n',
#  '[1073235, 62362, 74005]\n',
#  '[962677, 77537, 76200]\n',
#  '[731151, 51688, 66434]\n',
#  '[695889, 46738, 40074]\n',
#  '[43970, 72169, 67482]\n',
#  '[1168608, 42003, 74255]\n',
#  '[216876, 33329, 51964]\n',
#  '[1087003, 69400, 57753]\n',
#  '[871147, 3747, 45305]\n',
#  '[662301, 53269, 27961]\n',
#  '[526695, 57305, 57755]\n',
#  '[891724, 26053, 2693]\n',
#  '[893498, 20829, 74614]\n',
#  '[811022, 185, 69696]\n',
#  '[355255, 71405, 15769]\n',
#  '[341975, 35925, 52300]\n',
#  '[351028, 77537, 53044]\n',
#  '[357612, 62064, 52882]\n',
#  '[26661, 68656, 77985]\n',
#  '[752035, 44480, 78595]\n',
#  '[686537, 73499, 34597]\n',
#  '[1036704, 68155, 15699]\n',
#  '[1139757, 44986, 48653]\n',
#  '[133913, 35451, 48643]\n',
#  '[532981, 61015, 76187]\n',
#  '[760786, 55659, 22866]\n',
#  '[855879, 14295, 51808]\n',
#  '[538330, 8420, 37513]\n',
#  '[282215, 3884, 4497]\n',
#  '[916439, 71207, 29074]\n',
#  '[978103, 68327, 15508]\n',
#  '[513659, 43006, 17727]\n',
#  '[254700, 6208, 74276]\n',
#  '[317205, 59245, 5273]\n',
#  '[724051, 64850, 32360]\n',
#  '[256729, 32170, 70409]\n',
#  '[858540, 50324, 44199]\n',
#  '[1035683, 59140, 54558]\n',
#  '[1119678, 1472, 37759]\n',
#  '[162690, 14032, 40033]\n',
#  '[160712, 69725, 55261]\n',
#  '[832986, 70226, 79171]\n',
#  '[1162742, 22528, 4881]\n',
#  '[879643, 29451, 73142]\n',
#  '[387730, 57388, 14421]\n',
#  '[955574, 51940, 8946]\n',
#  '[890571, 714, 69810]\n',
#  '[712370, 9963, 43629]\n',
#  '[859202, 24559, 1996]\n',
#  '[1053393, 47563, 71131]\n',
#  '[1170874, 70616, 4901]\n',
#  '[95534, 50104, 58516]\n',
#  '[59307, 13151, 24771]\n',
#  '[501282, 62364, 22669]\n',
#  '[1051524, 31894, 64396]\n',
#  '[1173394, 77315, 32221]\n',
#  '[475750, 54515, 6596]\n',
#  '[1114138, 39811, 32781]\n',
#  '[1059219, 8444, 54638]\n',
#  '[87390, 70578, 27352]\n',
#  '[1021384, 1057, 80156]\n',
#  '[1172338, 73609, 4721]\n',
#  '[875523, 71561, 5003]\n',
#  '[155596, 10890, 78940]\n',
#  '[911565, 51964, 68682]\n',
#  '[123187, 64389, 78038]\n',
#  '[227319, 67041, 815]\n',
#  '[797731, 4566, 30883]\n',
#  '[804426, 16991, 18808]\n',
#  '[468967, 59618, 3502]\n',
#  '[1038663, 77904, 44941]\n',
#  '[314147, 72723, 69856]\n',
#  '[134914, 31370, 37775]\n',
#  '[104658, 67932, 34800]\n',
#  '[875894, 46859, 28423]\n',
#  '[1093555, 36258, 8869]\n',
#  '[381291, 50190, 48065]\n',
#  '[434338, 72452, 13404]\n',
#  '[252757, 42253, 51502]\n',
#  '[973189, 31665, 20688]\n',
#  '[262669, 2691, 49899]\n',
#  '[449695, 46699, 10334]\n',
#  '[653130, 62462, 4293]\n',
#  '[791322, 4271, 7604]\n',
#  '[384882, 8215, 8138]\n',
#  '[510642, 43467, 55606]\n',
#  '[50267, 8607, 51234]\n',
#  '[185789, 39116, 70316]\n',
#  '[810701, 50025, 1233]\n',
#  '[413729, 59145, 44138]\n',
#  '[477637, 62362, 74005]\n',
#  '[237081, 9607, 71528]\n',
#  '[975856, 68900, 36920]\n',
#  '[295677, 54558, 29276]\n',
#  '[892576, 35918, 74208]\n',
#  '[1134175, 48640, 17007]\n',
#  '[1032538, 39055, 2851]\n',
#  '[1067392, 54148, 66358]\n',
#  '[402818, 59931, 5672]\n',
#  '[819084, 78293, 55908]\n',
#  '[864908, 63826, 70184]\n',
#  '[940417, 35522, 22208]\n',
#  '[362288, 19958, 34269]\n',
#  '[531525, 53803, 28058]\n',
#  '[587625, 46566, 76685]\n',
#  '[1154531, 40993, 28837]\n',
#  '[631428, 46553, 14869]\n',
#  '[713711, 14851, 17536]\n',
#  '[1167424, 76978, 67737]\n',
#  '[683812, 18626, 54311]\n',
#  '[481680, 34796, 35761]\n',
#  '[589369, 62610, 32020]\n',
#  '[489353, 67501, 7498]\n',
#  '[460198, 45274, 30410]\n',
#  '[77550, 39583, 29347]\n',
#  '[1006715, 63520, 52817]\n',
#  '[240617, 63199, 63873]\n',
#  '[1013843, 74211, 43613]\n',
#  '[237486, 51356, 3490]\n',
#  '[786993, 25227, 25129]\n',
#  '[354789, 12778, 45221]\n',
#  '[647833, 42725, 31072]\n',
#  '[681483, 51964, 68682]\n',
#  '[449565, 27210, 28411]\n',
#  '[508540, 69828, 8388]\n',
#  '[1104442, 34522, 19365]\n',
#  '[206990, 6820, 10740]\n',
#  '[7441, 56712, 58096]\n',
#  '[228501, 69927, 45528]\n',
#  '[440739, 53341, 62012]\n',
#  '[55596, 53874, 75376]\n',
#  '[561108, 53872, 27773]\n',
#  '[234201, 66560, 42890]\n',
#  '[1053461, 23509, 65375]\n',
#  '[579391, 12757, 7826]\n',
#  '[510724, 69801, 72054]\n',
#  '[758924, 32181, 66603]\n',
#  '[273138, 44402, 75207]\n',
#  '[42514, 53667, 52261]\n',
#  '[753908, 21798, 77405]\n',
#  '[561221, 63520, 7556]\n',
#  '[173518, 23485, 67737]\n',
#  '[297668, 27919, 52328]\n',
#  '[153983, 51964, 68682]\n',
#  '[940902, 20006, 26087]\n',
#  '[43003, 34885, 78447]\n',
#  '[500003, 56223, 35363]\n',
#  '[510640, 63343, 74883]\n',
#  '[133504, 8469, 10856]\n',
#  '[770709, 61542, 59500]\n',
#  '[811222, 4506, 41138]\n',
#  '[165950, 21798, 77405]\n',
#  '[194436, 5884, 11173]\n',
#  '[1077292, 23739, 43758]\n',
#  '[812704, 20688, 70904]\n',
#  '[631011, 22925, 64357]\n',
#  '[878907, 30680, 35503]\n',
#  '[869191, 77616, 1546]\n',
#  '[747191, 44139, 69740]\n',
#  '[381333, 55129, 30955]\n',
#  '[451129, 62260, 15592]\n',
#  '[730899, 74414, 66868]\n',
#  '[167384, 33071, 31851]\n',
#  '[1083113, 45564, 31807]\n',
#  '[1121869, 78741, 25574]\n',
#  '[529350, 19949, 3363]\n',
#  '[58851, 19970, 55696]\n',
#  '[782515, 2977, 77104]\n',
#  '[274913, 59417, 27571]\n',
#  '[129825, 68626, 36281]\n',
#  '[397214, 57218, 39524]\n',
#  '[341301, 23040, 28219]\n',
#  '[896642, 60894, 6242]\n',
#  '[389029, 48679, 3226]\n',
#  '[114645, 54558, 59140]\n',
#  '[810503, 72369, 26033]\n',
#  '[171852, 46836, 73206]\n',
#  '[630810, 67396, 36278]\n',
#  '[940422, 54558, 59140]\n',
#  '[78862, 70142, 32460]\n',
#  '[886249, 63047, 68724]\n',
#  '[26228, 78400, 40090]\n',
#  '[70114, 75654, 75921]\n',
#  '[692351, 46948, 52582]\n',
#  '[1101544, 4249, 4622]\n',
#  '[153429, 56699, 26715]\n',
#  '[620595, 20829, 13649]\n',
#  '[1098258, 22162, 7471]\n',
#  '[332666, 1118, 43826]\n',
#  '[684721, 79450, 50368]\n',
#  '[834740, 39583, 62538]\n',
#  '[1113086, 68682, 25465]\n',
#  '[49792, 30902, 17487]\n',
#  '[786209, 68393, 30709]\n',
#  '[424709, 39327, 27990]\n',
#  '[918220, 15542, 58535]\n',
#  '[234867, 10768, 42677]\n',
#  '[873022, 28832, 69687]\n',
#  '[540117, 44606, 55042]\n',
#  '[996992, 30880, 40252]\n',
#  '[441597, 18905, 62046]\n',
#  '[745437, 61953, 8773]\n',
#  '[984478, 45156, 53729]\n',
#  '[953249, 77389, 10587]\n',
#  '[826839, 77763, 73997]\n',
#  '[132731, 33963, 16994]\n',
#  '[192569, 1247, 63015]\n',
#  '[119602, 25426, 28175]\n',
#  '[11526, 31762, 66238]\n',
#  '[990659, 34352, 8362]\n',
#  '[339960, 76779, 40751]\n',
#  '[723346, 19656, 28976]\n',
#  '[156611, 42420, 30818]\n',
#  '[306648, 50312, 63933]\n',
#  '[64829, 22444, 66201]\n',
#  '[193014, 7915, 59373]\n',
#  '[182174, 46642, 68421]\n',
#  '[1045549, 27737, 35628]\n',
#  '[176373, 59500, 52079]\n',
#  '[260456, 23376, 41302]\n',
#  '[603891, 56427, 20851]\n',
#  '[1125357, 3392, 15030]\n',
#  '[310480, 3598, 44606]\n',
#  '[135274, 25227, 25129]\n',
#  '[1119477, 7360, 61773]\n',
#  '[161857, 63306, 59094]\n',
#  '[951845, 53264, 21362]\n',
#  '[326934, 66930, 16750]\n',
#  '[1086277, 491, 25178]\n',
#  '[829553, 29649, 7106]\n',
#  '[896901, 4953, 58894]\n',
#  '[773490, 15208, 23081]\n',
#  '[1007113, 34512, 69804]\n',
#  '[807269, 4249, 4622]\n',
#  '[352621, 32106, 75242]\n',
#  '[15911, 72323, 56952]\n',
#  '[988984, 9134, 14172]\n',
#  '[639364, 77537, 76200]\n',
#  '[1116261, 2070, 2128]\n',
#  '[8248, 11781, 76598]\n',
#  '[181611, 49212, 74582]\n',
#  '[896578, 14112, 15968]\n',
#  '[384299, 47803, 45350]\n',
#  '[1077115, 34378, 17737]\n',
#  '[75507, 47994, 8122]\n',
#  '[1133256, 72673, 71419]\n',
#  '[711827, 8035, 62771]\n',
#  '[264156, 48062, 22249]\n',
#  '[961917, 18964, 67436]\n',
#  '[674924, 79697, 61551]\n',
#  '[22600, 49769, 9078]\n',
#  '[342521, 29162, 24340]\n',
#  '[143265, 2331, 15104]\n',
#  '[1133199, 63533, 24903]\n',
#  '[436385, 62756, 70758]\n',
#  '[711598, 27030, 59326]\n',
#  '[1147183, 7622, 9252]\n',
#  '[574081, 71299, 61233]\n',
#  '[248013, 7127, 53300]\n',
#  '[235657, 10063, 64729]\n',
#  '[714761, 74311, 2966]\n',
#  '[471265, 37908, 1185]\n',
#  '[425394, 51473, 40620]\n',
#  '[1089083, 33697, 23201]\n',
#  '[344545, 6832, 19938]\n',
#  '[701333, 3138, 51387]\n',
#  '[448922, 8444, 54638]\n',
#  '[1148187, 63607, 32488]\n',
#  '[606231, 28035, 35371]\n',
#  '[1112785, 33780, 58443]\n',
#  '[117929, 26090, 49362]\n',
#  '[690300, 76835, 45139]\n',
#  '[225152, 71758, 9259]\n',
#  '[752623, 58929, 66540]\n',
#  '[718006, 2636, 3057]\n',
#  '[689672, 57280, 5980]\n',
#  '[830031, 65538, 4416]\n',
#  '[142681, 32508, 34414]\n',
#  '[103447, 26293, 77349]\n',
#  '[302532, 67400, 65175]\n',
#  '[232746, 62023, 770]\n',
#  '[869464, 21067, 4668]\n',
#  '[932194, 14005, 53097]\n',
#  '[137374, 61388, 46439]\n',
#  '[1098618, 64356, 52844]\n',
#  '[711224, 6242, 77887]\n',
#  '[27283, 60500, 75451]\n',
#  '[229638, 11820, 20097]\n',
#  '[1151026, 62734, 50315]\n',
#  '[745993, 59364, 19725]\n',
#  '[818654, 14211, 37645]\n',
#  '[388793, 8773, 61953]\n',
#  '[821534, 44962, 74958]\n',
#  '[630712, 29965, 47215]\n',
#  '[568326, 50791, 76208]\n',
#  '[552594, 40953, 4505]\n',
#  '[104383, 80073, 49973]\n',
#  '[360141, 6895, 68573]\n',
#  '[674016, 17016, 78773]\n',
#  '[184842, 33710, 31658]\n',
#  '[646427, 31296, 72856]\n',
#  '[380551, 52817, 63520]\n',
#  '[958647, 11122, 69979]\n',
#  '[618744, 3938, 49669]\n',
#  '[633709, 30902, 19599]\n',
#  '[887104, 44841, 13065]\n',
#  '[587112, 79697, 61551]\n',
#  '[523558, 106, 5734]\n',
#  '[421580, 55861, 50268]\n',
#  '[210872, 12524, 21864]\n',
#  '[466552, 7239, 67508]\n',
#  '[367144, 76398, 28645]\n',
#  '[176587, 33092, 71011]\n',
#  '[342298, 11302, 79237]\n',
#  '[735956, 47287, 21510]\n',
#  '[1069481, 34738, 12062]\n',
#  '[308269, 27500, 78527]\n',
#  '[1022581, 68136, 27060]\n',
#  '[59026, 44413, 30343]\n',
#  '[683247, 69166, 38012]\n',
#  '[657735, 6478, 52496]\n',
#  '[808331, 19780, 51295]\n',
#  '[627762, 3964, 12096]\n',
#  '[820872, 61379, 23089]\n',
#  '[622535, 6545, 49236]\n',
#  '[1080787, 44460, 11098]\n',
#  '[1143773, 35904, 61479]\n',
#  '[1012742, 77722, 73270]\n',
#  '[845508, 16848, 16217]\n',
#  '[652803, 27592, 46349]\n',
#  '[634572, 75320, 39924]\n',
#  '[1024253, 7236, 70672]\n',
#  '[957917, 38451, 24970]\n',
#  '[1052977, 35228, 3357]\n',
#  '[175222, 27334, 22175]\n',
#  '[785497, 32162, 374]\n',
#  '[245436, 28045, 41166]\n',
#  '[979725, 39528, 32906]\n',
#  '[1111352, 26354, 37845]\n',
#  '[268213, 67501, 7498]\n',
#  '[268457, 37042, 58204]\n',
#  '[286443, 4047, 43294]\n',
#  '[150578, 8275, 60126]\n',
#  '[1122265, 26655, 67930]\n',
#  '[652800, 29513, 14716]\n',
#  '[1068074, 56070, 66102]\n',
#  '[673246, 46719, 15535]\n',
#  '[304010, 78520, 16941]\n',
#  '[679208, 20698, 25703]\n',
#  '[953263, 18969, 10149]\n',
#  '[199768, 55020, 60835]\n',
#  '[311980, 68119, 50683]\n',
#  '[5918, 55178, 56116]\n',
#  '[507589, 31766, 12911]\n',
#  '[1076779, 39819, 27423]\n',
#  '[965049, 16583, 10411]\n',
#  '[912804, 5047, 56683]\n',
#  '[529345, 39058, 37555]\n',
#  '[338813, 24597, 59480]\n',
#  '[724217, 45187, 58416]\n',
#  '[1921, 470, 35882]\n',
#  '[106857, 42475, 1125]\n',
#  '[500870, 16585, 30129]\n',
#  '[906063, 21329, 32606]\n',
#  '[254466, 77575, 30190]\n',
#  '[22660, 22881, 26707]\n',
#  '[175869, 4903, 1333]\n',
#  '[282744, 48148, 75320]\n',
#  '[161268, 21250, 67637]\n',
#  '[1032161, 51107, 33895]\n',
#  '[340926, 16602, 24863]\n',
#  '[580836, 39055, 2851]\n',
#  '[991653, 61222, 47234]\n',
#  '[219193, 44786, 13475]\n',
#  '[154679, 11857, 18277]\n',
#  '[499877, 46746, 65183]\n',
#  '[734537, 77239, 43168]\n',
#  '[530086, 20903, 13787]\n',
#  '[304425, 40237, 27136]\n',
#  '[431693, 23365, 71975]\n',
#  '[583532, 38031, 11595]\n',
#  '[426859, 4497, 3884]\n',
#  '[838048, 67373, 46692]\n',
#  '[138196, 27337, 12385]\n',
#  '[130552, 58590, 2835]\n',
#  '[473815, 8844, 57865]\n',
#  '[1082253, 58129, 42759]\n',
#  '[188451, 11479, 48272]\n',
#  '[1070410, 48869, 48647]\n',
#  '[862890, 9856, 41091]\n',
#  '[743041, 55042, 56092]\n',
#  '[895376, 42325, 27357]\n',
#  '[680722, 22229, 29448]\n',
#  '[158072, 69475, 11095]\n',
#  '[780253, 52311, 42854]\n',
#  '[751424, 48054, 30302]\n',
#  '[1121035, 38872, 27315]\n',
#  '[1176607, 61925, 45693]\n',
#  '[935850, 48265, 17386]\n',
#  '[1046763, 66083, 11642]\n',
#  '[750397, 21127, 53640]\n',
#  '[732456, 59955, 70764]\n',
#  '[270327, 43463, 18749]\n',
#  '[600293, 53100, 36784]\n',
#  '[450439, 40689, 27003]\n',
#  '[1074076, 33686, 14591]\n',
#  '[190875, 41000, 20472]\n',
#  '[1131334, 11439, 7607]\n',
#  '[27570, 69739, 63948]\n',
#  '[917787, 302, 53564]\n',
#  '[93596, 23532, 43293]\n',
#  '[572215, 21362, 13837]\n',
#  '[446637, 38218, 5665]\n',
#  '[17881, 75557, 11313]\n',
#  '[601335, 11820, 20097]\n',
#  '[688634, 77537, 53044]\n',
#  '[183865, 12249, 18463]\n',
#  '[1006784, 15593, 45141]\n',
#  '[1125721, 6906, 54963]\n',
#  '[1014782, 40954, 69933]\n',
#  '[791833, 11842, 26697]\n',
#  '[1016959, 34055, 46723]\n',
#  ...]
