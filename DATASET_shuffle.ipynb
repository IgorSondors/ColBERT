# %%
import random

# Открываем исходный файл для чтения
input_file_path = '/home/sondors/Documents/price/ColBERT_data/13_categories/train_aug/triples_X1_13_categories_aug.json'
with open(input_file_path, 'r', encoding='utf-8') as input_file:
    # Читаем строки из исходного файла
    lines = input_file.readlines()

lines
# Out:
# ['[0, 73892, 327392]\n',
#  '[1, 188893, 381186]\n',
#  '[2, 743857, 167736]\n',
#  '[3, 17255, 610553]\n',
#  '[4, 367708, 51075]\n',
#  '[5, 629446, 1436]\n',
#  '[6, 4334, 199845]\n',
#  '[7, 604697, 656933]\n',
#  '[8, 300858, 166264]\n',
#  '[9, 603434, 139653]\n',
#  '[10, 739298, 353320]\n',
#  '[11, 133443, 257220]\n',
#  '[12, 225059, 590228]\n',
#  '[13, 194965, 18368]\n',
#  '[14, 484170, 149429]\n',
#  '[15, 571216, 646769]\n',
#  '[16, 73663, 263776]\n',
#  '[17, 704017, 710289]\n',
#  '[18, 346758, 542575]\n',
#  '[19, 252512, 635914]\n',
#  '[20, 371203, 297328]\n',
#  '[21, 605226, 117236]\n',
#  '[22, 129442, 698899]\n',
#  '[23, 526673, 451644]\n',
#  '[24, 681030, 516629]\n',
#  '[25, 351166, 139675]\n',
#  '[26, 374680, 210429]\n',
#  '[27, 754449, 50623]\n',
#  '[28, 353356, 727621]\n',
#  '[29, 590384, 249747]\n',
#  '[30, 139013, 388683]\n',
#  '[31, 127701, 535361]\n',
#  '[32, 119841, 228778]\n',
#  '[33, 133820, 61842]\n',
#  '[34, 233384, 65451]\n',
# ...

# %%
# Перемешиваем порядок строк
random.shuffle(lines)

# Открываем новый файл для записи
output_file_path = '/home/sondors/Documents/price/ColBERT_data/13_categories/train_aug/triples_X1_13_categories_aug_shuffle.json'
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    # Записываем перемешанные строки в новый файл
    output_file.writelines(lines)

print(f'Файл {output_file_path} успешно создан с перемешанным порядком строк.')
# Out:
# Файл /home/sondors/Documents/price/ColBERT_data/13_categories/train_aug/triples_X1_13_categories_aug_shuffle.json успешно создан с перемешанным порядком строк.

# %%
lines
# Out:
# ['[409227, 622352, 33235]\n',
#  '[526279, 606498, 14267]\n',
#  '[7348, 381658, 341130]\n',
#  '[419929, 742681, 103245]\n',
#  '[482281, 77544, 350428]\n',
#  '[124744, 299680, 470312]\n',
#  '[304725, 303092, 327679]\n',
#  '[275158, 210075, 159846]\n',
#  '[464177, 483281, 474176]\n',
#  '[170222, 267168, 251997]\n',
#  '[181578, 727018, 504112]\n',
#  '[499183, 647572, 359036]\n',
#  '[567743, 321036, 53155]\n',
#  '[460777, 413130, 603242]\n',
#  '[348567, 39423, 360924]\n',
#  '[362956, 133653, 352635]\n',
#  '[106884, 213553, 91359]\n',
#  '[190857, 563999, 376338]\n',
#  '[103790, 391787, 46031]\n',
#  '[443038, 436833, 585505]\n',
#  '[486012, 115983, 487071]\n',
#  '[509373, 485142, 717796]\n',
#  '[86187, 588693, 610313]\n',
#  '[529088, 318075, 147094]\n',
#  '[254750, 642305, 480322]\n',
#  '[16195, 713442, 491729]\n',
#  '[440382, 556816, 328961]\n',
#  '[511289, 386440, 168678]\n',
#  '[335581, 30189, 474978]\n',
#  '[212418, 712179, 449618]\n',
# ...
