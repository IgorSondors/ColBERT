# %%
import random

# Открываем исходный файл для чтения
input_file_path = '/home/sondors/Documents/price/ColBERT_data/13_categories/train_nway_6/triples_X1_13_categories_aug_nway_6.json'
with open(input_file_path, 'r', encoding='utf-8') as input_file:
    # Читаем строки из исходного файла
    lines = input_file.readlines()

lines
# Out:
# ['[0, 297984, 22660, 541886, 357441, 356913, 343590]\n',
#  '[1, 302374, 136316, 68974, 314737, 4205, 299863]\n',
#  '[2, 683103, 173256, 209482, 372034, 179069, 292431]\n',
#  '[3, 686137, 366155, 53753, 441236, 62876, 365999]\n',
#  '[4, 310752, 249001, 499647, 251804, 359565, 623930]\n',
#  '[5, 282511, 35586, 635766, 161837, 464535, 173100]\n',
#  '[6, 78041, 378514, 691329, 255704, 428815, 128848]\n',
#  '[7, 653995, 671652, 277997, 357276, 441400, 643455]\n',
#  '[8, 647473, 521125, 45398, 492314, 266673, 204923]\n',
#  '[9, 502643, 179808, 160309, 230589, 467227, 636168]\n',
#  '[10, 569376, 384032, 133976, 471469, 61882, 333107]\n',
#  '[11, 610094, 61537, 85777, 37252, 634203, 134473]\n',
#  '[12, 157673, 160746, 509088, 64942, 456033, 236856]\n',
#  '[13, 357246, 653483, 546838, 382376, 40677, 181354]\n',
#  '[14, 316037, 425477, 158930, 482299, 143019, 561991]\n',
#  '[15, 391587, 147636, 366832, 458654, 391167, 195204]\n',
# ...

# %%
# Перемешиваем порядок строк
random.shuffle(lines)

# Открываем новый файл для записи
output_file_path = '/home/sondors/Documents/price/ColBERT_data/13_categories/train_nway_6/triples_X1_13_categories_aug_nway_6_shuffle.json'
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    # Записываем перемешанные строки в новый файл
    output_file.writelines(lines)

print(f'Файл {output_file_path} успешно создан с перемешанным порядком строк.')
# Out:
# Файл /home/sondors/Documents/price/ColBERT_data/13_categories/train_nway_6/triples_X1_13_categories_aug_nway_6_shuffle.json успешно создан с перемешанным порядком строк.

# %%
lines
# Out:
# ['[465710, 217529, 346609, 620964, 510105, 639248, 492737]\n',
#  '[424886, 302374, 136316, 632150, 428005, 111073, 117532]\n',
#  '[148106, 402550, 583397, 439620, 108048, 238362, 43256]\n',
#  '[165206, 384610, 204797, 577191, 515107, 95030, 95675]\n',
#  '[568889, 488356, 532370, 649855, 680593, 568946, 377631]\n',
#  '[98951, 291816, 223199, 188384, 322302, 687200, 326144]\n',
#  '[321868, 257003, 577996, 588078, 562487, 246605, 137987]\n',
#  '[98270, 297903, 510946, 429472, 83155, 69340, 582737]\n',
#  '[355328, 310036, 606179, 259120, 58481, 560015, 396305]\n',
#  '[563679, 143795, 649693, 539085, 237278, 550932, 652214]\n',
#  '[585269, 164130, 266058, 636950, 471034, 101300, 206603]\n',
#  '[573888, 211879, 281011, 227554, 317757, 129647, 318662]\n',
#  '[353419, 138887, 84891, 286900, 330513, 301676, 339700]\n',
#  '[355911, 300968, 588025, 622456, 105725, 91739, 649440]\n',
#  '[251439, 131940, 68505, 127167, 425497, 582419, 246439]\n',
# ...
