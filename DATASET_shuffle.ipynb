# %%
import random

# Открываем исходный файл для чтения
input_file_path = '/mnt/vdb1/Datasets/ColBERT_data/13_categories/train/triples_13_categories.json'
with open(input_file_path, 'r', encoding='utf-8') as input_file:
    # Читаем строки из исходного файла
    lines = input_file.readlines()

lines
# Out:
# ['[0, 7560, 12627]\n',
#  '[1, 1262, 26637]\n',
#  '[2, 14213, 28539]\n',
#  '[3, 18949, 22608]\n',
#  '[4, 19088, 1887]\n',
#  '[5, 28671, 17821]\n',
#  '[6, 21380, 26660]\n',
#  '[7, 23909, 10963]\n',
#  '[8, 8699, 18995]\n',
#  '[9, 22020, 1501]\n',
#  '[10, 24910, 10948]\n',
#  '[11, 20688, 26367]\n',
#  '[12, 16091, 9851]\n',
#  '[13, 21384, 3049]\n',
#  '[14, 14572, 21142]\n',
#  '[15, 14498, 4759]\n',
#  '[16, 27772, 6468]\n',
#  '[17, 27655, 14267]\n',
#  '[18, 2919, 10114]\n',
#  '[19, 12043, 4090]\n',
#  '[20, 12781, 11396]\n',
#  '[21, 14732, 27317]\n',
#  '[22, 29717, 8952]\n',
#  '[23, 13116, 3823]\n',
#  '[24, 10698, 12431]\n',
#  '[25, 3713, 3424]\n',
#  '[26, 21276, 19898]\n',
#  '[27, 18790, 18243]\n',
#  '[28, 614, 27302]\n',
#  '[29, 17187, 23472]\n',
#  '[30, 10694, 5075]\n',
#  '[31, 24246, 123]\n',
#  '[32, 25974, 23939]\n',
#  '[33, 23828, 10136]\n',
#  '[34, 26225, 12414]\n',
#  '[35, 133, 6254]\n',
#  '[36, 19248, 21255]\n',
#  '[37, 11046, 9735]\n',
# ...

# %%
def shuffle_wrt_file(output_file_path, lines):
    # Перемешиваем порядок строк
    random.shuffle(lines)

    # Открываем новый файл для записи
    with open(output_file_path, 'a', encoding='utf-8') as output_file:
        # Записываем перемешанные строки в новый файл
        output_file.writelines(lines)

# multiplier = 12
# output_file_path = f'/mnt/vdb1/Datasets/ColBERT/18_categories/train/triples_X{multiplier}_shuffle.json'
# for i in range(multiplier):
#     shuffle_wrt_file(output_file_path, lines)

output_file_path = '/mnt/vdb1/Datasets/ColBERT_data/13_categories/train/triples_13_categories_shuffle.json'
shuffle_wrt_file(output_file_path, lines)

print(f'Файл {output_file_path} успешно создан с перемешанным порядком строк.')
# Out:
# Файл /mnt/vdb1/Datasets/ColBERT_data/13_categories/train/triples_13_categories_shuffle.json успешно создан с перемешанным порядком строк.

# %%
lines
# Out:
# ['[125038, 16129, 10345]\n',
#  '[166184, 21768, 26422]\n',
#  '[65082, 24494, 9475]\n',
#  '[418830, 20479, 11238]\n',
#  '[33968, 14461, 17567]\n',
#  '[247275, 455, 27970]\n',
#  '[629818, 4087, 63]\n',
#  '[483807, 199, 13889]\n',
#  '[257911, 24612, 9077]\n',
#  '[345752, 12411, 16614]\n',
#  '[70464, 1853, 23339]\n',
#  '[91424, 12398, 5313]\n',
#  '[545349, 8848, 8813]\n',
#  '[70228, 16429, 14358]\n',
#  '[84746, 5632, 22117]\n',
#  '[248934, 29036, 11962]\n',
#  '[333488, 16634, 20675]\n',
#  '[407007, 5801, 27377]\n',
#  '[465000, 16934, 6133]\n',
#  '[453947, 24125, 9905]\n',
#  '[594371, 19067, 14043]\n',
#  '[371438, 7851, 5730]\n',
#  '[550534, 18889, 28877]\n',
#  '[185487, 25437, 10756]\n',
#  '[204093, 17271, 20301]\n',
#  '[487378, 29761, 28643]\n',
#  '[57475, 7135, 9853]\n',
#  '[357138, 298, 28537]\n',
#  '[173311, 18608, 7176]\n',
#  '[287143, 16814, 28131]\n',
#  '[496905, 11366, 19076]\n',
#  '[112826, 1525, 20398]\n',
#  '[64401, 14835, 16539]\n',
# ...
